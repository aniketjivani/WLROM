# %% [markdown]
# Here we want to run individual models for all sims, out upto 750 iterations, save models in scratch on NERSC, and be able to load the model individual parameters too. Then we can build maps / interpolators and also do a visualization based on t-SNE similar to the idea shown in the parametric neural networks paper that shows if implicitly the relation to the flux rope parameters can be learnt.

# %% [markdown]
# Load environment variables

# %%
import os
from pathlib import Path

# %%
os.getcwd()
# Out:
# '/global/u1/a/ajivani/WLROM/EdgeSS'

# %%
os.path.join(os.getcwd(), "logs")
# Out:
# '/global/u1/a/ajivani/WLROM/EdgeSS/logs'

# %%
import logging

# stealing this from: 
# https://github.com/rtqichen/torchdiffeq/blob/master/examples/odenet_mnist.py#L250C1-L274C18
def get_logger(logpath, package_files=[], displaying=True, saving=True, debug=False):
    logger = logging.getLogger()
    if debug:
        level = logging.DEBUG
    else:
        level = logging.INFO
    logger.setLevel(level)
    if saving:
        info_file_handler = logging.FileHandler(logpath, mode="a")
        info_file_handler.setLevel(level)
        logger.addHandler(info_file_handler)
    if displaying:
        console_handler = logging.StreamHandler()
        console_handler.setLevel(level)
        logger.addHandler(console_handler)
        #     logger.info(filepath)

        #     with open(filepath, "r") as f:
        #         logger.info(f.read())

        #     for f in package_files:
        #         logger.info(f)
        #         with open(f, "r") as package_f:
        #             logger.info(package_f.read())

    return logger

# %%
logger = get_logger(logpath=os.path.join(os.getcwd(), "individual_nn_training.log"))

# %%
print(os.environ['PSCRATCH'])
# Out:
# /pscratch/sd/a/ajivani

# %%
scratch_dir = os.environ["PSCRATCH"]
scratch_dir
# Out:
# '/pscratch/sd/a/ajivani'

# %%
def makedirs(dirname):
    try:
        os.mkdir(dirname)
        print("Dir '{}' created to save individual models".format(dirname))
    except FileExistsError:
        print("Path already exists")

# %%
trained_models = os.path.join(scratch_dir, "trained_models_1d_edge")

# %%
makedirs(trained_models)
# Out:
# Path already exists

# %% [markdown]
# Load Packages

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# %%
adjoint=True

# %%
if adjoint:
    from torchdiffeq import odeint_adjoint as odeint
else:
    from torchdiffeq import odeint

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda', index=0)

# %%
runModel=True

# %%
import numpy as np
import scipy.linalg as la
import scipy.sparse as sparse
import matplotlib.pyplot as plt

# %%
import time
import re

# %%
# %matplotlib inline

# %%
plt.rc("axes.spines", right=True, top=True)
plt.rc("figure", dpi=300, 
       figsize=(9, 3)
      )
plt.rc("font", family="serif")
plt.rc("legend", edgecolor="none", frameon=True)
plt.style.use("dark_background")

# %%
import edge_utils as edut

# %% [markdown]
# Load a sample model and see how to access its parameters.

# %%
# sample_model = torch.load("dydt_Ay_global_model_5000_steps.pkl") 
# #this does not work, we shouldn't pickle model files probably?

# %% [markdown]
# Setup training loop for all sims, set up a logger

# %%
sims_to_remove = np.array([33, 39, 63, 73, 113, 128, 131, 142, 193, 218, 253, 264, 273, 312, 313, 324])

# %%
ed_2161, sd_2161 = edut.load_edge_data_blobfree(2161)

# %%
theta_s_2161, theta_e_2161 = np.linspace(0, 360, 512)[160] + 1.2 * 180 - 360, np.linspace(0, 360, 512)[320] + 1.2 * 180 - 360
print("Range of angles for CR2161: {} {}".format(theta_s_2161, theta_e_2161))
# Out:
# Range of angles for CR2161: -31.279843444227026 81.44031311154595

# %%
def getRValuesAllSims(edge_data_matrix):
    """
    Return r values for all sims at once so we don't lose time in training processing r values repeatedly
    """
    r_data_matrix = np.zeros(edge_data_matrix.shape)
    nsims = edge_data_matrix.shape[2]
    for i in range(nsims):
        r_vals, theta_vals = edut.getRValues(edge_data_matrix, simIdx=i, minStartIdx=0)
        r_data_matrix[:, :, i] = r_vals

    return r_data_matrix

# %%
rd_2161 = getRValuesAllSims(ed_2161)

# %%
nTimes, nTheta_2161, nSims_2161 = ed_2161.shape
nTimes, nTheta_2161, nSims_2161
# Out:
# (90, 160, 278)

# %%
theta_grid = np.linspace(np.ceil(theta_s_2161), np.ceil(theta_e_2161), nTheta_2161)

# %%
sd_modified = np.setdiff1d(sd_2161, sims_to_remove)

# %%
len(sd_modified)
# Out:
# 262

# %%
## for reproducibility, we will just load these from file instead of regenerating each time because
## kernel will have to be restarted very frequently (long training process)
# from numpy.random import Generator, PCG64
# rng = Generator(PCG64())

# nTrain = int(np.floor(0.6 * len(sd_modified)))
# nCalib = int(np.floor(0.2 * len(sd_modified)))
# nTest = len(sd_modified) - nTrain - nCalib

# nTrain, nTest, nCalib

# %%
# sd_train = np.sort(np.random.choice(sd_modified, nTrain, replace=False))
# sd_test_calib = np.setdiff1d(sd_modified, sd_train)
# sd_calib = np.sort(np.random.choice(sd_test_calib, nCalib, replace=False))
# sd_test = np.setdiff1d(sd_test_calib, sd_calib)

# sd_test, sd_calib

# %%
### LOAD FROM FILE FOR NOW FOR REPRODUCIBILITY
sd_train = np.load(os.path.join(scratch_dir, trained_models, "sd_train.npy"))
sd_test  = np.load(os.path.join(scratch_dir, trained_models, "sd_test.npy"))
sd_calib = np.load(os.path.join(scratch_dir, trained_models, "sd_calib.npy"))

# %%
np.sum(np.sort(np.hstack((sd_test, sd_calib, sd_train))) == sd_modified)
# Out:
# 262

# %%
train_sd_idx = np.array([np.where(sd_2161 == i)[0][0] for i in sd_train])
test_sd_idx  = np.array([np.where(sd_2161 == i)[0][0] for i in sd_test])

# %%
train_sd_idx_modified = np.array([np.where(sd_modified == i)[0][0] for i in sd_train])

# %%
test_sd_idx_modified = np.array([np.where(sd_modified == i)[0][0] for i in sd_test])

# %%
input_dim = rd_2161.shape[1]

# %%
input_dim
# Out:
# 160

# %%
def getDataForSim(edge_data_matrix, r_data_matrix, sim_data, sid):
    """
    Take in a randomly chosen sim from the training set and return the following:
    y0_train_torch
    y_train_torch
    i.e. IC and data in torch tensor format on Device
    t_train_torch
    and correct sim_index from sim_data
    """
    
    sim_index = np.argwhere(sim_data == sid)[0][0]
    
    r_sim = r_data_matrix[:, :, sim_index]
    
    tMinIdx, tMin, tMaxIdx, tMax = edut.getTMinTMax(edge_data_matrix, simIdx=sim_index)
    
    r_sim_valid = r_sim[tMinIdx:(tMaxIdx+1), :]
    valid_times = np.arange(tMin, tMax + 2, step=2)
    
    tTrainEnd = tMin + np.floor((2/3)*(tMax - tMin))
    
    
    trainEndIdx = np.argmin(np.abs(valid_times - tTrainEnd))
    #     trainEndIdx = np.argwhere(valid_times == tTrainEnd)[0][0]
    
    tTrain = valid_times[:(trainEndIdx + 1)]
    
    tTest = valid_times[(trainEndIdx + 1):]
    
    tTrainScaled = (tTrain - tMin) / (tMax - tMin)
    tTestScaled = (tTest - tMin) / (tMax - tMin)
    
    tAllScaled = (valid_times - tMin) / (tMax - tMin)
    
    y0_train_orig = r_sim_valid[0, :]
    y0_train_torch = torch.from_numpy(np.float32(y0_train_orig))
    y0_train_torch = y0_train_torch.reshape((1, len(y0_train_torch))).to(device)
    
    
    y_train_orig = r_sim_valid[:(trainEndIdx + 1), :]
    y_train_torch = torch.from_numpy(np.expand_dims(np.float32(y_train_orig), axis=1)).to(device)
    
    y_full_torch = torch.from_numpy(np.expand_dims(np.float32(r_sim_valid), axis=1)).to(device)
    
    t_train_torch = torch.tensor(np.float32(tTrainScaled)).to(device)
    t_scaled_torch = torch.tensor(np.float32(tAllScaled)).to(device)
    
    return y0_train_torch, y_train_torch, y_full_torch, t_train_torch, t_scaled_torch, sim_index

# %%
def get_batch(torch_train_data, torch_train_time, batch_time=5, batch_size=10):
    s = torch.from_numpy(np.random.choice(np.arange(len(torch_train_time) - batch_time, dtype=np.int64),
                                          batch_size,
                                          replace=False))
    batch_y0 = torch_train_data[s]  # (M, D)
    batch_t = torch.zeros((batch_size, batch_time))
    for i in range(batch_size):
        batch_t[i, :] = torch_train_time[s[i]:(s[i] + batch_time)]
        
    batch_y = torch.stack([torch_train_data[s + i] for i in range(batch_time)], dim=0)  # (T, M, D)
    return batch_y0.to(device), batch_t.to(device), batch_y.to(device)

# %%
class ODEFunc(nn.Module):

    def __init__(self, dim):
        super(ODEFunc, self).__init__()

        self.net1 = nn.Sequential(
            nn.Linear(dim, 100),
            nn.Tanh(),
            nn.Linear(100, 100),
            nn.Tanh(),
            nn.Linear(100, dim),
        )
        
        for m in self.net1.modules():
            if isinstance(m, nn.Linear):
                nn.init.normal_(m.weight, mean=0, std=0.1)
                nn.init.constant_(m.bias, val=0)
                
    def forward(self, t, y):
        return self.net1(y)

# %%
class RunningAverageMeter(object):
    """Computes and stores the average and current value"""

    def __init__(self, momentum=0.99):
        self.momentum = momentum
        self.losses = []
        self.reset()

    def reset(self):
        self.val = None
        self.avg = 0

    def update(self, val):
        if self.val is None:
            self.avg = val
        else:
            self.avg = self.avg * self.momentum + val * (1 - self.momentum)
        self.val = val
        self.losses.append(self.avg)

# %%
def getAbsoluteAvgBatchLoss(prediction_tensor, target_tensor):
    """
    both tensors are of dims (n_times, n_batch, 1, len_traj) or (n_times, 1, len_traj)
    """
    
    # swap dimensions of batch and time
    if len(prediction_tensor.shape) > 3:
        prediction_tensor = torch.permute(prediction_tensor, (1, 0, 2, 3))
        target_tensor = torch.permute(target_tensor, (1, 0, 2, 3))
        # print(prediction_tensor.shape)#testing
        # get torch.abs of difference
        abs_diff = torch.abs(prediction_tensor - target_tensor)

        # sum over trajectory length
        batch_sums = torch.sum(abs_diff, 3)
    else:
        prediction_tensor = torch.permute(prediction_tensor, (1, 0, 2))
        target_tensor = torch.permute(target_tensor, (1, 0, 2))
        # print(prediction_tensor.shape)#testing
        # get torch.abs of difference
        abs_diff = torch.abs(prediction_tensor - target_tensor)

        # sum over trajectory length
        batch_sums = torch.sum(abs_diff, 2)


    # print(batch_sums.shape)  #testing
    
    # get mean of final tensor to get batch and time averaged absolute loss
    batch_loss = torch.mean(batch_sums)
    
    # print(batch_loss)#testing
    
    return batch_loss

# %%
# Stealing from: 
# github.com/rtqichen/torchdiffeq/blob/84e220ac9ea9367c14933d8f141fc2791034ec88/
# examples/odenet_mnist.py#L241C1-L242C73

def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %%
# Sketch of what each loop would look like:

def runNeuralODE(simID, model_save_path, niters=750, test_freq=5, batch_time=5, batch_size=10):
    y0_train_torch, y_train_torch, y_full_torch, t_train_torch, t_scaled_torch, sim_index = getDataForSim(ed_2161,rd_2161,sd_2161,simID)

    time_meter = RunningAverageMeter(0.97)
    loss_meter = RunningAverageMeter(0.97)

    ii = 0
    func = ODEFunc(160).to(device)
    optimizer = optim.Adam(func.parameters(), lr=1e-3)
    end = time.time()

    logger.info(func)
    logger.info('Number of parameters: {}'.format(count_parameters(func)))
    
    niters=niters
    test_freq=test_freq

    for itr in range(1, niters + 1):
        optimizer.zero_grad()
        batch_y0, batch_t, batch_y = get_batch(y_train_torch, 
                                               t_train_torch,
                                              batch_time=batch_time,
                                              batch_size=batch_size)
        pred_y = torch.zeros_like(batch_y)

        for i in range(batch_size):
            pred_y[:, i, :, :] = odeint(func, 
                                        batch_y0[i, :, :], 
                                        batch_t[i, :]).to(device)

        loss = getAbsoluteAvgBatchLoss(pred_y, batch_y)
        loss.backward()
        optimizer.step()

        time_meter.update(time.time() - end)
        loss_meter.update(loss.item())

        if itr % test_freq == 0:
            with torch.no_grad():
                pred_y_full_series = odeint(func, 
                                            y0_train_torch, 
                                            t_scaled_torch)
                loss_full_series = getAbsoluteAvgBatchLoss(pred_y_full_series, 
                                                           y_full_torch)
                # print("Iter {:04d} | Total Loss {:.6f} | Sim {:03d} ".format(itr,
                                                                # loss_full_series.item(), 
                                                                # simID))
                
                
                logger.info("Iter {:04d} | Total Loss {:.6f} | Sim {:03d} ".format(itr,
                                                                loss_full_series.item(), 
                                                                simID))

                ii += 1

        end = time.time()
    
        
    model_dict_name = "dydt_Ay_750_steps_sim_{:03d}.pt".format(simID)
    torch.save(func.state_dict(), os.path.join(model_save_path, model_dict_name))
    # print("Saved Model for Sim {:03d}".format(simID))
    logger.info("Saved Model for Sim {:03d}\n".format(simID))
    torch.cuda.empty_cache()

# %% [markdown]
# ### Call training process for one or more sims and save model once trained

# %%
trained_models
# Out:
# '/pscratch/sd/a/ajivani/trained_models_1d_edge'

# %%
sd_train
# Out:
# array([ 31,  32,  35,  37,  40,  42,  43,  45,  46,  47,  48,  49,  52,
#         53,  57,  59,  60,  61,  62,  66,  67,  70,  71,  74,  75,  76,
#         77,  78,  79,  80,  83,  84,  85,  87,  90,  91,  92,  94,  95,
#         96,  97,  98, 100, 101, 102, 106, 108, 111, 112, 114, 120, 121,
#        123, 124, 130, 132, 135, 136, 138, 139, 140, 141, 143, 147, 148,
#        149, 150, 151, 154, 155, 156, 157, 158, 159, 161, 164, 174, 178,
#        180, 183, 184, 185, 190, 192, 194, 196, 197, 198, 199, 202, 204,
#        205, 209, 210, 211, 212, 215, 216, 217, 219, 220, 221, 222, 223,
#        229, 230, 232, 234, 235, 236, 238, 240, 241, 242, 243, 244, 246,
#        248, 249, 251, 252, 254, 256, 257, 260, 261, 263, 271, 274, 275,
#        276, 277, 278, 279, 281, 282, 284, 287, 288, 289, 290, 291, 293,
#        298, 299, 301, 303, 305, 311, 314, 315, 317, 318, 319, 323, 325,
#        329])

# %%
# SIMS STILL PENDING
# 32, 37, 40, 47, 52, 53, 61, 62, 78, 79, 87, 91, 92, 95, 98, 100 (rest all are correct)

# %%
sd_train[140]
# Out:
# 290

# %%
sd_train[156]
# Out:
# 329

# %%
pending_sims = np.array([32, 37, 40, 47, 52, 53, 61, 62, 78, 79, 87, 91, 92, 95, 98, 100])

# %% [markdown]
# We probably need some sort of script that can launch jobs on multiple GPUs or try running models in parallel on the same GPU? abandoning this idea for now as there are very specific implementations
# that may or may not apply to this scenario.

# %%
# for sim in sd_train[140:]:
for sim in pending_sims:
    runNeuralODE(sim, trained_models, niters=750, test_freq=5)
# Out:
# ODEFunc(
#   (net1): Sequential(
#     (0): Linear(in_features=160, out_features=100, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=100, out_features=100, bias=True)
#     (3): Tanh()
#     (4): Linear(in_features=100, out_features=160, bias=True)
#   )
# )
# Number of parameters: 42360
# Iter 0005 | Total Loss 343.554352 | Sim 032
# Iter 0010 | Total Loss 309.172302 | Sim 032
# Iter 0015 | Total Loss 273.139252 | Sim 032
# Iter 0020 | Total Loss 234.920319 | Sim 032
# Iter 0025 | Total Loss 195.499725 | Sim 032
# Iter 0030 | Total Loss 156.908218 | Sim 032
# Iter 0035 | Total Loss 121.750351 | Sim 032
# Iter 0040 | Total Loss 90.421333 | Sim 032
# Iter 0045 | Total Loss 64.205299 | Sim 032
# Iter 0050 | Total Loss 47.325859 | Sim 032
# Iter 0055 | Total Loss 39.042061 | Sim 032
# Iter 0060 | Total Loss 35.162102 | Sim 032
# Iter 0065 | Total Loss 32.035881 | Sim 032
# Iter 0070 | Total Loss 29.533352 | Sim 032
# Iter 0075 | Total Loss 28.328007 | Sim 032
# Iter 0080 | Total Loss 27.382954 | Sim 032
# Iter 0085 | Total Loss 26.200464 | Sim 032
# Iter 0090 | Total Loss 25.375118 | Sim 032
# Iter 0095 | Total Loss 24.945833 | Sim 032
# Iter 0100 | Total Loss 25.164331 | Sim 032
# Iter 0105 | Total Loss 25.901136 | Sim 032
# Iter 0110 | Total Loss 25.188623 | Sim 032
# Iter 0115 | Total Loss 25.152946 | Sim 032
# Iter 0120 | Total Loss 24.845831 | Sim 032
# Iter 0125 | Total Loss 24.462774 | Sim 032
# Iter 0130 | Total Loss 24.747089 | Sim 032
# Iter 0135 | Total Loss 24.267981 | Sim 032
# Iter 0140 | Total Loss 24.064445 | Sim 032
# Iter 0145 | Total Loss 24.200052 | Sim 032
# Iter 0150 | Total Loss 24.534529 | Sim 032
# Iter 0155 | Total Loss 24.043032 | Sim 032
# Iter 0160 | Total Loss 23.494539 | Sim 032
# Iter 0165 | Total Loss 23.836651 | Sim 032
# Iter 0170 | Total Loss 23.861158 | Sim 032
# Iter 0175 | Total Loss 24.355003 | Sim 032
# Iter 0180 | Total Loss 24.199368 | Sim 032
# Iter 0185 | Total Loss 23.980047 | Sim 032
# Iter 0190 | Total Loss 23.979715 | Sim 032
# Iter 0195 | Total Loss 23.811462 | Sim 032
# Iter 0200 | Total Loss 24.419147 | Sim 032
# Iter 0205 | Total Loss 25.149040 | Sim 032
# Iter 0210 | Total Loss 25.333460 | Sim 032
# Iter 0215 | Total Loss 24.724083 | Sim 032
# Iter 0220 | Total Loss 24.815678 | Sim 032
# Iter 0225 | Total Loss 24.786970 | Sim 032
# Iter 0230 | Total Loss 24.888884 | Sim 032
# Iter 0235 | Total Loss 25.234362 | Sim 032
# Iter 0240 | Total Loss 24.576332 | Sim 032
# Iter 0245 | Total Loss 24.265865 | Sim 032
# Iter 0250 | Total Loss 24.041899 | Sim 032
# Iter 0255 | Total Loss 24.355404 | Sim 032
# Iter 0260 | Total Loss 24.549026 | Sim 032
# Iter 0265 | Total Loss 25.806368 | Sim 032
# Iter 0270 | Total Loss 25.405527 | Sim 032
# Iter 0275 | Total Loss 24.915276 | Sim 032
# Iter 0280 | Total Loss 24.243706 | Sim 032
# Iter 0285 | Total Loss 23.373384 | Sim 032
# Iter 0290 | Total Loss 23.760084 | Sim 032
# Iter 0295 | Total Loss 24.214340 | Sim 032
# Iter 0300 | Total Loss 24.079290 | Sim 032
# Iter 0305 | Total Loss 24.602421 | Sim 032
# Iter 0310 | Total Loss 25.112354 | Sim 032
# Iter 0315 | Total Loss 25.529480 | Sim 032
# Iter 0320 | Total Loss 25.511177 | Sim 032
# Iter 0325 | Total Loss 25.355600 | Sim 032
# Iter 0330 | Total Loss 24.769741 | Sim 032
# Iter 0335 | Total Loss 25.242365 | Sim 032
# Iter 0340 | Total Loss 25.773581 | Sim 032
# Iter 0345 | Total Loss 26.434153 | Sim 032
# Iter 0350 | Total Loss 25.589317 | Sim 032
# Iter 0355 | Total Loss 26.244833 | Sim 032
# Iter 0360 | Total Loss 27.510515 | Sim 032
# Iter 0365 | Total Loss 26.113291 | Sim 032
# Iter 0370 | Total Loss 24.720814 | Sim 032
# Iter 0375 | Total Loss 24.525433 | Sim 032
# Iter 0380 | Total Loss 23.941292 | Sim 032
# Iter 0385 | Total Loss 23.838408 | Sim 032
# Iter 0390 | Total Loss 24.357388 | Sim 032
# Iter 0395 | Total Loss 24.079576 | Sim 032
# Iter 0400 | Total Loss 24.653481 | Sim 032
# Iter 0405 | Total Loss 24.246527 | Sim 032
# Iter 0410 | Total Loss 24.758490 | Sim 032
# Iter 0415 | Total Loss 25.976067 | Sim 032
# Iter 0420 | Total Loss 25.336885 | Sim 032
# Iter 0425 | Total Loss 27.410938 | Sim 032
# Iter 0430 | Total Loss 27.120672 | Sim 032
# Iter 0435 | Total Loss 25.959658 | Sim 032
# Iter 0440 | Total Loss 24.869146 | Sim 032
# Iter 0445 | Total Loss 24.443754 | Sim 032
# Iter 0450 | Total Loss 24.344339 | Sim 032
# Iter 0455 | Total Loss 25.165565 | Sim 032
# Iter 0460 | Total Loss 24.566727 | Sim 032
# Iter 0465 | Total Loss 23.860435 | Sim 032
# Iter 0470 | Total Loss 24.116287 | Sim 032
# Iter 0475 | Total Loss 24.965673 | Sim 032
# Iter 0480 | Total Loss 26.175364 | Sim 032
# Iter 0485 | Total Loss 26.143381 | Sim 032
# Iter 0490 | Total Loss 26.313913 | Sim 032
# Iter 0495 | Total Loss 26.636984 | Sim 032
# Iter 0500 | Total Loss 26.049198 | Sim 032
# Iter 0505 | Total Loss 25.073383 | Sim 032
# Iter 0510 | Total Loss 24.519444 | Sim 032
# Iter 0515 | Total Loss 24.505419 | Sim 032
# Iter 0520 | Total Loss 24.933676 | Sim 032
# Iter 0525 | Total Loss 24.214241 | Sim 032
# Iter 0530 | Total Loss 24.809454 | Sim 032
# Iter 0535 | Total Loss 25.186344 | Sim 032
# Iter 0540 | Total Loss 24.692160 | Sim 032
# Iter 0545 | Total Loss 25.120049 | Sim 032
# Iter 0550 | Total Loss 24.304409 | Sim 032
# Iter 0555 | Total Loss 24.054119 | Sim 032
# Iter 0560 | Total Loss 23.808809 | Sim 032
# Iter 0565 | Total Loss 24.025209 | Sim 032
# Iter 0570 | Total Loss 24.598131 | Sim 032
# Iter 0575 | Total Loss 25.885036 | Sim 032
# Iter 0580 | Total Loss 25.247726 | Sim 032
# Iter 0585 | Total Loss 24.554579 | Sim 032
# Iter 0590 | Total Loss 24.429758 | Sim 032
# Iter 0595 | Total Loss 24.265362 | Sim 032
# Iter 0600 | Total Loss 24.024006 | Sim 032
# Iter 0605 | Total Loss 23.730232 | Sim 032
# Iter 0610 | Total Loss 23.921389 | Sim 032
# Iter 0615 | Total Loss 25.385523 | Sim 032
# Iter 0620 | Total Loss 25.272041 | Sim 032
# Iter 0625 | Total Loss 25.365971 | Sim 032
# Iter 0630 | Total Loss 25.290581 | Sim 032
# Iter 0635 | Total Loss 25.358580 | Sim 032
# Iter 0640 | Total Loss 25.757624 | Sim 032
# Iter 0645 | Total Loss 26.608025 | Sim 032
# Iter 0650 | Total Loss 27.759470 | Sim 032
# Iter 0655 | Total Loss 25.934322 | Sim 032
# Iter 0660 | Total Loss 26.264038 | Sim 032
# Iter 0665 | Total Loss 26.163956 | Sim 032
# Iter 0670 | Total Loss 25.688215 | Sim 032
# Iter 0675 | Total Loss 25.666525 | Sim 032
# Iter 0680 | Total Loss 24.092529 | Sim 032
# Iter 0685 | Total Loss 24.930664 | Sim 032
# Iter 0690 | Total Loss 24.636610 | Sim 032
# Iter 0695 | Total Loss 24.789118 | Sim 032
# Iter 0700 | Total Loss 25.171003 | Sim 032
# Iter 0705 | Total Loss 25.812485 | Sim 032
# Iter 0710 | Total Loss 24.368231 | Sim 032
# Iter 0715 | Total Loss 24.091288 | Sim 032
# Iter 0720 | Total Loss 24.145313 | Sim 032
# Iter 0725 | Total Loss 23.982594 | Sim 032
# Iter 0730 | Total Loss 24.432318 | Sim 032
# Iter 0735 | Total Loss 25.007235 | Sim 032
# Iter 0740 | Total Loss 24.368931 | Sim 032
# Iter 0745 | Total Loss 24.495222 | Sim 032
# Iter 0750 | Total Loss 24.488497 | Sim 032
# Saved Model for Sim 032
#
# ODEFunc(
#   (net1): Sequential(
#     (0): Linear(in_features=160, out_features=100, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=100, out_features=100, bias=True)
#     (3): Tanh()
#     (4): Linear(in_features=100, out_features=160, bias=True)
#   )
# )
# Number of parameters: 42360
# Iter 0005 | Total Loss 670.097351 | Sim 037
# Iter 0010 | Total Loss 632.914917 | Sim 037
# Iter 0015 | Total Loss 592.506897 | Sim 037
# Iter 0020 | Total Loss 548.666809 | Sim 037
# Iter 0025 | Total Loss 504.046417 | Sim 037
# Iter 0030 | Total Loss 459.633423 | Sim 037
# Iter 0035 | Total Loss 415.999603 | Sim 037
# Iter 0040 | Total Loss 373.617523 | Sim 037
# Iter 0045 | Total Loss 333.063263 | Sim 037
# Iter 0050 | Total Loss 293.943024 | Sim 037
# Iter 0055 | Total Loss 258.675629 | Sim 037
# Iter 0060 | Total Loss 225.129395 | Sim 037
# Iter 0065 | Total Loss 194.314484 | Sim 037
# Iter 0070 | Total Loss 166.881042 | Sim 037
# Iter 0075 | Total Loss 142.865982 | Sim 037
# Iter 0080 | Total Loss 122.573448 | Sim 037
# Iter 0085 | Total Loss 104.870201 | Sim 037
# Iter 0090 | Total Loss 89.275894 | Sim 037
# Iter 0095 | Total Loss 77.045250 | Sim 037
# Iter 0100 | Total Loss 67.832405 | Sim 037
# Iter 0105 | Total Loss 60.788456 | Sim 037
# Iter 0110 | Total Loss 54.149590 | Sim 037
# Iter 0115 | Total Loss 49.117664 | Sim 037
# Iter 0120 | Total Loss 45.552986 | Sim 037
# Iter 0125 | Total Loss 41.390621 | Sim 037
# Iter 0130 | Total Loss 38.204109 | Sim 037
# Iter 0135 | Total Loss 36.616879 | Sim 037
# Iter 0140 | Total Loss 36.055317 | Sim 037
# Iter 0145 | Total Loss 35.661919 | Sim 037
# Iter 0150 | Total Loss 35.566174 | Sim 037
# Iter 0155 | Total Loss 35.715855 | Sim 037
# Iter 0160 | Total Loss 36.009552 | Sim 037
# Iter 0165 | Total Loss 36.152454 | Sim 037
# Iter 0170 | Total Loss 35.958328 | Sim 037
# Iter 0175 | Total Loss 35.540169 | Sim 037
# Iter 0180 | Total Loss 35.328945 | Sim 037
# Iter 0185 | Total Loss 35.539425 | Sim 037
# Iter 0190 | Total Loss 35.334641 | Sim 037
# Iter 0195 | Total Loss 35.545113 | Sim 037
# Iter 0200 | Total Loss 37.112133 | Sim 037
# Iter 0205 | Total Loss 40.139183 | Sim 037
# Iter 0210 | Total Loss 44.044910 | Sim 037
# Iter 0215 | Total Loss 47.143219 | Sim 037
# Iter 0220 | Total Loss 47.239433 | Sim 037
# Iter 0225 | Total Loss 47.979237 | Sim 037
# Iter 0230 | Total Loss 49.681992 | Sim 037
# Iter 0235 | Total Loss 49.966782 | Sim 037
# Iter 0240 | Total Loss 47.295837 | Sim 037
# Iter 0245 | Total Loss 46.856567 | Sim 037
# Iter 0250 | Total Loss 47.468544 | Sim 037
# Iter 0255 | Total Loss 48.082935 | Sim 037
# Iter 0260 | Total Loss 49.092754 | Sim 037
# Iter 0265 | Total Loss 50.950043 | Sim 037
# Iter 0270 | Total Loss 49.624710 | Sim 037
# Iter 0275 | Total Loss 48.109066 | Sim 037
# Iter 0280 | Total Loss 47.613316 | Sim 037
# Iter 0285 | Total Loss 51.622498 | Sim 037
# Iter 0290 | Total Loss 53.999897 | Sim 037
# Iter 0295 | Total Loss 53.667068 | Sim 037
# Iter 0300 | Total Loss 50.364986 | Sim 037
# Iter 0305 | Total Loss 46.852516 | Sim 037
# Iter 0310 | Total Loss 49.179611 | Sim 037
# Iter 0315 | Total Loss 52.271019 | Sim 037
# Iter 0320 | Total Loss 53.983849 | Sim 037
# Iter 0325 | Total Loss 57.094925 | Sim 037
# Iter 0330 | Total Loss 59.041130 | Sim 037
# Iter 0335 | Total Loss 58.879841 | Sim 037
# Iter 0340 | Total Loss 54.402847 | Sim 037
# Iter 0345 | Total Loss 51.136375 | Sim 037
# Iter 0350 | Total Loss 48.020176 | Sim 037
# Iter 0355 | Total Loss 47.992752 | Sim 037
# Iter 0360 | Total Loss 49.113899 | Sim 037
# Iter 0365 | Total Loss 48.735603 | Sim 037
# Iter 0370 | Total Loss 46.100887 | Sim 037
# Iter 0375 | Total Loss 43.988575 | Sim 037
# Iter 0380 | Total Loss 44.927746 | Sim 037
# Iter 0385 | Total Loss 47.010170 | Sim 037
# Iter 0390 | Total Loss 48.348785 | Sim 037
# Iter 0395 | Total Loss 50.507359 | Sim 037
# Iter 0400 | Total Loss 49.753525 | Sim 037
# Iter 0405 | Total Loss 45.591595 | Sim 037
# Iter 0410 | Total Loss 44.163719 | Sim 037
# Iter 0415 | Total Loss 46.192917 | Sim 037
# Iter 0420 | Total Loss 49.563797 | Sim 037
# Iter 0425 | Total Loss 47.655743 | Sim 037
# Iter 0430 | Total Loss 44.327930 | Sim 037
# Iter 0435 | Total Loss 45.115196 | Sim 037
# Iter 0440 | Total Loss 51.517227 | Sim 037
# Iter 0445 | Total Loss 55.244835 | Sim 037
# Iter 0450 | Total Loss 56.102409 | Sim 037
# Iter 0455 | Total Loss 58.810917 | Sim 037
# Iter 0460 | Total Loss 59.344772 | Sim 037
# Iter 0465 | Total Loss 53.711224 | Sim 037
# Iter 0470 | Total Loss 45.876507 | Sim 037
# Iter 0475 | Total Loss 43.581081 | Sim 037
# Iter 0480 | Total Loss 41.666924 | Sim 037
# Iter 0485 | Total Loss 42.160892 | Sim 037
# Iter 0490 | Total Loss 46.360237 | Sim 037
# Iter 0495 | Total Loss 53.516495 | Sim 037
# Iter 0500 | Total Loss 53.570988 | Sim 037
# Iter 0505 | Total Loss 47.631245 | Sim 037
# Iter 0510 | Total Loss 45.823093 | Sim 037
# Iter 0515 | Total Loss 44.723438 | Sim 037
# Iter 0520 | Total Loss 42.701637 | Sim 037
# Iter 0525 | Total Loss 39.616474 | Sim 037
# Iter 0530 | Total Loss 38.599777 | Sim 037
# Iter 0535 | Total Loss 41.807362 | Sim 037
# Iter 0540 | Total Loss 46.981129 | Sim 037
# Iter 0545 | Total Loss 50.464733 | Sim 037
# Iter 0550 | Total Loss 51.627903 | Sim 037
# Iter 0555 | Total Loss 45.623878 | Sim 037
# Iter 0560 | Total Loss 42.866982 | Sim 037
# Iter 0565 | Total Loss 40.161911 | Sim 037
# Iter 0570 | Total Loss 39.018852 | Sim 037
# Iter 0575 | Total Loss 39.647942 | Sim 037
# Iter 0580 | Total Loss 38.429493 | Sim 037
# Iter 0585 | Total Loss 35.679344 | Sim 037
# Iter 0590 | Total Loss 35.052341 | Sim 037
# Iter 0595 | Total Loss 35.020454 | Sim 037
# Iter 0600 | Total Loss 35.097752 | Sim 037
# Iter 0605 | Total Loss 36.153194 | Sim 037
# Iter 0610 | Total Loss 37.021999 | Sim 037
# Iter 0615 | Total Loss 39.454884 | Sim 037
# Iter 0620 | Total Loss 45.195984 | Sim 037
# Iter 0625 | Total Loss 50.612194 | Sim 037
# Iter 0630 | Total Loss 52.753635 | Sim 037
# Iter 0635 | Total Loss 54.545765 | Sim 037
# Iter 0640 | Total Loss 54.634876 | Sim 037
# Iter 0645 | Total Loss 53.926655 | Sim 037
# Iter 0650 | Total Loss 52.509808 | Sim 037
# Iter 0655 | Total Loss 44.586147 | Sim 037
# Iter 0660 | Total Loss 40.191219 | Sim 037
# Iter 0665 | Total Loss 39.083839 | Sim 037
# Iter 0670 | Total Loss 37.562843 | Sim 037
# Iter 0675 | Total Loss 37.807499 | Sim 037
# Iter 0680 | Total Loss 40.527378 | Sim 037
# Iter 0685 | Total Loss 48.984528 | Sim 037
# Iter 0690 | Total Loss 65.246956 | Sim 037
# Iter 0695 | Total Loss 77.085236 | Sim 037
# Iter 0700 | Total Loss 73.797348 | Sim 037
# Iter 0705 | Total Loss 63.452423 | Sim 037
# Iter 0710 | Total Loss 55.645714 | Sim 037
# Iter 0715 | Total Loss 48.309364 | Sim 037
# Iter 0720 | Total Loss 41.579071 | Sim 037
# Iter 0725 | Total Loss 38.736671 | Sim 037
# Iter 0730 | Total Loss 37.708496 | Sim 037
# Iter 0735 | Total Loss 39.403389 | Sim 037
# Iter 0740 | Total Loss 38.406754 | Sim 037
# Iter 0745 | Total Loss 39.833344 | Sim 037
# Iter 0750 | Total Loss 43.208027 | Sim 037
# Saved Model for Sim 037
#
# ODEFunc(
#   (net1): Sequential(
#     (0): Linear(in_features=160, out_features=100, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=100, out_features=100, bias=True)
#     (3): Tanh()
#     (4): Linear(in_features=100, out_features=160, bias=True)
#   )
# )
# Number of parameters: 42360
# Iter 0005 | Total Loss 1021.465942 | Sim 040
# Iter 0010 | Total Loss 983.301880 | Sim 040
# Iter 0015 | Total Loss 942.277954 | Sim 040
# Iter 0020 | Total Loss 899.446350 | Sim 040
# Iter 0025 | Total Loss 855.992676 | Sim 040
# Iter 0030 | Total Loss 812.729370 | Sim 040
# Iter 0035 | Total Loss 769.856262 | Sim 040
# Iter 0040 | Total Loss 726.633362 | Sim 040
# Iter 0045 | Total Loss 682.976990 | Sim 040
# Iter 0050 | Total Loss 639.590454 | Sim 040
# Iter 0055 | Total Loss 596.960327 | Sim 040
# Iter 0060 | Total Loss 555.119934 | Sim 040
# Iter 0065 | Total Loss 513.700012 | Sim 040
# Iter 0070 | Total Loss 472.599854 | Sim 040
# Iter 0075 | Total Loss 432.366333 | Sim 040
# Iter 0080 | Total Loss 392.884033 | Sim 040
# Iter 0085 | Total Loss 354.407410 | Sim 040
# Iter 0090 | Total Loss 317.200623 | Sim 040
# Iter 0095 | Total Loss 281.679993 | Sim 040
# Iter 0100 | Total Loss 247.927612 | Sim 040
# Iter 0105 | Total Loss 216.890472 | Sim 040
# Iter 0110 | Total Loss 190.423203 | Sim 040
# Iter 0115 | Total Loss 166.169983 | Sim 040
# Iter 0120 | Total Loss 144.577316 | Sim 040
# Iter 0125 | Total Loss 125.278099 | Sim 040
# Iter 0130 | Total Loss 108.095741 | Sim 040
# Iter 0135 | Total Loss 93.831802 | Sim 040
# Iter 0140 | Total Loss 83.239410 | Sim 040
# Iter 0145 | Total Loss 74.838455 | Sim 040
# Iter 0150 | Total Loss 68.324211 | Sim 040
# Iter 0155 | Total Loss 62.961250 | Sim 040
# Iter 0160 | Total Loss 59.729214 | Sim 040
# Iter 0165 | Total Loss 57.726891 | Sim 040
# Iter 0170 | Total Loss 55.596851 | Sim 040
# Iter 0175 | Total Loss 53.752708 | Sim 040
# Iter 0180 | Total Loss 53.432476 | Sim 040
# Iter 0185 | Total Loss 53.759987 | Sim 040
# Iter 0190 | Total Loss 54.101437 | Sim 040
# Iter 0195 | Total Loss 55.081394 | Sim 040
# Iter 0200 | Total Loss 55.556591 | Sim 040
# Iter 0205 | Total Loss 55.861889 | Sim 040
# Iter 0210 | Total Loss 55.930561 | Sim 040
# Iter 0215 | Total Loss 56.682487 | Sim 040
# Iter 0220 | Total Loss 57.179962 | Sim 040
# Iter 0225 | Total Loss 57.392181 | Sim 040
# Iter 0230 | Total Loss 57.321445 | Sim 040
# Iter 0235 | Total Loss 57.203381 | Sim 040
# Iter 0240 | Total Loss 56.114117 | Sim 040
# Iter 0245 | Total Loss 56.159821 | Sim 040
# Iter 0250 | Total Loss 56.037006 | Sim 040
# Iter 0255 | Total Loss 55.349136 | Sim 040
# Iter 0260 | Total Loss 55.122761 | Sim 040
# Iter 0265 | Total Loss 55.091969 | Sim 040
# Iter 0270 | Total Loss 55.022266 | Sim 040
# Iter 0275 | Total Loss 56.574455 | Sim 040
# Iter 0280 | Total Loss 58.094612 | Sim 040
# Iter 0285 | Total Loss 58.532593 | Sim 040
# Iter 0290 | Total Loss 57.534473 | Sim 040
# Iter 0295 | Total Loss 56.795639 | Sim 040
# Iter 0300 | Total Loss 57.072685 | Sim 040
# Iter 0305 | Total Loss 58.871498 | Sim 040
# Iter 0310 | Total Loss 59.924526 | Sim 040
# Iter 0315 | Total Loss 60.650902 | Sim 040
# Iter 0320 | Total Loss 60.410164 | Sim 040
# Iter 0325 | Total Loss 59.512409 | Sim 040
# Iter 0330 | Total Loss 60.002201 | Sim 040
# Iter 0335 | Total Loss 59.466839 | Sim 040
# Iter 0340 | Total Loss 58.865177 | Sim 040
# Iter 0345 | Total Loss 57.753490 | Sim 040
# Iter 0350 | Total Loss 56.078060 | Sim 040
# Iter 0355 | Total Loss 55.529037 | Sim 040
# Iter 0360 | Total Loss 54.827812 | Sim 040
# Iter 0365 | Total Loss 55.702007 | Sim 040
# Iter 0370 | Total Loss 56.827682 | Sim 040
# Iter 0375 | Total Loss 57.311035 | Sim 040
# Iter 0380 | Total Loss 57.412254 | Sim 040
# Iter 0385 | Total Loss 58.376637 | Sim 040
# Iter 0390 | Total Loss 58.014935 | Sim 040
# Iter 0395 | Total Loss 57.007008 | Sim 040
# Iter 0400 | Total Loss 56.069115 | Sim 040
# Iter 0405 | Total Loss 54.490997 | Sim 040
# Iter 0410 | Total Loss 53.818172 | Sim 040
# Iter 0415 | Total Loss 53.944118 | Sim 040
# Iter 0420 | Total Loss 54.042271 | Sim 040
# Iter 0425 | Total Loss 54.511162 | Sim 040
# Iter 0430 | Total Loss 55.096722 | Sim 040
# Iter 0435 | Total Loss 54.956497 | Sim 040
# Iter 0440 | Total Loss 54.426765 | Sim 040
# Iter 0445 | Total Loss 54.228497 | Sim 040
# Iter 0450 | Total Loss 54.389992 | Sim 040
# Iter 0455 | Total Loss 53.712601 | Sim 040
# Iter 0460 | Total Loss 52.846844 | Sim 040
# Iter 0465 | Total Loss 52.762783 | Sim 040
# Iter 0470 | Total Loss 52.262997 | Sim 040
# Iter 0475 | Total Loss 51.555943 | Sim 040
# Iter 0480 | Total Loss 50.808369 | Sim 040
# Iter 0485 | Total Loss 50.845737 | Sim 040
# Iter 0490 | Total Loss 50.786213 | Sim 040
# Iter 0495 | Total Loss 51.425537 | Sim 040
# Iter 0500 | Total Loss 53.320316 | Sim 040
# Iter 0505 | Total Loss 55.184925 | Sim 040
# Iter 0510 | Total Loss 55.388088 | Sim 040
# Iter 0515 | Total Loss 54.275066 | Sim 040
# Iter 0520 | Total Loss 53.877834 | Sim 040
# Iter 0525 | Total Loss 54.607586 | Sim 040
# Iter 0530 | Total Loss 54.567863 | Sim 040
# Iter 0535 | Total Loss 55.850094 | Sim 040
# Iter 0540 | Total Loss 57.086956 | Sim 040
# Iter 0545 | Total Loss 57.702984 | Sim 040
# Iter 0550 | Total Loss 57.785126 | Sim 040
# Iter 0555 | Total Loss 56.621929 | Sim 040
# Iter 0560 | Total Loss 57.897526 | Sim 040
# Iter 0565 | Total Loss 60.039108 | Sim 040
# Iter 0570 | Total Loss 61.347404 | Sim 040
# Iter 0575 | Total Loss 60.899635 | Sim 040
# Iter 0580 | Total Loss 59.034630 | Sim 040
# Iter 0585 | Total Loss 56.374493 | Sim 040
# Iter 0590 | Total Loss 55.956161 | Sim 040
# Iter 0595 | Total Loss 57.674942 | Sim 040
# Iter 0600 | Total Loss 57.822330 | Sim 040
# Iter 0605 | Total Loss 56.376198 | Sim 040
# Iter 0610 | Total Loss 55.621487 | Sim 040
# Iter 0615 | Total Loss 55.766460 | Sim 040
# Iter 0620 | Total Loss 56.886890 | Sim 040
# Iter 0625 | Total Loss 59.817093 | Sim 040
# Iter 0630 | Total Loss 62.092983 | Sim 040
# Iter 0635 | Total Loss 61.749004 | Sim 040
# Iter 0640 | Total Loss 60.441090 | Sim 040
# Iter 0645 | Total Loss 58.528095 | Sim 040
# Iter 0650 | Total Loss 56.610699 | Sim 040
# Iter 0655 | Total Loss 55.535397 | Sim 040
# Iter 0660 | Total Loss 53.823460 | Sim 040
# Iter 0665 | Total Loss 52.022053 | Sim 040
# Iter 0670 | Total Loss 50.593853 | Sim 040
# Iter 0675 | Total Loss 50.741348 | Sim 040
# Iter 0680 | Total Loss 51.058701 | Sim 040
# Iter 0685 | Total Loss 52.881668 | Sim 040
# Iter 0690 | Total Loss 54.235859 | Sim 040
# Iter 0695 | Total Loss 54.417973 | Sim 040
# Iter 0700 | Total Loss 55.260548 | Sim 040
# Iter 0705 | Total Loss 56.432079 | Sim 040
# Iter 0710 | Total Loss 56.905140 | Sim 040
# Iter 0715 | Total Loss 55.584949 | Sim 040
# Iter 0720 | Total Loss 54.064865 | Sim 040
# Iter 0725 | Total Loss 52.993408 | Sim 040
# Iter 0730 | Total Loss 52.713078 | Sim 040
# Iter 0735 | Total Loss 52.890247 | Sim 040
# Iter 0740 | Total Loss 52.829388 | Sim 040
# Iter 0745 | Total Loss 53.419388 | Sim 040
# Iter 0750 | Total Loss 54.840977 | Sim 040
# Saved Model for Sim 040
#
# ODEFunc(
#   (net1): Sequential(
#     (0): Linear(in_features=160, out_features=100, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=100, out_features=100, bias=True)
#     (3): Tanh()
#     (4): Linear(in_features=100, out_features=160, bias=True)
#   )
# )
# Number of parameters: 42360
# Iter 0005 | Total Loss 482.155365 | Sim 047
# Iter 0010 | Total Loss 444.385223 | Sim 047
# Iter 0015 | Total Loss 404.619965 | Sim 047
# Iter 0020 | Total Loss 363.184601 | Sim 047
# Iter 0025 | Total Loss 321.503693 | Sim 047
# Iter 0030 | Total Loss 280.341492 | Sim 047
# Iter 0035 | Total Loss 239.841812 | Sim 047
# Iter 0040 | Total Loss 202.135864 | Sim 047
# Iter 0045 | Total Loss 168.251846 | Sim 047
# Iter 0050 | Total Loss 138.921051 | Sim 047
# Iter 0055 | Total Loss 113.154152 | Sim 047
# Iter 0060 | Total Loss 92.113083 | Sim 047
# Iter 0065 | Total Loss 75.382225 | Sim 047
# Iter 0070 | Total Loss 61.876884 | Sim 047
# Iter 0075 | Total Loss 51.666695 | Sim 047
# Iter 0080 | Total Loss 42.886101 | Sim 047
# Iter 0085 | Total Loss 36.480515 | Sim 047
# Iter 0090 | Total Loss 34.124256 | Sim 047
# Iter 0095 | Total Loss 33.929790 | Sim 047
# Iter 0100 | Total Loss 33.825539 | Sim 047
# Iter 0105 | Total Loss 32.753555 | Sim 047
# Iter 0110 | Total Loss 32.022141 | Sim 047
# Iter 0115 | Total Loss 31.898726 | Sim 047
# Iter 0120 | Total Loss 31.283785 | Sim 047
# Iter 0125 | Total Loss 32.921436 | Sim 047
# Iter 0130 | Total Loss 34.700325 | Sim 047
# Iter 0135 | Total Loss 33.364563 | Sim 047
# Iter 0140 | Total Loss 33.081478 | Sim 047
# Iter 0145 | Total Loss 31.498472 | Sim 047
# Iter 0150 | Total Loss 30.949400 | Sim 047
# Iter 0155 | Total Loss 30.946562 | Sim 047
# Iter 0160 | Total Loss 31.322075 | Sim 047
# Iter 0165 | Total Loss 32.284420 | Sim 047
# Iter 0170 | Total Loss 31.981562 | Sim 047
# Iter 0175 | Total Loss 30.282133 | Sim 047
# Iter 0180 | Total Loss 28.551657 | Sim 047
# Iter 0185 | Total Loss 27.851219 | Sim 047
# Iter 0190 | Total Loss 28.166208 | Sim 047
# Iter 0195 | Total Loss 29.640715 | Sim 047
# Iter 0200 | Total Loss 30.817739 | Sim 047
# Iter 0205 | Total Loss 31.229900 | Sim 047
# Iter 0210 | Total Loss 31.712387 | Sim 047
# Iter 0215 | Total Loss 29.617897 | Sim 047
# Iter 0220 | Total Loss 27.917116 | Sim 047
# Iter 0225 | Total Loss 27.413012 | Sim 047
# Iter 0230 | Total Loss 27.786566 | Sim 047
# Iter 0235 | Total Loss 30.276434 | Sim 047
# Iter 0240 | Total Loss 31.436480 | Sim 047
# Iter 0245 | Total Loss 31.376917 | Sim 047
# Iter 0250 | Total Loss 31.647621 | Sim 047
# Iter 0255 | Total Loss 31.678160 | Sim 047
# Iter 0260 | Total Loss 30.362572 | Sim 047
# Iter 0265 | Total Loss 29.146914 | Sim 047
# Iter 0270 | Total Loss 28.745703 | Sim 047
# Iter 0275 | Total Loss 29.274668 | Sim 047
# Iter 0280 | Total Loss 28.805182 | Sim 047
# Iter 0285 | Total Loss 28.766363 | Sim 047
# Iter 0290 | Total Loss 29.196690 | Sim 047
# Iter 0295 | Total Loss 30.242474 | Sim 047
# Iter 0300 | Total Loss 29.457926 | Sim 047
# Iter 0305 | Total Loss 28.520956 | Sim 047
# Iter 0310 | Total Loss 28.118313 | Sim 047
# Iter 0315 | Total Loss 29.186407 | Sim 047
# Iter 0320 | Total Loss 29.577652 | Sim 047
# Iter 0325 | Total Loss 30.291557 | Sim 047
# Iter 0330 | Total Loss 30.730402 | Sim 047
# Iter 0335 | Total Loss 31.707548 | Sim 047
# Iter 0340 | Total Loss 31.630648 | Sim 047
# Iter 0345 | Total Loss 31.290644 | Sim 047
# Iter 0350 | Total Loss 30.279856 | Sim 047
# Iter 0355 | Total Loss 29.198610 | Sim 047
# Iter 0360 | Total Loss 29.427279 | Sim 047
# Iter 0365 | Total Loss 29.519987 | Sim 047
# Iter 0370 | Total Loss 29.756489 | Sim 047
# Iter 0375 | Total Loss 29.315191 | Sim 047
# Iter 0380 | Total Loss 29.535833 | Sim 047
# Iter 0385 | Total Loss 29.588776 | Sim 047
# Iter 0390 | Total Loss 29.602140 | Sim 047
# Iter 0395 | Total Loss 29.940136 | Sim 047
# Iter 0400 | Total Loss 30.470301 | Sim 047
# Iter 0405 | Total Loss 32.007092 | Sim 047
# Iter 0410 | Total Loss 31.170151 | Sim 047
# Iter 0415 | Total Loss 31.910694 | Sim 047
# Iter 0420 | Total Loss 32.006245 | Sim 047
# Iter 0425 | Total Loss 30.206310 | Sim 047
# Iter 0430 | Total Loss 29.570520 | Sim 047
# Iter 0435 | Total Loss 29.932947 | Sim 047
# Iter 0440 | Total Loss 31.051682 | Sim 047
# Iter 0445 | Total Loss 31.983952 | Sim 047
# Iter 0450 | Total Loss 31.998096 | Sim 047
# Iter 0455 | Total Loss 33.049088 | Sim 047
# Iter 0460 | Total Loss 33.912930 | Sim 047
# Iter 0465 | Total Loss 34.163406 | Sim 047
# Iter 0470 | Total Loss 31.914804 | Sim 047
# Iter 0475 | Total Loss 31.430000 | Sim 047
# Iter 0480 | Total Loss 31.843338 | Sim 047
# Iter 0485 | Total Loss 31.625998 | Sim 047
# Iter 0490 | Total Loss 30.794558 | Sim 047
# Iter 0495 | Total Loss 29.466196 | Sim 047
# Iter 0500 | Total Loss 28.601631 | Sim 047
# Iter 0505 | Total Loss 29.097464 | Sim 047
# Iter 0510 | Total Loss 28.744181 | Sim 047
# Iter 0515 | Total Loss 29.351490 | Sim 047
# Iter 0520 | Total Loss 30.491682 | Sim 047
# Iter 0525 | Total Loss 31.511524 | Sim 047
# Iter 0530 | Total Loss 31.019592 | Sim 047
# Iter 0535 | Total Loss 31.573803 | Sim 047
# Iter 0540 | Total Loss 32.709652 | Sim 047
# Iter 0545 | Total Loss 33.830105 | Sim 047
# Iter 0550 | Total Loss 31.321022 | Sim 047
# Iter 0555 | Total Loss 30.023130 | Sim 047
# Iter 0560 | Total Loss 29.150898 | Sim 047
# Iter 0565 | Total Loss 29.540993 | Sim 047
# Iter 0570 | Total Loss 30.753582 | Sim 047
# Iter 0575 | Total Loss 31.102953 | Sim 047
# Iter 0580 | Total Loss 30.356241 | Sim 047
# Iter 0585 | Total Loss 30.124483 | Sim 047
# Iter 0590 | Total Loss 29.873497 | Sim 047
# Iter 0595 | Total Loss 29.373167 | Sim 047
# Iter 0600 | Total Loss 29.829363 | Sim 047
# Iter 0605 | Total Loss 30.545387 | Sim 047
# Iter 0610 | Total Loss 30.198879 | Sim 047
# Iter 0615 | Total Loss 31.515242 | Sim 047
# Iter 0620 | Total Loss 34.101406 | Sim 047
# Iter 0625 | Total Loss 32.691017 | Sim 047
# Iter 0630 | Total Loss 32.595718 | Sim 047
# Iter 0635 | Total Loss 31.475695 | Sim 047
# Iter 0640 | Total Loss 29.393156 | Sim 047
# Iter 0645 | Total Loss 29.288809 | Sim 047
# Iter 0650 | Total Loss 29.594055 | Sim 047
# Iter 0655 | Total Loss 30.074020 | Sim 047
# Iter 0660 | Total Loss 30.213167 | Sim 047
# Iter 0665 | Total Loss 30.094772 | Sim 047
# Iter 0670 | Total Loss 29.691643 | Sim 047
# Iter 0675 | Total Loss 28.323784 | Sim 047
# Iter 0680 | Total Loss 28.489275 | Sim 047
# Iter 0685 | Total Loss 29.383696 | Sim 047
# Iter 0690 | Total Loss 30.516241 | Sim 047
# Iter 0695 | Total Loss 30.199396 | Sim 047
# Iter 0700 | Total Loss 29.751070 | Sim 047
# Iter 0705 | Total Loss 28.360495 | Sim 047
# Iter 0710 | Total Loss 28.823978 | Sim 047
# Iter 0715 | Total Loss 30.063656 | Sim 047
# Iter 0720 | Total Loss 29.909569 | Sim 047
# Iter 0725 | Total Loss 30.608318 | Sim 047
# Iter 0730 | Total Loss 32.424809 | Sim 047
# Iter 0735 | Total Loss 32.449200 | Sim 047
# Iter 0740 | Total Loss 31.937988 | Sim 047
# Iter 0745 | Total Loss 31.625696 | Sim 047
# Iter 0750 | Total Loss 32.112091 | Sim 047
# Saved Model for Sim 047
#
# ODEFunc(
#   (net1): Sequential(
#     (0): Linear(in_features=160, out_features=100, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=100, out_features=100, bias=True)
#     (3): Tanh()
#     (4): Linear(in_features=100, out_features=160, bias=True)
#   )
# )
# Number of parameters: 42360
# Iter 0005 | Total Loss 295.125427 | Sim 052
# Iter 0010 | Total Loss 268.439789 | Sim 052
# Iter 0015 | Total Loss 241.110428 | Sim 052
# Iter 0020 | Total Loss 210.698761 | Sim 052
# Iter 0025 | Total Loss 180.819412 | Sim 052
# Iter 0030 | Total Loss 157.769989 | Sim 052
# Iter 0035 | Total Loss 137.846725 | Sim 052
# Iter 0040 | Total Loss 118.191666 | Sim 052
# Iter 0045 | Total Loss 100.256248 | Sim 052
# Iter 0050 | Total Loss 88.518410 | Sim 052
# Iter 0055 | Total Loss 80.863388 | Sim 052
# Iter 0060 | Total Loss 79.032181 | Sim 052
# Iter 0065 | Total Loss 79.315239 | Sim 052
# Iter 0070 | Total Loss 79.106773 | Sim 052
# Iter 0075 | Total Loss 80.764130 | Sim 052
# Iter 0080 | Total Loss 79.764084 | Sim 052
# Iter 0085 | Total Loss 78.035728 | Sim 052
# Iter 0090 | Total Loss 73.780304 | Sim 052
# Iter 0095 | Total Loss 69.601891 | Sim 052
# Iter 0100 | Total Loss 66.435410 | Sim 052
# Iter 0105 | Total Loss 65.927513 | Sim 052
# Iter 0110 | Total Loss 65.851898 | Sim 052
# Iter 0115 | Total Loss 65.545990 | Sim 052
# Iter 0120 | Total Loss 65.635323 | Sim 052
# Iter 0125 | Total Loss 64.422379 | Sim 052
# Iter 0130 | Total Loss 63.171375 | Sim 052
# Iter 0135 | Total Loss 62.643158 | Sim 052
# Iter 0140 | Total Loss 63.190861 | Sim 052
# Iter 0145 | Total Loss 63.576599 | Sim 052
# Iter 0150 | Total Loss 64.091721 | Sim 052
# Iter 0155 | Total Loss 64.804947 | Sim 052
# Iter 0160 | Total Loss 64.391212 | Sim 052
# Iter 0165 | Total Loss 64.089890 | Sim 052
# Iter 0170 | Total Loss 63.591377 | Sim 052
# Iter 0175 | Total Loss 63.995319 | Sim 052
# Iter 0180 | Total Loss 65.417114 | Sim 052
# Iter 0185 | Total Loss 66.388000 | Sim 052
# Iter 0190 | Total Loss 68.055511 | Sim 052
# Iter 0195 | Total Loss 69.190857 | Sim 052
# Iter 0200 | Total Loss 69.958160 | Sim 052
# Iter 0205 | Total Loss 69.240135 | Sim 052
# Iter 0210 | Total Loss 69.726227 | Sim 052
# Iter 0215 | Total Loss 70.553131 | Sim 052
# Iter 0220 | Total Loss 71.370415 | Sim 052
# Iter 0225 | Total Loss 72.807388 | Sim 052
# Iter 0230 | Total Loss 71.388412 | Sim 052
# Iter 0235 | Total Loss 71.189308 | Sim 052
# Iter 0240 | Total Loss 70.078812 | Sim 052
# Iter 0245 | Total Loss 67.650337 | Sim 052
# Iter 0250 | Total Loss 66.554482 | Sim 052
# Iter 0255 | Total Loss 66.581207 | Sim 052
# Iter 0260 | Total Loss 67.076874 | Sim 052
# Iter 0265 | Total Loss 70.528610 | Sim 052
# Iter 0270 | Total Loss 71.758011 | Sim 052
# Iter 0275 | Total Loss 70.488235 | Sim 052
# Iter 0280 | Total Loss 67.791389 | Sim 052
# Iter 0285 | Total Loss 63.436089 | Sim 052
# Iter 0290 | Total Loss 60.380009 | Sim 052
# Iter 0295 | Total Loss 60.064106 | Sim 052
# Iter 0300 | Total Loss 60.959248 | Sim 052
# Iter 0305 | Total Loss 62.138180 | Sim 052
# Iter 0310 | Total Loss 63.053528 | Sim 052
# Iter 0315 | Total Loss 65.199646 | Sim 052
# Iter 0320 | Total Loss 67.776543 | Sim 052
# Iter 0325 | Total Loss 69.274139 | Sim 052
# Iter 0330 | Total Loss 70.589302 | Sim 052
# Iter 0335 | Total Loss 70.274757 | Sim 052
# Iter 0340 | Total Loss 70.036842 | Sim 052
# Iter 0345 | Total Loss 70.965240 | Sim 052
# Iter 0350 | Total Loss 71.591721 | Sim 052
# Iter 0355 | Total Loss 70.458160 | Sim 052
# Iter 0360 | Total Loss 69.173729 | Sim 052
# Iter 0365 | Total Loss 68.185394 | Sim 052
# Iter 0370 | Total Loss 67.813942 | Sim 052
# Iter 0375 | Total Loss 66.020905 | Sim 052
# Iter 0380 | Total Loss 64.300896 | Sim 052
# Iter 0385 | Total Loss 64.134544 | Sim 052
# Iter 0390 | Total Loss 64.060928 | Sim 052
# Iter 0395 | Total Loss 64.399757 | Sim 052
# Iter 0400 | Total Loss 65.695984 | Sim 052
# Iter 0405 | Total Loss 67.203888 | Sim 052
# Iter 0410 | Total Loss 68.540062 | Sim 052
# Iter 0415 | Total Loss 69.043358 | Sim 052
# Iter 0420 | Total Loss 67.998764 | Sim 052
# Iter 0425 | Total Loss 67.097206 | Sim 052
# Iter 0430 | Total Loss 67.210258 | Sim 052
# Iter 0435 | Total Loss 67.233513 | Sim 052
# Iter 0440 | Total Loss 67.015427 | Sim 052
# Iter 0445 | Total Loss 66.704292 | Sim 052
# Iter 0450 | Total Loss 66.751236 | Sim 052
# Iter 0455 | Total Loss 68.495903 | Sim 052
# Iter 0460 | Total Loss 70.774734 | Sim 052
# Iter 0465 | Total Loss 73.350739 | Sim 052
# Iter 0470 | Total Loss 73.736267 | Sim 052
# Iter 0475 | Total Loss 72.682678 | Sim 052
# Iter 0480 | Total Loss 69.593353 | Sim 052
# Iter 0485 | Total Loss 68.339561 | Sim 052
# Iter 0490 | Total Loss 68.252251 | Sim 052
# Iter 0495 | Total Loss 70.347038 | Sim 052
# Iter 0500 | Total Loss 73.168571 | Sim 052
# Iter 0505 | Total Loss 75.537827 | Sim 052
# Iter 0510 | Total Loss 77.839928 | Sim 052
# Iter 0515 | Total Loss 76.972115 | Sim 052
# Iter 0520 | Total Loss 76.177475 | Sim 052
# Iter 0525 | Total Loss 73.768837 | Sim 052
# Iter 0530 | Total Loss 71.660805 | Sim 052
# Iter 0535 | Total Loss 69.824318 | Sim 052
# Iter 0540 | Total Loss 69.660759 | Sim 052
# Iter 0545 | Total Loss 69.493073 | Sim 052
# Iter 0550 | Total Loss 69.257523 | Sim 052
# Iter 0555 | Total Loss 67.767014 | Sim 052
# Iter 0560 | Total Loss 66.139679 | Sim 052
# Iter 0565 | Total Loss 66.245010 | Sim 052
# Iter 0570 | Total Loss 68.080704 | Sim 052
# Iter 0575 | Total Loss 69.726349 | Sim 052
# Iter 0580 | Total Loss 70.115303 | Sim 052
# Iter 0585 | Total Loss 72.331322 | Sim 052
# Iter 0590 | Total Loss 70.954445 | Sim 052
# Iter 0595 | Total Loss 69.854042 | Sim 052
# Iter 0600 | Total Loss 68.130470 | Sim 052
# Iter 0605 | Total Loss 67.786125 | Sim 052
# Iter 0610 | Total Loss 67.930092 | Sim 052
# Iter 0615 | Total Loss 67.637207 | Sim 052
# Iter 0620 | Total Loss 66.280487 | Sim 052
# Iter 0625 | Total Loss 64.060478 | Sim 052
# Iter 0630 | Total Loss 62.461002 | Sim 052
# Iter 0635 | Total Loss 62.386608 | Sim 052
# Iter 0640 | Total Loss 67.341690 | Sim 052
# Iter 0645 | Total Loss 69.542145 | Sim 052
# Iter 0650 | Total Loss 67.552567 | Sim 052
# Iter 0655 | Total Loss 66.461731 | Sim 052
# Iter 0660 | Total Loss 66.502235 | Sim 052
# Iter 0665 | Total Loss 68.738892 | Sim 052
# Iter 0670 | Total Loss 69.180046 | Sim 052
# Iter 0675 | Total Loss 70.760376 | Sim 052
# Iter 0680 | Total Loss 71.982422 | Sim 052
# Iter 0685 | Total Loss 71.834991 | Sim 052
# Iter 0690 | Total Loss 69.992622 | Sim 052
# Iter 0695 | Total Loss 66.918068 | Sim 052
# Iter 0700 | Total Loss 65.794556 | Sim 052
# Iter 0705 | Total Loss 65.514061 | Sim 052
# Iter 0710 | Total Loss 63.406940 | Sim 052
# Iter 0715 | Total Loss 63.236271 | Sim 052
# Iter 0720 | Total Loss 63.568886 | Sim 052
# Iter 0725 | Total Loss 62.984989 | Sim 052
# Iter 0730 | Total Loss 62.792370 | Sim 052
# Iter 0735 | Total Loss 63.063656 | Sim 052
# Iter 0740 | Total Loss 63.886158 | Sim 052
# Iter 0745 | Total Loss 66.311607 | Sim 052
# Iter 0750 | Total Loss 68.276352 | Sim 052
# Saved Model for Sim 052
#
# ODEFunc(
#   (net1): Sequential(
#     (0): Linear(in_features=160, out_features=100, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=100, out_features=100, bias=True)
#     (3): Tanh()
#     (4): Linear(in_features=100, out_features=160, bias=True)
#   )
# )
# Number of parameters: 42360
# Iter 0005 | Total Loss 934.462219 | Sim 053
# Iter 0010 | Total Loss 899.398315 | Sim 053
# Iter 0015 | Total Loss 860.709473 | Sim 053
# Iter 0020 | Total Loss 819.169495 | Sim 053
# Iter 0025 | Total Loss 776.389954 | Sim 053
# Iter 0030 | Total Loss 733.521667 | Sim 053
# Iter 0035 | Total Loss 690.508972 | Sim 053
# Iter 0040 | Total Loss 647.917480 | Sim 053
# Iter 0045 | Total Loss 605.932190 | Sim 053
# Iter 0050 | Total Loss 565.023560 | Sim 053
# Iter 0055 | Total Loss 525.401489 | Sim 053
# Iter 0060 | Total Loss 486.665161 | Sim 053
# Iter 0065 | Total Loss 449.656830 | Sim 053
# Iter 0070 | Total Loss 414.120697 | Sim 053
# Iter 0075 | Total Loss 379.701355 | Sim 053
# Iter 0080 | Total Loss 347.059235 | Sim 053
# Iter 0085 | Total Loss 317.042419 | Sim 053
# Iter 0090 | Total Loss 288.158020 | Sim 053
# Iter 0095 | Total Loss 260.540039 | Sim 053
# Iter 0100 | Total Loss 235.504410 | Sim 053
# Iter 0105 | Total Loss 213.152710 | Sim 053
# Iter 0110 | Total Loss 193.269150 | Sim 053
# Iter 0115 | Total Loss 177.206131 | Sim 053
# Iter 0120 | Total Loss 162.274628 | Sim 053
# Iter 0125 | Total Loss 149.619110 | Sim 053
# Iter 0130 | Total Loss 140.355072 | Sim 053
# Iter 0135 | Total Loss 132.458023 | Sim 053
# Iter 0140 | Total Loss 126.313042 | Sim 053
# Iter 0145 | Total Loss 120.972153 | Sim 053
# Iter 0150 | Total Loss 116.402153 | Sim 053
# Iter 0155 | Total Loss 113.141281 | Sim 053
# Iter 0160 | Total Loss 111.026909 | Sim 053
# Iter 0165 | Total Loss 109.078606 | Sim 053
# Iter 0170 | Total Loss 106.832588 | Sim 053
# Iter 0175 | Total Loss 104.652008 | Sim 053
# Iter 0180 | Total Loss 102.917801 | Sim 053
# Iter 0185 | Total Loss 101.409744 | Sim 053
# Iter 0190 | Total Loss 100.824394 | Sim 053
# Iter 0195 | Total Loss 100.615036 | Sim 053
# Iter 0200 | Total Loss 100.296303 | Sim 053
# Iter 0205 | Total Loss 99.356033 | Sim 053
# Iter 0210 | Total Loss 98.590683 | Sim 053
# Iter 0215 | Total Loss 98.210793 | Sim 053
# Iter 0220 | Total Loss 97.904099 | Sim 053
# Iter 0225 | Total Loss 97.633156 | Sim 053
# Iter 0230 | Total Loss 97.178360 | Sim 053
# Iter 0235 | Total Loss 97.070816 | Sim 053
# Iter 0240 | Total Loss 97.283920 | Sim 053
# Iter 0245 | Total Loss 97.376396 | Sim 053
# Iter 0250 | Total Loss 97.189224 | Sim 053
# Iter 0255 | Total Loss 97.338509 | Sim 053
# Iter 0260 | Total Loss 97.276283 | Sim 053
# Iter 0265 | Total Loss 97.414330 | Sim 053
# Iter 0270 | Total Loss 97.847740 | Sim 053
# Iter 0275 | Total Loss 98.370537 | Sim 053
# Iter 0280 | Total Loss 99.477142 | Sim 053
# Iter 0285 | Total Loss 100.073143 | Sim 053
# Iter 0290 | Total Loss 99.892303 | Sim 053
# Iter 0295 | Total Loss 99.183434 | Sim 053
# Iter 0300 | Total Loss 98.737358 | Sim 053
# Iter 0305 | Total Loss 98.508232 | Sim 053
# Iter 0310 | Total Loss 98.623711 | Sim 053
# Iter 0315 | Total Loss 98.470268 | Sim 053
# Iter 0320 | Total Loss 97.967285 | Sim 053
# Iter 0325 | Total Loss 97.704941 | Sim 053
# Iter 0330 | Total Loss 97.723068 | Sim 053
# Iter 0335 | Total Loss 97.707939 | Sim 053
# Iter 0340 | Total Loss 97.675583 | Sim 053
# Iter 0345 | Total Loss 97.619926 | Sim 053
# Iter 0350 | Total Loss 97.587708 | Sim 053
# Iter 0355 | Total Loss 97.600998 | Sim 053
# Iter 0360 | Total Loss 97.544312 | Sim 053
# Iter 0365 | Total Loss 97.397278 | Sim 053
# Iter 0370 | Total Loss 97.262001 | Sim 053
# Iter 0375 | Total Loss 97.088310 | Sim 053
# Iter 0380 | Total Loss 97.204926 | Sim 053
# Iter 0385 | Total Loss 97.384659 | Sim 053
# Iter 0390 | Total Loss 97.339745 | Sim 053
# Iter 0395 | Total Loss 97.691086 | Sim 053
# Iter 0400 | Total Loss 97.839531 | Sim 053
# Iter 0405 | Total Loss 98.152809 | Sim 053
# Iter 0410 | Total Loss 98.285728 | Sim 053
# Iter 0415 | Total Loss 98.558418 | Sim 053
# Iter 0420 | Total Loss 98.909599 | Sim 053
# Iter 0425 | Total Loss 100.264404 | Sim 053
# Iter 0430 | Total Loss 100.791290 | Sim 053
# Iter 0435 | Total Loss 100.992767 | Sim 053
# Iter 0440 | Total Loss 100.143387 | Sim 053
# Iter 0445 | Total Loss 100.102142 | Sim 053
# Iter 0450 | Total Loss 101.295685 | Sim 053
# Iter 0455 | Total Loss 101.719376 | Sim 053
# Iter 0460 | Total Loss 101.114731 | Sim 053
# Iter 0465 | Total Loss 100.068375 | Sim 053
# Iter 0470 | Total Loss 99.754280 | Sim 053
# Iter 0475 | Total Loss 99.124748 | Sim 053
# Iter 0480 | Total Loss 98.645653 | Sim 053
# Iter 0485 | Total Loss 99.124634 | Sim 053
# Iter 0490 | Total Loss 99.380821 | Sim 053
# Iter 0495 | Total Loss 99.512436 | Sim 053
# Iter 0500 | Total Loss 99.134132 | Sim 053
# Iter 0505 | Total Loss 98.911545 | Sim 053
# Iter 0510 | Total Loss 99.120285 | Sim 053
# Iter 0515 | Total Loss 99.074303 | Sim 053
# Iter 0520 | Total Loss 98.957771 | Sim 053
# Iter 0525 | Total Loss 98.333862 | Sim 053
# Iter 0530 | Total Loss 98.249977 | Sim 053
# Iter 0535 | Total Loss 97.827522 | Sim 053
# Iter 0540 | Total Loss 97.285599 | Sim 053
# Iter 0545 | Total Loss 97.915596 | Sim 053
# Iter 0550 | Total Loss 98.811218 | Sim 053
# Iter 0555 | Total Loss 100.514839 | Sim 053
# Iter 0560 | Total Loss 102.283096 | Sim 053
# Iter 0565 | Total Loss 102.410858 | Sim 053
# Iter 0570 | Total Loss 103.421608 | Sim 053
# Iter 0575 | Total Loss 103.688698 | Sim 053
# Iter 0580 | Total Loss 104.891373 | Sim 053
# Iter 0585 | Total Loss 105.690277 | Sim 053
# Iter 0590 | Total Loss 104.394676 | Sim 053
# Iter 0595 | Total Loss 101.383087 | Sim 053
# Iter 0600 | Total Loss 100.372795 | Sim 053
# Iter 0605 | Total Loss 99.707916 | Sim 053
# Iter 0610 | Total Loss 99.347420 | Sim 053
# Iter 0615 | Total Loss 98.706421 | Sim 053
# Iter 0620 | Total Loss 97.975113 | Sim 053
# Iter 0625 | Total Loss 98.209351 | Sim 053
# Iter 0630 | Total Loss 99.206497 | Sim 053
# Iter 0635 | Total Loss 99.573105 | Sim 053
# Iter 0640 | Total Loss 98.542191 | Sim 053
# Iter 0645 | Total Loss 98.575623 | Sim 053
# Iter 0650 | Total Loss 99.471260 | Sim 053
# Iter 0655 | Total Loss 99.935631 | Sim 053
# Iter 0660 | Total Loss 99.230827 | Sim 053
# Iter 0665 | Total Loss 99.109840 | Sim 053
# Iter 0670 | Total Loss 99.782753 | Sim 053
# Iter 0675 | Total Loss 99.227966 | Sim 053
# Iter 0680 | Total Loss 99.120872 | Sim 053
# Iter 0685 | Total Loss 98.643608 | Sim 053
# Iter 0690 | Total Loss 99.289902 | Sim 053
# Iter 0695 | Total Loss 100.443604 | Sim 053
# Iter 0700 | Total Loss 101.595482 | Sim 053
# Iter 0705 | Total Loss 101.549301 | Sim 053
# Iter 0710 | Total Loss 100.170433 | Sim 053
# Iter 0715 | Total Loss 98.751053 | Sim 053
# Iter 0720 | Total Loss 97.436203 | Sim 053
# Iter 0725 | Total Loss 97.023811 | Sim 053
# Iter 0730 | Total Loss 97.176605 | Sim 053
# Iter 0735 | Total Loss 98.106110 | Sim 053
# Iter 0740 | Total Loss 98.213249 | Sim 053
# Iter 0745 | Total Loss 97.349869 | Sim 053
# Iter 0750 | Total Loss 97.054092 | Sim 053
# Saved Model for Sim 053
#
# ODEFunc(
#   (net1): Sequential(
#     (0): Linear(in_features=160, out_features=100, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=100, out_features=100, bias=True)
#     (3): Tanh()
#     (4): Linear(in_features=100, out_features=160, bias=True)
#   )
# )
# Number of parameters: 42360
# Iter 0005 | Total Loss 1077.467041 | Sim 061
# Iter 0010 | Total Loss 1038.744995 | Sim 061
# Iter 0015 | Total Loss 997.192566 | Sim 061
# Iter 0020 | Total Loss 954.130981 | Sim 061
# Iter 0025 | Total Loss 910.478699 | Sim 061
# Iter 0030 | Total Loss 866.213623 | Sim 061
# Iter 0035 | Total Loss 821.750183 | Sim 061
# Iter 0040 | Total Loss 777.460754 | Sim 061
# Iter 0045 | Total Loss 733.473022 | Sim 061
# Iter 0050 | Total Loss 689.990112 | Sim 061
# Iter 0055 | Total Loss 646.960327 | Sim 061
# Iter 0060 | Total Loss 604.323914 | Sim 061
# Iter 0065 | Total Loss 562.213379 | Sim 061
# Iter 0070 | Total Loss 520.521912 | Sim 061
# Iter 0075 | Total Loss 479.708435 | Sim 061
# Iter 0080 | Total Loss 439.577728 | Sim 061
# Iter 0085 | Total Loss 399.897736 | Sim 061
# Iter 0090 | Total Loss 361.407990 | Sim 061
# Iter 0095 | Total Loss 324.342255 | Sim 061
# Iter 0100 | Total Loss 289.222717 | Sim 061
# Iter 0105 | Total Loss 255.659134 | Sim 061
# Iter 0110 | Total Loss 223.076431 | Sim 061
# Iter 0115 | Total Loss 192.376602 | Sim 061
# Iter 0120 | Total Loss 164.460983 | Sim 061
# Iter 0125 | Total Loss 138.716354 | Sim 061
# Iter 0130 | Total Loss 116.502136 | Sim 061
# Iter 0135 | Total Loss 97.911865 | Sim 061
# Iter 0140 | Total Loss 81.407112 | Sim 061
# Iter 0145 | Total Loss 67.475327 | Sim 061
# Iter 0150 | Total Loss 55.855648 | Sim 061
# Iter 0155 | Total Loss 46.699902 | Sim 061
# Iter 0160 | Total Loss 39.713177 | Sim 061
# Iter 0165 | Total Loss 35.130287 | Sim 061
# Iter 0170 | Total Loss 30.838909 | Sim 061
# Iter 0175 | Total Loss 26.882687 | Sim 061
# Iter 0180 | Total Loss 25.073988 | Sim 061
# Iter 0185 | Total Loss 24.108009 | Sim 061
# Iter 0190 | Total Loss 23.786139 | Sim 061
# Iter 0195 | Total Loss 24.149015 | Sim 061
# Iter 0200 | Total Loss 23.961901 | Sim 061
# Iter 0205 | Total Loss 23.428366 | Sim 061
# Iter 0210 | Total Loss 22.958117 | Sim 061
# Iter 0215 | Total Loss 22.501362 | Sim 061
# Iter 0220 | Total Loss 22.566025 | Sim 061
# Iter 0225 | Total Loss 22.563906 | Sim 061
# Iter 0230 | Total Loss 22.943617 | Sim 061
# Iter 0235 | Total Loss 23.526302 | Sim 061
# Iter 0240 | Total Loss 24.037809 | Sim 061
# Iter 0245 | Total Loss 24.248833 | Sim 061
# Iter 0250 | Total Loss 23.982815 | Sim 061
# Iter 0255 | Total Loss 24.788454 | Sim 061
# Iter 0260 | Total Loss 26.497774 | Sim 061
# Iter 0265 | Total Loss 27.630291 | Sim 061
# Iter 0270 | Total Loss 26.619371 | Sim 061
# Iter 0275 | Total Loss 26.020334 | Sim 061
# Iter 0280 | Total Loss 26.227715 | Sim 061
# Iter 0285 | Total Loss 26.822363 | Sim 061
# Iter 0290 | Total Loss 27.940533 | Sim 061
# Iter 0295 | Total Loss 29.484886 | Sim 061
# Iter 0300 | Total Loss 28.862247 | Sim 061
# Iter 0305 | Total Loss 27.330795 | Sim 061
# Iter 0310 | Total Loss 25.153658 | Sim 061
# Iter 0315 | Total Loss 24.049612 | Sim 061
# Iter 0320 | Total Loss 23.836069 | Sim 061
# Iter 0325 | Total Loss 23.848492 | Sim 061
# Iter 0330 | Total Loss 23.418949 | Sim 061
# Iter 0335 | Total Loss 22.270184 | Sim 061
# Iter 0340 | Total Loss 21.922451 | Sim 061
# Iter 0345 | Total Loss 22.274603 | Sim 061
# Iter 0350 | Total Loss 22.499983 | Sim 061
# Iter 0355 | Total Loss 22.540768 | Sim 061
# Iter 0360 | Total Loss 22.716383 | Sim 061
# Iter 0365 | Total Loss 22.816328 | Sim 061
# Iter 0370 | Total Loss 22.945307 | Sim 061
# Iter 0375 | Total Loss 23.716742 | Sim 061
# Iter 0380 | Total Loss 24.005360 | Sim 061
# Iter 0385 | Total Loss 23.316250 | Sim 061
# Iter 0390 | Total Loss 24.262417 | Sim 061
# Iter 0395 | Total Loss 24.588945 | Sim 061
# Iter 0400 | Total Loss 23.992931 | Sim 061
# Iter 0405 | Total Loss 23.885075 | Sim 061
# Iter 0410 | Total Loss 24.203070 | Sim 061
# Iter 0415 | Total Loss 24.029652 | Sim 061
# Iter 0420 | Total Loss 24.416098 | Sim 061
# Iter 0425 | Total Loss 24.990929 | Sim 061
# Iter 0430 | Total Loss 23.798283 | Sim 061
# Iter 0435 | Total Loss 23.468939 | Sim 061
# Iter 0440 | Total Loss 23.380823 | Sim 061
# Iter 0445 | Total Loss 23.546576 | Sim 061
# Iter 0450 | Total Loss 23.527967 | Sim 061
# Iter 0455 | Total Loss 24.696083 | Sim 061
# Iter 0460 | Total Loss 25.770353 | Sim 061
# Iter 0465 | Total Loss 25.894741 | Sim 061
# Iter 0470 | Total Loss 24.917086 | Sim 061
# Iter 0475 | Total Loss 22.832203 | Sim 061
# Iter 0480 | Total Loss 23.494238 | Sim 061
# Iter 0485 | Total Loss 24.832422 | Sim 061
# Iter 0490 | Total Loss 24.204227 | Sim 061
# Iter 0495 | Total Loss 24.381973 | Sim 061
# Iter 0500 | Total Loss 24.191843 | Sim 061
# Iter 0505 | Total Loss 24.025764 | Sim 061
# Iter 0510 | Total Loss 24.663347 | Sim 061
# Iter 0515 | Total Loss 26.315947 | Sim 061
# Iter 0520 | Total Loss 27.247366 | Sim 061
# Iter 0525 | Total Loss 26.104263 | Sim 061
# Iter 0530 | Total Loss 23.757305 | Sim 061
# Iter 0535 | Total Loss 23.208494 | Sim 061
# Iter 0540 | Total Loss 24.037050 | Sim 061
# Iter 0545 | Total Loss 25.018372 | Sim 061
# Iter 0550 | Total Loss 24.125973 | Sim 061
# Iter 0555 | Total Loss 23.134159 | Sim 061
# Iter 0560 | Total Loss 23.478655 | Sim 061
# Iter 0565 | Total Loss 24.286764 | Sim 061
# Iter 0570 | Total Loss 25.009848 | Sim 061
# Iter 0575 | Total Loss 25.000841 | Sim 061
# Iter 0580 | Total Loss 24.109177 | Sim 061
# Iter 0585 | Total Loss 23.556566 | Sim 061
# Iter 0590 | Total Loss 23.119001 | Sim 061
# Iter 0595 | Total Loss 23.801390 | Sim 061
# Iter 0600 | Total Loss 24.179182 | Sim 061
# Iter 0605 | Total Loss 23.432518 | Sim 061
# Iter 0610 | Total Loss 22.522264 | Sim 061
# Iter 0615 | Total Loss 22.523169 | Sim 061
# Iter 0620 | Total Loss 23.116156 | Sim 061
# Iter 0625 | Total Loss 23.619652 | Sim 061
# Iter 0630 | Total Loss 24.130301 | Sim 061
# Iter 0635 | Total Loss 24.879723 | Sim 061
# Iter 0640 | Total Loss 24.288414 | Sim 061
# Iter 0645 | Total Loss 23.697453 | Sim 061
# Iter 0650 | Total Loss 23.984005 | Sim 061
# Iter 0655 | Total Loss 24.108902 | Sim 061
# Iter 0660 | Total Loss 25.402729 | Sim 061
# Iter 0665 | Total Loss 27.303415 | Sim 061
# Iter 0670 | Total Loss 26.217083 | Sim 061
# Iter 0675 | Total Loss 24.515207 | Sim 061
# Iter 0680 | Total Loss 25.931404 | Sim 061
# Iter 0685 | Total Loss 25.109148 | Sim 061
# Iter 0690 | Total Loss 25.168949 | Sim 061
# ...
# Iter 0515 | Total Loss 63.015526 | Sim 095
# Iter 0520 | Total Loss 61.596268 | Sim 095
# Iter 0525 | Total Loss 62.475460 | Sim 095
# Iter 0530 | Total Loss 64.725609 | Sim 095
# Iter 0535 | Total Loss 65.678665 | Sim 095
# Iter 0540 | Total Loss 65.378807 | Sim 095
# Iter 0545 | Total Loss 65.042397 | Sim 095
# Iter 0550 | Total Loss 63.215832 | Sim 095
# Iter 0555 | Total Loss 62.794579 | Sim 095
# Iter 0560 | Total Loss 62.210957 | Sim 095
# Iter 0565 | Total Loss 62.836239 | Sim 095
# Iter 0570 | Total Loss 62.182301 | Sim 095
# Iter 0575 | Total Loss 62.445751 | Sim 095
# Iter 0580 | Total Loss 61.886787 | Sim 095
# Iter 0585 | Total Loss 61.335209 | Sim 095
# Iter 0590 | Total Loss 62.336796 | Sim 095
# Iter 0595 | Total Loss 62.712463 | Sim 095
# Iter 0600 | Total Loss 61.391064 | Sim 095
# Iter 0605 | Total Loss 61.414501 | Sim 095
# Iter 0610 | Total Loss 65.254692 | Sim 095
# Iter 0615 | Total Loss 70.775169 | Sim 095
# Iter 0620 | Total Loss 73.511551 | Sim 095
# Iter 0625 | Total Loss 72.471909 | Sim 095
# Iter 0630 | Total Loss 74.143417 | Sim 095
# Iter 0635 | Total Loss 74.757446 | Sim 095
# Iter 0640 | Total Loss 73.987099 | Sim 095
# Iter 0645 | Total Loss 72.022308 | Sim 095
# Iter 0650 | Total Loss 71.787949 | Sim 095
# Iter 0655 | Total Loss 71.110474 | Sim 095
# Iter 0660 | Total Loss 70.425941 | Sim 095
# Iter 0665 | Total Loss 70.908386 | Sim 095
# Iter 0670 | Total Loss 68.762672 | Sim 095
# Iter 0675 | Total Loss 64.247787 | Sim 095
# Iter 0680 | Total Loss 62.993549 | Sim 095
# Iter 0685 | Total Loss 61.884819 | Sim 095
# Iter 0690 | Total Loss 62.775520 | Sim 095
# Iter 0695 | Total Loss 63.265694 | Sim 095
# Iter 0700 | Total Loss 64.778191 | Sim 095
# Iter 0705 | Total Loss 68.673790 | Sim 095
# Iter 0710 | Total Loss 67.499199 | Sim 095
# Iter 0715 | Total Loss 63.908325 | Sim 095
# Iter 0720 | Total Loss 62.979202 | Sim 095
# Iter 0725 | Total Loss 63.111786 | Sim 095
# Iter 0730 | Total Loss 62.998287 | Sim 095
# Iter 0735 | Total Loss 65.128738 | Sim 095
# Iter 0740 | Total Loss 67.413277 | Sim 095
# Iter 0745 | Total Loss 69.364174 | Sim 095
# Iter 0750 | Total Loss 69.729958 | Sim 095
# Saved Model for Sim 095
#
# ODEFunc(
#   (net1): Sequential(
#     (0): Linear(in_features=160, out_features=100, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=100, out_features=100, bias=True)
#     (3): Tanh()
#     (4): Linear(in_features=100, out_features=160, bias=True)
#   )
# )
# Number of parameters: 42360
# Iter 0005 | Total Loss 730.802856 | Sim 098
# Iter 0010 | Total Loss 694.279480 | Sim 098
# Iter 0015 | Total Loss 654.891907 | Sim 098
# Iter 0020 | Total Loss 613.518677 | Sim 098
# Iter 0025 | Total Loss 570.598083 | Sim 098
# Iter 0030 | Total Loss 527.165955 | Sim 098
# Iter 0035 | Total Loss 483.741638 | Sim 098
# Iter 0040 | Total Loss 440.203461 | Sim 098
# Iter 0045 | Total Loss 396.835876 | Sim 098
# Iter 0050 | Total Loss 353.953491 | Sim 098
# Iter 0055 | Total Loss 312.311646 | Sim 098
# Iter 0060 | Total Loss 272.101196 | Sim 098
# Iter 0065 | Total Loss 233.370605 | Sim 098
# Iter 0070 | Total Loss 197.505264 | Sim 098
# Iter 0075 | Total Loss 163.799332 | Sim 098
# Iter 0080 | Total Loss 133.105835 | Sim 098
# Iter 0085 | Total Loss 107.573990 | Sim 098
# Iter 0090 | Total Loss 85.787933 | Sim 098
# Iter 0095 | Total Loss 67.510559 | Sim 098
# Iter 0100 | Total Loss 52.003357 | Sim 098
# Iter 0105 | Total Loss 39.510315 | Sim 098
# Iter 0110 | Total Loss 30.595797 | Sim 098
# Iter 0115 | Total Loss 24.339989 | Sim 098
# Iter 0120 | Total Loss 20.619366 | Sim 098
# Iter 0125 | Total Loss 18.487450 | Sim 098
# Iter 0130 | Total Loss 17.437950 | Sim 098
# Iter 0135 | Total Loss 16.939255 | Sim 098
# Iter 0140 | Total Loss 17.188107 | Sim 098
# Iter 0145 | Total Loss 17.365417 | Sim 098
# Iter 0150 | Total Loss 16.104317 | Sim 098
# Iter 0155 | Total Loss 15.484114 | Sim 098
# Iter 0160 | Total Loss 15.479686 | Sim 098
# Iter 0165 | Total Loss 15.610497 | Sim 098
# Iter 0170 | Total Loss 16.059893 | Sim 098
# Iter 0175 | Total Loss 16.042530 | Sim 098
# Iter 0180 | Total Loss 16.296808 | Sim 098
# Iter 0185 | Total Loss 16.248177 | Sim 098
# Iter 0190 | Total Loss 16.682323 | Sim 098
# Iter 0195 | Total Loss 16.626959 | Sim 098
# Iter 0200 | Total Loss 17.158092 | Sim 098
# Iter 0205 | Total Loss 16.946320 | Sim 098
# Iter 0210 | Total Loss 16.770346 | Sim 098
# Iter 0215 | Total Loss 16.265648 | Sim 098
# Iter 0220 | Total Loss 15.711319 | Sim 098
# Iter 0225 | Total Loss 16.247305 | Sim 098
# Iter 0230 | Total Loss 16.238043 | Sim 098
# Iter 0235 | Total Loss 15.975495 | Sim 098
# Iter 0240 | Total Loss 18.040113 | Sim 098
# Iter 0245 | Total Loss 21.439392 | Sim 098
# Iter 0250 | Total Loss 22.178457 | Sim 098
# Iter 0255 | Total Loss 20.264078 | Sim 098
# Iter 0260 | Total Loss 19.002275 | Sim 098
# Iter 0265 | Total Loss 18.193979 | Sim 098
# Iter 0270 | Total Loss 17.268194 | Sim 098
# Iter 0275 | Total Loss 16.441423 | Sim 098
# Iter 0280 | Total Loss 15.854786 | Sim 098
# Iter 0285 | Total Loss 15.624676 | Sim 098
# Iter 0290 | Total Loss 15.643471 | Sim 098
# Iter 0295 | Total Loss 15.938479 | Sim 098
# Iter 0300 | Total Loss 16.100674 | Sim 098
# Iter 0305 | Total Loss 17.257879 | Sim 098
# Iter 0310 | Total Loss 17.742586 | Sim 098
# Iter 0315 | Total Loss 17.104891 | Sim 098
# Iter 0320 | Total Loss 16.779484 | Sim 098
# Iter 0325 | Total Loss 16.171860 | Sim 098
# Iter 0330 | Total Loss 15.831483 | Sim 098
# Iter 0335 | Total Loss 16.072447 | Sim 098
# Iter 0340 | Total Loss 16.800081 | Sim 098
# Iter 0345 | Total Loss 19.222445 | Sim 098
# Iter 0350 | Total Loss 20.420353 | Sim 098
# Iter 0355 | Total Loss 18.833883 | Sim 098
# Iter 0360 | Total Loss 18.592648 | Sim 098
# Iter 0365 | Total Loss 18.019323 | Sim 098
# Iter 0370 | Total Loss 16.267368 | Sim 098
# Iter 0375 | Total Loss 15.806523 | Sim 098
# Iter 0380 | Total Loss 16.062862 | Sim 098
# Iter 0385 | Total Loss 16.300228 | Sim 098
# Iter 0390 | Total Loss 15.630637 | Sim 098
# Iter 0395 | Total Loss 15.576831 | Sim 098
# Iter 0400 | Total Loss 15.500348 | Sim 098
# Iter 0405 | Total Loss 15.754939 | Sim 098
# Iter 0410 | Total Loss 16.844282 | Sim 098
# Iter 0415 | Total Loss 17.087597 | Sim 098
# Iter 0420 | Total Loss 16.787811 | Sim 098
# Iter 0425 | Total Loss 15.908052 | Sim 098
# Iter 0430 | Total Loss 15.780615 | Sim 098
# Iter 0435 | Total Loss 16.530624 | Sim 098
# Iter 0440 | Total Loss 17.563797 | Sim 098
# Iter 0445 | Total Loss 19.139027 | Sim 098
# Iter 0450 | Total Loss 20.921848 | Sim 098
# Iter 0455 | Total Loss 20.384344 | Sim 098
# Iter 0460 | Total Loss 17.441973 | Sim 098
# Iter 0465 | Total Loss 16.416035 | Sim 098
# Iter 0470 | Total Loss 15.746858 | Sim 098
# Iter 0475 | Total Loss 15.494221 | Sim 098
# Iter 0480 | Total Loss 16.783995 | Sim 098
# Iter 0485 | Total Loss 17.991026 | Sim 098
# Iter 0490 | Total Loss 17.044514 | Sim 098
# Iter 0495 | Total Loss 16.875704 | Sim 098
# Iter 0500 | Total Loss 17.344425 | Sim 098
# Iter 0505 | Total Loss 17.479713 | Sim 098
# Iter 0510 | Total Loss 16.869167 | Sim 098
# Iter 0515 | Total Loss 17.621124 | Sim 098
# Iter 0520 | Total Loss 17.492464 | Sim 098
# Iter 0525 | Total Loss 17.315851 | Sim 098
# Iter 0530 | Total Loss 16.776442 | Sim 098
# Iter 0535 | Total Loss 15.921495 | Sim 098
# Iter 0540 | Total Loss 15.149117 | Sim 098
# Iter 0545 | Total Loss 14.822083 | Sim 098
# Iter 0550 | Total Loss 14.583252 | Sim 098
# Iter 0555 | Total Loss 15.053478 | Sim 098
# Iter 0560 | Total Loss 15.505837 | Sim 098
# Iter 0565 | Total Loss 15.776818 | Sim 098
# Iter 0570 | Total Loss 15.205583 | Sim 098
# Iter 0575 | Total Loss 15.027726 | Sim 098
# Iter 0580 | Total Loss 15.243219 | Sim 098
# Iter 0585 | Total Loss 15.361000 | Sim 098
# Iter 0590 | Total Loss 15.636976 | Sim 098
# Iter 0595 | Total Loss 16.381403 | Sim 098
# Iter 0600 | Total Loss 15.925045 | Sim 098
# Iter 0605 | Total Loss 16.082993 | Sim 098
# Iter 0610 | Total Loss 16.387838 | Sim 098
# Iter 0615 | Total Loss 17.218605 | Sim 098
# Iter 0620 | Total Loss 17.664644 | Sim 098
# Iter 0625 | Total Loss 17.871679 | Sim 098
# Iter 0630 | Total Loss 18.749033 | Sim 098
# Iter 0635 | Total Loss 16.459089 | Sim 098
# Iter 0640 | Total Loss 15.323638 | Sim 098
# Iter 0645 | Total Loss 15.555072 | Sim 098
# Iter 0650 | Total Loss 15.285584 | Sim 098
# Iter 0655 | Total Loss 15.144330 | Sim 098
# Iter 0660 | Total Loss 15.327011 | Sim 098
# Iter 0665 | Total Loss 18.260427 | Sim 098
# Iter 0670 | Total Loss 18.548838 | Sim 098
# Iter 0675 | Total Loss 16.398281 | Sim 098
# Iter 0680 | Total Loss 16.022167 | Sim 098
# Iter 0685 | Total Loss 16.552130 | Sim 098
# Iter 0690 | Total Loss 16.682606 | Sim 098
# Iter 0695 | Total Loss 17.882046 | Sim 098
# Iter 0700 | Total Loss 17.651588 | Sim 098
# Iter 0705 | Total Loss 16.899996 | Sim 098
# Iter 0710 | Total Loss 16.508244 | Sim 098
# Iter 0715 | Total Loss 15.385782 | Sim 098
# Iter 0720 | Total Loss 15.028254 | Sim 098
# Iter 0725 | Total Loss 15.697883 | Sim 098
# Iter 0730 | Total Loss 16.522263 | Sim 098
# Iter 0735 | Total Loss 18.049105 | Sim 098
# Iter 0740 | Total Loss 17.102964 | Sim 098
# Iter 0745 | Total Loss 15.503509 | Sim 098
# Iter 0750 | Total Loss 15.481987 | Sim 098
# Saved Model for Sim 098
#
# ODEFunc(
#   (net1): Sequential(
#     (0): Linear(in_features=160, out_features=100, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=100, out_features=100, bias=True)
#     (3): Tanh()
#     (4): Linear(in_features=100, out_features=160, bias=True)
#   )
# )
# Number of parameters: 42360
# Iter 0005 | Total Loss 384.520844 | Sim 100
# Iter 0010 | Total Loss 350.634979 | Sim 100
# Iter 0015 | Total Loss 313.816132 | Sim 100
# Iter 0020 | Total Loss 275.389160 | Sim 100
# Iter 0025 | Total Loss 236.777130 | Sim 100
# Iter 0030 | Total Loss 199.622696 | Sim 100
# Iter 0035 | Total Loss 163.984604 | Sim 100
# Iter 0040 | Total Loss 131.657562 | Sim 100
# Iter 0045 | Total Loss 105.593742 | Sim 100
# Iter 0050 | Total Loss 83.895004 | Sim 100
# Iter 0055 | Total Loss 67.067680 | Sim 100
# Iter 0060 | Total Loss 54.662266 | Sim 100
# Iter 0065 | Total Loss 46.321552 | Sim 100
# Iter 0070 | Total Loss 40.759228 | Sim 100
# Iter 0075 | Total Loss 37.623257 | Sim 100
# Iter 0080 | Total Loss 36.450329 | Sim 100
# Iter 0085 | Total Loss 34.978737 | Sim 100
# Iter 0090 | Total Loss 33.522327 | Sim 100
# Iter 0095 | Total Loss 32.695236 | Sim 100
# Iter 0100 | Total Loss 32.306694 | Sim 100
# Iter 0105 | Total Loss 32.249207 | Sim 100
# Iter 0110 | Total Loss 31.552402 | Sim 100
# Iter 0115 | Total Loss 31.622768 | Sim 100
# Iter 0120 | Total Loss 31.814566 | Sim 100
# Iter 0125 | Total Loss 32.728710 | Sim 100
# Iter 0130 | Total Loss 32.561554 | Sim 100
# Iter 0135 | Total Loss 33.028461 | Sim 100
# Iter 0140 | Total Loss 34.863483 | Sim 100
# Iter 0145 | Total Loss 35.675400 | Sim 100
# Iter 0150 | Total Loss 34.663643 | Sim 100
# Iter 0155 | Total Loss 34.049492 | Sim 100
# Iter 0160 | Total Loss 33.473026 | Sim 100
# Iter 0165 | Total Loss 33.852421 | Sim 100
# Iter 0170 | Total Loss 35.405495 | Sim 100
# Iter 0175 | Total Loss 35.166283 | Sim 100
# Iter 0180 | Total Loss 33.729736 | Sim 100
# Iter 0185 | Total Loss 35.006443 | Sim 100
# Iter 0190 | Total Loss 34.644241 | Sim 100
# Iter 0195 | Total Loss 34.925556 | Sim 100
# Iter 0200 | Total Loss 35.232754 | Sim 100
# Iter 0205 | Total Loss 33.594463 | Sim 100
# Iter 0210 | Total Loss 31.000397 | Sim 100
# Iter 0215 | Total Loss 30.032982 | Sim 100
# Iter 0220 | Total Loss 29.288233 | Sim 100
# Iter 0225 | Total Loss 30.421028 | Sim 100
# Iter 0230 | Total Loss 31.066566 | Sim 100
# Iter 0235 | Total Loss 29.827028 | Sim 100
# Iter 0240 | Total Loss 30.526175 | Sim 100
# Iter 0245 | Total Loss 31.706715 | Sim 100
# Iter 0250 | Total Loss 34.283592 | Sim 100
# Iter 0255 | Total Loss 33.516811 | Sim 100
# Iter 0260 | Total Loss 34.370010 | Sim 100
# Iter 0265 | Total Loss 34.510113 | Sim 100
# Iter 0270 | Total Loss 33.261913 | Sim 100
# Iter 0275 | Total Loss 31.265553 | Sim 100
# Iter 0280 | Total Loss 31.944035 | Sim 100
# Iter 0285 | Total Loss 32.152836 | Sim 100
# Iter 0290 | Total Loss 32.796108 | Sim 100
# Iter 0295 | Total Loss 33.739342 | Sim 100
# Iter 0300 | Total Loss 33.218727 | Sim 100
# Iter 0305 | Total Loss 32.971611 | Sim 100
# Iter 0310 | Total Loss 33.067730 | Sim 100
# Iter 0315 | Total Loss 33.288551 | Sim 100
# Iter 0320 | Total Loss 33.083817 | Sim 100
# Iter 0325 | Total Loss 32.841358 | Sim 100
# Iter 0330 | Total Loss 32.085991 | Sim 100
# Iter 0335 | Total Loss 31.801744 | Sim 100
# Iter 0340 | Total Loss 31.267452 | Sim 100
# Iter 0345 | Total Loss 31.149498 | Sim 100
# Iter 0350 | Total Loss 31.443399 | Sim 100
# Iter 0355 | Total Loss 31.851795 | Sim 100
# Iter 0360 | Total Loss 32.651840 | Sim 100
# Iter 0365 | Total Loss 34.272228 | Sim 100
# Iter 0370 | Total Loss 35.942791 | Sim 100
# Iter 0375 | Total Loss 37.108681 | Sim 100
# Iter 0380 | Total Loss 37.678749 | Sim 100
# Iter 0385 | Total Loss 36.432995 | Sim 100
# Iter 0390 | Total Loss 34.568485 | Sim 100
# Iter 0395 | Total Loss 33.491863 | Sim 100
# Iter 0400 | Total Loss 30.882294 | Sim 100
# Iter 0405 | Total Loss 30.669271 | Sim 100
# Iter 0410 | Total Loss 31.848549 | Sim 100
# Iter 0415 | Total Loss 32.466496 | Sim 100
# Iter 0420 | Total Loss 30.348629 | Sim 100
# Iter 0425 | Total Loss 31.662960 | Sim 100
# Iter 0430 | Total Loss 32.154457 | Sim 100
# Iter 0435 | Total Loss 33.442307 | Sim 100
# Iter 0440 | Total Loss 34.271847 | Sim 100
# Iter 0445 | Total Loss 33.712769 | Sim 100
# Iter 0450 | Total Loss 31.904787 | Sim 100
# Iter 0455 | Total Loss 32.473942 | Sim 100
# Iter 0460 | Total Loss 37.212765 | Sim 100
# Iter 0465 | Total Loss 39.395741 | Sim 100
# Iter 0470 | Total Loss 38.206863 | Sim 100
# Iter 0475 | Total Loss 35.031647 | Sim 100
# Iter 0480 | Total Loss 34.216442 | Sim 100
# Iter 0485 | Total Loss 36.952114 | Sim 100
# Iter 0490 | Total Loss 39.323967 | Sim 100
# Iter 0495 | Total Loss 39.597607 | Sim 100
# Iter 0500 | Total Loss 37.663540 | Sim 100
# Iter 0505 | Total Loss 36.227692 | Sim 100
# Iter 0510 | Total Loss 34.796131 | Sim 100
# Iter 0515 | Total Loss 32.223431 | Sim 100
# Iter 0520 | Total Loss 31.412928 | Sim 100
# Iter 0525 | Total Loss 32.417732 | Sim 100
# Iter 0530 | Total Loss 33.634346 | Sim 100
# Iter 0535 | Total Loss 34.728756 | Sim 100
# Iter 0540 | Total Loss 33.290092 | Sim 100
# Iter 0545 | Total Loss 31.356886 | Sim 100
# Iter 0550 | Total Loss 31.452030 | Sim 100
# Iter 0555 | Total Loss 32.609188 | Sim 100
# Iter 0560 | Total Loss 34.407520 | Sim 100
# Iter 0565 | Total Loss 33.445488 | Sim 100
# Iter 0570 | Total Loss 34.327045 | Sim 100
# Iter 0575 | Total Loss 33.592735 | Sim 100
# Iter 0580 | Total Loss 31.385645 | Sim 100
# Iter 0585 | Total Loss 30.367628 | Sim 100
# Iter 0590 | Total Loss 30.508627 | Sim 100
# Iter 0595 | Total Loss 31.000549 | Sim 100
# Iter 0600 | Total Loss 31.571743 | Sim 100
# Iter 0605 | Total Loss 32.242752 | Sim 100
# Iter 0610 | Total Loss 33.289803 | Sim 100
# Iter 0615 | Total Loss 32.193226 | Sim 100
# Iter 0620 | Total Loss 31.693199 | Sim 100
# Iter 0625 | Total Loss 30.560629 | Sim 100
# Iter 0630 | Total Loss 28.658600 | Sim 100
# Iter 0635 | Total Loss 28.759249 | Sim 100
# Iter 0640 | Total Loss 29.711269 | Sim 100
# Iter 0645 | Total Loss 30.438303 | Sim 100
# Iter 0650 | Total Loss 32.560066 | Sim 100
# Iter 0655 | Total Loss 35.205566 | Sim 100
# Iter 0660 | Total Loss 34.874935 | Sim 100
# Iter 0665 | Total Loss 34.950710 | Sim 100
# Iter 0670 | Total Loss 33.810005 | Sim 100
# Iter 0675 | Total Loss 33.442902 | Sim 100
# Iter 0680 | Total Loss 33.038765 | Sim 100
# Iter 0685 | Total Loss 34.327824 | Sim 100
# Iter 0690 | Total Loss 35.181473 | Sim 100
# Iter 0695 | Total Loss 36.780087 | Sim 100
# Iter 0700 | Total Loss 35.318123 | Sim 100
# Iter 0705 | Total Loss 33.901211 | Sim 100
# Iter 0710 | Total Loss 32.932442 | Sim 100
# Iter 0715 | Total Loss 32.674137 | Sim 100
# Iter 0720 | Total Loss 32.491272 | Sim 100
# Iter 0725 | Total Loss 31.886665 | Sim 100
# Iter 0730 | Total Loss 33.788990 | Sim 100
# Iter 0735 | Total Loss 33.848763 | Sim 100
# Iter 0740 | Total Loss 33.140301 | Sim 100
# Iter 0745 | Total Loss 32.814686 | Sim 100
# Iter 0750 | Total Loss 32.549580 | Sim 100
# Saved Model for Sim 100
