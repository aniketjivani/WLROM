# %% [markdown]
# Here we want to run individual models for all sims, out upto 750 iterations, save models in scratch on NERSC, and be able to load the model individual parameters too. Then we can build maps / interpolators and also do a visualization based on t-SNE similar to the idea shown in the parametric neural networks paper that shows if implicitly the relation to the flux rope parameters can be learnt.

# %% [markdown]
# Load environment variables

# %%
import os
from pathlib import Path

# %%
os.getcwd()
# Out:
# '/global/u1/a/ajivani/WLROM/EdgeSS'

# %%
os.path.join(os.getcwd(), "logs")
# Out:
# '/global/u1/a/ajivani/WLROM/EdgeSS/logs'

# %%
import logging

# stealing this from: 
# https://github.com/rtqichen/torchdiffeq/blob/master/examples/odenet_mnist.py#L250C1-L274C18
def get_logger(logpath, package_files=[], displaying=True, saving=True, debug=False):
    logger = logging.getLogger()
    if debug:
        level = logging.DEBUG
    else:
        level = logging.INFO
    logger.setLevel(level)
    if saving:
        info_file_handler = logging.FileHandler(logpath, mode="a")
        info_file_handler.setLevel(level)
        logger.addHandler(info_file_handler)
    if displaying:
        console_handler = logging.StreamHandler()
        console_handler.setLevel(level)
        logger.addHandler(console_handler)
        #     logger.info(filepath)

        #     with open(filepath, "r") as f:
        #         logger.info(f.read())

        #     for f in package_files:
        #         logger.info(f)
        #         with open(f, "r") as package_f:
        #             logger.info(package_f.read())

    return logger

# %%
logger = get_logger(logpath=os.path.join(os.getcwd(), "individual_nn_training.log"))

# %%
print(os.environ['PSCRATCH'])
# Out:
# /pscratch/sd/a/ajivani

# %%
scratch_dir = os.environ["PSCRATCH"]
scratch_dir
# Out:
# '/pscratch/sd/a/ajivani'

# %%
def makedirs(dirname):
    try:
        os.mkdir(dirname)
        print("Dir '{}' created to save individual models".format(dirname))
    except FileExistsError:
        print("Path already exists")

# %%
trained_models = os.path.join(scratch_dir, "trained_models_1d_edge")

# %%
makedirs(trained_models)
# Out:
# Path already exists

# %% [markdown]
# Load Packages

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# %%
adjoint=True

# %%
if adjoint:
    from torchdiffeq import odeint_adjoint as odeint
else:
    from torchdiffeq import odeint

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda', index=0)

# %%
runModel=True

# %%
import numpy as np
import scipy.linalg as la
import scipy.sparse as sparse
import matplotlib.pyplot as plt

# %%
import time
import re

# %%
# %matplotlib inline

# %%
plt.rc("axes.spines", right=True, top=True)
plt.rc("figure", dpi=300, 
       figsize=(9, 3)
      )
plt.rc("font", family="serif")
plt.rc("legend", edgecolor="none", frameon=True)
plt.style.use("dark_background")

# %%
import edge_utils as edut

# %% [markdown]
# Load a sample model and see how to access its parameters.

# %%
# sample_model = torch.load("dydt_Ay_global_model_5000_steps.pkl") 
# #this does not work, we shouldn't pickle model files probably?

# %% [markdown]
# Setup training loop for all sims, set up a logger

# %%
sims_to_remove = np.array([33, 39, 63, 73, 113, 128, 131, 142, 193, 218, 253, 264, 273, 312, 313, 324])

# %%
ed_2161, sd_2161 = edut.load_edge_data_blobfree(2161)

# %%
theta_s_2161, theta_e_2161 = np.linspace(0, 360, 512)[160] + 1.2 * 180 - 360, np.linspace(0, 360, 512)[320] + 1.2 * 180 - 360
print("Range of angles for CR2161: {} {}".format(theta_s_2161, theta_e_2161))
# Out:
# Range of angles for CR2161: -31.279843444227026 81.44031311154595

# %%
def getRValuesAllSims(edge_data_matrix):
    """
    Return r values for all sims at once so we don't lose time in training processing r values repeatedly
    """
    r_data_matrix = np.zeros(edge_data_matrix.shape)
    nsims = edge_data_matrix.shape[2]
    for i in range(nsims):
        r_vals, theta_vals = edut.getRValues(edge_data_matrix, simIdx=i, minStartIdx=0)
        r_data_matrix[:, :, i] = r_vals

    return r_data_matrix

# %%
rd_2161 = getRValuesAllSims(ed_2161)

# %%
nTimes, nTheta_2161, nSims_2161 = ed_2161.shape
nTimes, nTheta_2161, nSims_2161
# Out:
# (90, 160, 278)

# %%
theta_grid = np.linspace(np.ceil(theta_s_2161), np.ceil(theta_e_2161), nTheta_2161)

# %%
sd_modified = np.setdiff1d(sd_2161, sims_to_remove)

# %%
len(sd_modified)
# Out:
# 262

# %%
## for reproducibility, we will just load these from file instead of regenerating each time because
## kernel will have to be restarted very frequently (long training process)
# from numpy.random import Generator, PCG64
# rng = Generator(PCG64())

# nTrain = int(np.floor(0.6 * len(sd_modified)))
# nCalib = int(np.floor(0.2 * len(sd_modified)))
# nTest = len(sd_modified) - nTrain - nCalib

# nTrain, nTest, nCalib

# %%
# sd_train = np.sort(np.random.choice(sd_modified, nTrain, replace=False))
# sd_test_calib = np.setdiff1d(sd_modified, sd_train)
# sd_calib = np.sort(np.random.choice(sd_test_calib, nCalib, replace=False))
# sd_test = np.setdiff1d(sd_test_calib, sd_calib)

# sd_test, sd_calib

# %%
### LOAD FROM FILE FOR NOW FOR REPRODUCIBILITY
sd_train = np.load(os.path.join(scratch_dir, trained_models, "sd_train.npy"))
sd_test  = np.load(os.path.join(scratch_dir, trained_models, "sd_test.npy"))
sd_calib = np.load(os.path.join(scratch_dir, trained_models, "sd_calib.npy"))

# %%
np.sum(np.sort(np.hstack((sd_test, sd_calib, sd_train))) == sd_modified)
# Out:
# 262

# %%
train_sd_idx = np.array([np.where(sd_2161 == i)[0][0] for i in sd_train])
test_sd_idx  = np.array([np.where(sd_2161 == i)[0][0] for i in sd_test])

# %%
train_sd_idx_modified = np.array([np.where(sd_modified == i)[0][0] for i in sd_train])

# %%
test_sd_idx_modified = np.array([np.where(sd_modified == i)[0][0] for i in sd_test])

# %%
input_dim = rd_2161.shape[1]

# %%
input_dim
# Out:
# 160

# %%
def getDataForSim(edge_data_matrix, r_data_matrix, sim_data, sid):
    """
    Take in a randomly chosen sim from the training set and return the following:
    y0_train_torch
    y_train_torch
    i.e. IC and data in torch tensor format on Device
    t_train_torch
    and correct sim_index from sim_data
    """
    
    sim_index = np.argwhere(sim_data == sid)[0][0]
    
    r_sim = r_data_matrix[:, :, sim_index]
    
    tMinIdx, tMin, tMaxIdx, tMax = edut.getTMinTMax(edge_data_matrix, simIdx=sim_index)
    
    r_sim_valid = r_sim[tMinIdx:(tMaxIdx+1), :]
    valid_times = np.arange(tMin, tMax + 2, step=2)
    
    tTrainEnd = tMin + np.floor((2/3)*(tMax - tMin))
    
    
    trainEndIdx = np.argmin(np.abs(valid_times - tTrainEnd))
    #     trainEndIdx = np.argwhere(valid_times == tTrainEnd)[0][0]
    
    tTrain = valid_times[:(trainEndIdx + 1)]
    
    tTest = valid_times[(trainEndIdx + 1):]
    
    tTrainScaled = (tTrain - tMin) / (tMax - tMin)
    tTestScaled = (tTest - tMin) / (tMax - tMin)
    
    tAllScaled = (valid_times - tMin) / (tMax - tMin)
    
    y0_train_orig = r_sim_valid[0, :]
    y0_train_torch = torch.from_numpy(np.float32(y0_train_orig))
    y0_train_torch = y0_train_torch.reshape((1, len(y0_train_torch))).to(device)
    
    
    y_train_orig = r_sim_valid[:(trainEndIdx + 1), :]
    y_train_torch = torch.from_numpy(np.expand_dims(np.float32(y_train_orig), axis=1)).to(device)
    
    y_full_torch = torch.from_numpy(np.expand_dims(np.float32(r_sim_valid), axis=1)).to(device)
    
    t_train_torch = torch.tensor(np.float32(tTrainScaled)).to(device)
    t_scaled_torch = torch.tensor(np.float32(tAllScaled)).to(device)
    
    return y0_train_torch, y_train_torch, y_full_torch, t_train_torch, t_scaled_torch, sim_index

# %%
def get_batch(torch_train_data, torch_train_time, batch_time=5, batch_size=10):
    s = torch.from_numpy(np.random.choice(np.arange(len(torch_train_time) - batch_time, dtype=np.int64),
                                          batch_size,
                                          replace=False))
    batch_y0 = torch_train_data[s]  # (M, D)
    batch_t = torch.zeros((batch_size, batch_time))
    for i in range(batch_size):
        batch_t[i, :] = torch_train_time[s[i]:(s[i] + batch_time)]
        
    batch_y = torch.stack([torch_train_data[s + i] for i in range(batch_time)], dim=0)  # (T, M, D)
    return batch_y0.to(device), batch_t.to(device), batch_y.to(device)

# %%
class ODEFunc(nn.Module):

    def __init__(self, dim):
        super(ODEFunc, self).__init__()

        self.net1 = nn.Sequential(
            nn.Linear(dim, 100),
            nn.Tanh(),
            nn.Linear(100, 100),
            nn.Tanh(),
            nn.Linear(100, dim),
        )
        
        for m in self.net1.modules():
            if isinstance(m, nn.Linear):
                nn.init.normal_(m.weight, mean=0, std=0.1)
                nn.init.constant_(m.bias, val=0)
                
    def forward(self, t, y):
        return self.net1(y)

# %%
class RunningAverageMeter(object):
    """Computes and stores the average and current value"""

    def __init__(self, momentum=0.99):
        self.momentum = momentum
        self.losses = []
        self.reset()

    def reset(self):
        self.val = None
        self.avg = 0

    def update(self, val):
        if self.val is None:
            self.avg = val
        else:
            self.avg = self.avg * self.momentum + val * (1 - self.momentum)
        self.val = val
        self.losses.append(self.avg)

# %%
def getAbsoluteAvgBatchLoss(prediction_tensor, target_tensor):
    """
    both tensors are of dims (n_times, n_batch, 1, len_traj) or (n_times, 1, len_traj)
    """
    
    # swap dimensions of batch and time
    if len(prediction_tensor.shape) > 3:
        prediction_tensor = torch.permute(prediction_tensor, (1, 0, 2, 3))
        target_tensor = torch.permute(target_tensor, (1, 0, 2, 3))
        # print(prediction_tensor.shape)#testing
        # get torch.abs of difference
        abs_diff = torch.abs(prediction_tensor - target_tensor)

        # sum over trajectory length
        batch_sums = torch.sum(abs_diff, 3)
    else:
        prediction_tensor = torch.permute(prediction_tensor, (1, 0, 2))
        target_tensor = torch.permute(target_tensor, (1, 0, 2))
        # print(prediction_tensor.shape)#testing
        # get torch.abs of difference
        abs_diff = torch.abs(prediction_tensor - target_tensor)

        # sum over trajectory length
        batch_sums = torch.sum(abs_diff, 2)


    # print(batch_sums.shape)  #testing
    
    # get mean of final tensor to get batch and time averaged absolute loss
    batch_loss = torch.mean(batch_sums)
    
    # print(batch_loss)#testing
    
    return batch_loss

# %%
# Stealing from: 
# github.com/rtqichen/torchdiffeq/blob/84e220ac9ea9367c14933d8f141fc2791034ec88/
# examples/odenet_mnist.py#L241C1-L242C73

def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %%
# Sketch of what each loop would look like:

def runNeuralODE(simID, model_save_path, niters=750, test_freq=5, batch_time=5, batch_size=10):
    y0_train_torch, y_train_torch, y_full_torch, t_train_torch, t_scaled_torch, sim_index = getDataForSim(ed_2161,rd_2161,sd_2161,simID)

    time_meter = RunningAverageMeter(0.97)
    loss_meter = RunningAverageMeter(0.97)

    ii = 0
    func = ODEFunc(160).to(device)
    optimizer = optim.Adam(func.parameters(), lr=1e-3)
    end = time.time()

    logger.info(func)
    logger.info('Number of parameters: {}'.format(count_parameters(func)))
    
    niters=niters
    test_freq=test_freq

    for itr in range(1, niters + 1):
        optimizer.zero_grad()
        batch_y0, batch_t, batch_y = get_batch(y_train_torch, 
                                               t_train_torch,
                                              batch_time=batch_time,
                                              batch_size=batch_size)
        pred_y = torch.zeros_like(batch_y)

        for i in range(batch_size):
            pred_y[:, i, :, :] = odeint(func, 
                                        batch_y0[i, :, :], 
                                        batch_t[i, :]).to(device)

        loss = getAbsoluteAvgBatchLoss(pred_y, batch_y)
        loss.backward()
        optimizer.step()

        time_meter.update(time.time() - end)
        loss_meter.update(loss.item())

        if itr % test_freq == 0:
            with torch.no_grad():
                pred_y_full_series = odeint(func, 
                                            y0_train_torch, 
                                            t_scaled_torch)
                loss_full_series = getAbsoluteAvgBatchLoss(pred_y_full_series, 
                                                           y_full_torch)
                # print("Iter {:04d} | Total Loss {:.6f} | Sim {:03d} ".format(itr,
                                                                # loss_full_series.item(), 
                                                                # simID))
                
                
                logger.info("Iter {:04d} | Total Loss {:.6f} | Sim {:03d} ".format(itr,
                                                                loss_full_series.item(), 
                                                                simID))

                ii += 1

        end = time.time()
    
        
    model_dict_name = "dydt_Ay_750_steps_sim_{:03d}.pt".format(simID)
    torch.save(func.state_dict(), os.path.join(model_save_path, model_dict_name))
    # print("Saved Model for Sim {:03d}".format(simID))
    logger.info("Saved Model for Sim {:03d}\n".format(simID))
    torch.cuda.empty_cache()

# %% [markdown]
# ### Call training process for one or more sims and save model once trained

# %%
trained_models
# Out:
# '/pscratch/sd/a/ajivani/trained_models_1d_edge'

# %%
sd_train
# Out:
# array([ 31,  32,  35,  37,  40,  42,  43,  45,  46,  47,  48,  49,  52,
#         53,  57,  59,  60,  61,  62,  66,  67,  70,  71,  74,  75,  76,
#         77,  78,  79,  80,  83,  84,  85,  87,  90,  91,  92,  94,  95,
#         96,  97,  98, 100, 101, 102, 106, 108, 111, 112, 114, 120, 121,
#        123, 124, 130, 132, 135, 136, 138, 139, 140, 141, 143, 147, 148,
#        149, 150, 151, 154, 155, 156, 157, 158, 159, 161, 164, 174, 178,
#        180, 183, 184, 185, 190, 192, 194, 196, 197, 198, 199, 202, 204,
#        205, 209, 210, 211, 212, 215, 216, 217, 219, 220, 221, 222, 223,
#        229, 230, 232, 234, 235, 236, 238, 240, 241, 242, 243, 244, 246,
#        248, 249, 251, 252, 254, 256, 257, 260, 261, 263, 271, 274, 275,
#        276, 277, 278, 279, 281, 282, 284, 287, 288, 289, 290, 291, 293,
#        298, 299, 301, 303, 305, 311, 314, 315, 317, 318, 319, 323, 325,
#        329])

# %%
# SIMS STILL PENDING
# 32, 37, 40, 47, 52, 53, 61, 62, 78, 79, 87, 91, 92, 95, 98, 100 (rest all are correct)

# %%
sd_train[140]
# Out:
# 290

# %%
sd_train[156]
# Out:
# 329

# %%
# pending_sims = np.array([32, 37, 40, 47, 52, 53, 61, 62, 78, 79, 87, 91, 92, 95, 98, 100])
# pending_sims = np.array([84])

# %% [markdown]
# We probably need some sort of script that can launch jobs on multiple GPUs or try running models in parallel on the same GPU? abandoning this idea for now as there are very specific implementations
# that may or may not apply to this scenario.

# %%
# for sim in sd_train[140:]:
# for sim in pending_sims:
for sim in sd_calib:
    runNeuralODE(sim, trained_models, niters=750, test_freq=5)
# Out:
# ODEFunc(
#   (net1): Sequential(
#     (0): Linear(in_features=160, out_features=100, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=100, out_features=100, bias=True)
#     (3): Tanh()
#     (4): Linear(in_features=100, out_features=160, bias=True)
#   )
# )
# ODEFunc(
#   (net1): Sequential(
#     (0): Linear(in_features=160, out_features=100, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=100, out_features=100, bias=True)
#     (3): Tanh()
#     (4): Linear(in_features=100, out_features=160, bias=True)
#   )
# )
# Number of parameters: 42360
# Number of parameters: 42360
# Iter 0005 | Total Loss 347.968079 | Sim 034
# Iter 0005 | Total Loss 347.968079 | Sim 034
# Iter 0010 | Total Loss 312.977142 | Sim 034
# Iter 0010 | Total Loss 312.977142 | Sim 034
# Iter 0015 | Total Loss 273.274994 | Sim 034
# Iter 0015 | Total Loss 273.274994 | Sim 034
# Iter 0020 | Total Loss 231.922256 | Sim 034
# Iter 0020 | Total Loss 231.922256 | Sim 034
# Iter 0025 | Total Loss 190.221313 | Sim 034
# Iter 0025 | Total Loss 190.221313 | Sim 034
# Iter 0030 | Total Loss 149.718658 | Sim 034
# Iter 0030 | Total Loss 149.718658 | Sim 034
# Iter 0035 | Total Loss 112.135254 | Sim 034
# Iter 0035 | Total Loss 112.135254 | Sim 034
# Iter 0040 | Total Loss 79.764069 | Sim 034
# Iter 0040 | Total Loss 79.764069 | Sim 034
# Iter 0045 | Total Loss 57.054470 | Sim 034
# Iter 0045 | Total Loss 57.054470 | Sim 034
# Iter 0050 | Total Loss 42.043213 | Sim 034
# Iter 0050 | Total Loss 42.043213 | Sim 034
# Iter 0055 | Total Loss 33.579292 | Sim 034
# Iter 0055 | Total Loss 33.579292 | Sim 034
# Iter 0060 | Total Loss 29.964260 | Sim 034
# Iter 0060 | Total Loss 29.964260 | Sim 034
# Iter 0065 | Total Loss 28.243299 | Sim 034
# Iter 0065 | Total Loss 28.243299 | Sim 034
# Iter 0070 | Total Loss 27.536432 | Sim 034
# Iter 0070 | Total Loss 27.536432 | Sim 034
# Iter 0075 | Total Loss 28.052183 | Sim 034
# Iter 0075 | Total Loss 28.052183 | Sim 034
# Iter 0080 | Total Loss 29.071768 | Sim 034
# Iter 0080 | Total Loss 29.071768 | Sim 034
# Iter 0085 | Total Loss 30.531971 | Sim 034
# Iter 0085 | Total Loss 30.531971 | Sim 034
# Iter 0090 | Total Loss 30.355637 | Sim 034
# Iter 0090 | Total Loss 30.355637 | Sim 034
# Iter 0095 | Total Loss 29.020277 | Sim 034
# Iter 0095 | Total Loss 29.020277 | Sim 034
# Iter 0100 | Total Loss 28.390903 | Sim 034
# Iter 0100 | Total Loss 28.390903 | Sim 034
# Iter 0105 | Total Loss 27.172621 | Sim 034
# Iter 0105 | Total Loss 27.172621 | Sim 034
# Iter 0110 | Total Loss 25.904478 | Sim 034
# Iter 0110 | Total Loss 25.904478 | Sim 034
# Iter 0115 | Total Loss 25.353207 | Sim 034
# Iter 0115 | Total Loss 25.353207 | Sim 034
# Iter 0120 | Total Loss 25.035213 | Sim 034
# Iter 0120 | Total Loss 25.035213 | Sim 034
# Iter 0125 | Total Loss 23.934681 | Sim 034
# Iter 0125 | Total Loss 23.934681 | Sim 034
# Iter 0130 | Total Loss 23.628757 | Sim 034
# Iter 0130 | Total Loss 23.628757 | Sim 034
# Iter 0135 | Total Loss 24.554548 | Sim 034
# Iter 0135 | Total Loss 24.554548 | Sim 034
# Iter 0140 | Total Loss 25.398058 | Sim 034
# Iter 0140 | Total Loss 25.398058 | Sim 034
# Iter 0145 | Total Loss 26.117800 | Sim 034
# Iter 0145 | Total Loss 26.117800 | Sim 034
# Iter 0150 | Total Loss 26.049522 | Sim 034
# Iter 0150 | Total Loss 26.049522 | Sim 034
# Iter 0155 | Total Loss 25.466946 | Sim 034
# Iter 0155 | Total Loss 25.466946 | Sim 034
# Iter 0160 | Total Loss 23.762682 | Sim 034
# Iter 0160 | Total Loss 23.762682 | Sim 034
# Iter 0165 | Total Loss 21.741102 | Sim 034
# Iter 0165 | Total Loss 21.741102 | Sim 034
# Iter 0170 | Total Loss 22.099394 | Sim 034
# Iter 0170 | Total Loss 22.099394 | Sim 034
# Iter 0175 | Total Loss 23.788788 | Sim 034
# Iter 0175 | Total Loss 23.788788 | Sim 034
# Iter 0180 | Total Loss 25.088182 | Sim 034
# Iter 0180 | Total Loss 25.088182 | Sim 034
# Iter 0185 | Total Loss 25.865871 | Sim 034
# Iter 0185 | Total Loss 25.865871 | Sim 034
# Iter 0190 | Total Loss 26.476025 | Sim 034
# Iter 0190 | Total Loss 26.476025 | Sim 034
# Iter 0195 | Total Loss 25.672165 | Sim 034
# Iter 0195 | Total Loss 25.672165 | Sim 034
# Iter 0200 | Total Loss 25.717312 | Sim 034
# Iter 0200 | Total Loss 25.717312 | Sim 034
# Iter 0205 | Total Loss 26.434134 | Sim 034
# Iter 0205 | Total Loss 26.434134 | Sim 034
# Iter 0210 | Total Loss 26.687120 | Sim 034
# Iter 0210 | Total Loss 26.687120 | Sim 034
# Iter 0215 | Total Loss 27.983665 | Sim 034
# Iter 0215 | Total Loss 27.983665 | Sim 034
# Iter 0220 | Total Loss 28.787502 | Sim 034
# Iter 0220 | Total Loss 28.787502 | Sim 034
# Iter 0225 | Total Loss 28.961929 | Sim 034
# Iter 0225 | Total Loss 28.961929 | Sim 034
# Iter 0230 | Total Loss 30.356197 | Sim 034
# Iter 0230 | Total Loss 30.356197 | Sim 034
# Iter 0235 | Total Loss 30.750679 | Sim 034
# Iter 0235 | Total Loss 30.750679 | Sim 034
# Iter 0240 | Total Loss 30.861547 | Sim 034
# Iter 0240 | Total Loss 30.861547 | Sim 034
# Iter 0245 | Total Loss 30.069654 | Sim 034
# Iter 0245 | Total Loss 30.069654 | Sim 034
# Iter 0250 | Total Loss 29.194910 | Sim 034
# Iter 0250 | Total Loss 29.194910 | Sim 034
# Iter 0255 | Total Loss 28.492939 | Sim 034
# Iter 0255 | Total Loss 28.492939 | Sim 034
# Iter 0260 | Total Loss 28.158918 | Sim 034
# Iter 0260 | Total Loss 28.158918 | Sim 034
# Iter 0265 | Total Loss 29.678608 | Sim 034
# Iter 0265 | Total Loss 29.678608 | Sim 034
# Iter 0270 | Total Loss 30.393976 | Sim 034
# Iter 0270 | Total Loss 30.393976 | Sim 034
# Iter 0275 | Total Loss 31.396914 | Sim 034
# Iter 0275 | Total Loss 31.396914 | Sim 034
# Iter 0280 | Total Loss 31.671391 | Sim 034
# Iter 0280 | Total Loss 31.671391 | Sim 034
# Iter 0285 | Total Loss 30.968250 | Sim 034
# Iter 0285 | Total Loss 30.968250 | Sim 034
# Iter 0290 | Total Loss 30.492523 | Sim 034
# Iter 0290 | Total Loss 30.492523 | Sim 034
# Iter 0295 | Total Loss 31.659864 | Sim 034
# Iter 0295 | Total Loss 31.659864 | Sim 034
# Iter 0300 | Total Loss 30.861734 | Sim 034
# Iter 0300 | Total Loss 30.861734 | Sim 034
# Iter 0305 | Total Loss 28.793806 | Sim 034
# Iter 0305 | Total Loss 28.793806 | Sim 034
# Iter 0310 | Total Loss 26.082405 | Sim 034
# Iter 0310 | Total Loss 26.082405 | Sim 034
# Iter 0315 | Total Loss 23.693954 | Sim 034
# Iter 0315 | Total Loss 23.693954 | Sim 034
# Iter 0320 | Total Loss 23.758072 | Sim 034
# Iter 0320 | Total Loss 23.758072 | Sim 034
# Iter 0325 | Total Loss 25.603918 | Sim 034
# Iter 0325 | Total Loss 25.603918 | Sim 034
# Iter 0330 | Total Loss 28.021570 | Sim 034
# Iter 0330 | Total Loss 28.021570 | Sim 034
# Iter 0335 | Total Loss 28.412451 | Sim 034
# Iter 0335 | Total Loss 28.412451 | Sim 034
# Iter 0340 | Total Loss 26.492996 | Sim 034
# Iter 0340 | Total Loss 26.492996 | Sim 034
# Iter 0345 | Total Loss 23.779343 | Sim 034
# Iter 0345 | Total Loss 23.779343 | Sim 034
# Iter 0350 | Total Loss 22.506483 | Sim 034
# Iter 0350 | Total Loss 22.506483 | Sim 034
# Iter 0355 | Total Loss 22.951357 | Sim 034
# Iter 0355 | Total Loss 22.951357 | Sim 034
# Iter 0360 | Total Loss 23.433767 | Sim 034
# Iter 0360 | Total Loss 23.433767 | Sim 034
# Iter 0365 | Total Loss 25.285103 | Sim 034
# Iter 0365 | Total Loss 25.285103 | Sim 034
# Iter 0370 | Total Loss 26.358498 | Sim 034
# Iter 0370 | Total Loss 26.358498 | Sim 034
# Iter 0375 | Total Loss 27.354492 | Sim 034
# Iter 0375 | Total Loss 27.354492 | Sim 034
# Iter 0380 | Total Loss 29.368160 | Sim 034
# Iter 0380 | Total Loss 29.368160 | Sim 034
# Iter 0385 | Total Loss 30.244820 | Sim 034
# Iter 0385 | Total Loss 30.244820 | Sim 034
# Iter 0390 | Total Loss 30.136860 | Sim 034
# Iter 0390 | Total Loss 30.136860 | Sim 034
# Iter 0395 | Total Loss 31.034248 | Sim 034
# Iter 0395 | Total Loss 31.034248 | Sim 034
# Iter 0400 | Total Loss 30.037064 | Sim 034
# Iter 0400 | Total Loss 30.037064 | Sim 034
# Iter 0405 | Total Loss 26.078518 | Sim 034
# Iter 0405 | Total Loss 26.078518 | Sim 034
# Iter 0410 | Total Loss 25.126841 | Sim 034
# Iter 0410 | Total Loss 25.126841 | Sim 034
# Iter 0415 | Total Loss 25.243708 | Sim 034
# Iter 0415 | Total Loss 25.243708 | Sim 034
# Iter 0420 | Total Loss 26.421261 | Sim 034
# Iter 0420 | Total Loss 26.421261 | Sim 034
# Iter 0425 | Total Loss 28.941931 | Sim 034
# Iter 0425 | Total Loss 28.941931 | Sim 034
# Iter 0430 | Total Loss 32.441914 | Sim 034
# Iter 0430 | Total Loss 32.441914 | Sim 034
# Iter 0435 | Total Loss 33.485466 | Sim 034
# Iter 0435 | Total Loss 33.485466 | Sim 034
# Iter 0440 | Total Loss 32.501457 | Sim 034
# Iter 0440 | Total Loss 32.501457 | Sim 034
# Iter 0445 | Total Loss 29.753201 | Sim 034
# Iter 0445 | Total Loss 29.753201 | Sim 034
# Iter 0450 | Total Loss 27.258532 | Sim 034
# Iter 0450 | Total Loss 27.258532 | Sim 034
# Iter 0455 | Total Loss 26.565939 | Sim 034
# Iter 0455 | Total Loss 26.565939 | Sim 034
# Iter 0460 | Total Loss 24.042728 | Sim 034
# Iter 0460 | Total Loss 24.042728 | Sim 034
# Iter 0465 | Total Loss 21.840092 | Sim 034
# Iter 0465 | Total Loss 21.840092 | Sim 034
# Iter 0470 | Total Loss 22.387886 | Sim 034
# Iter 0470 | Total Loss 22.387886 | Sim 034
# Iter 0475 | Total Loss 22.641037 | Sim 034
# Iter 0475 | Total Loss 22.641037 | Sim 034
# Iter 0480 | Total Loss 24.343525 | Sim 034
# Iter 0480 | Total Loss 24.343525 | Sim 034
# Iter 0485 | Total Loss 25.428665 | Sim 034
# Iter 0485 | Total Loss 25.428665 | Sim 034
# Iter 0490 | Total Loss 28.342928 | Sim 034
# Iter 0490 | Total Loss 28.342928 | Sim 034
# Iter 0495 | Total Loss 28.661680 | Sim 034
# Iter 0495 | Total Loss 28.661680 | Sim 034
# Iter 0500 | Total Loss 28.775553 | Sim 034
# Iter 0500 | Total Loss 28.775553 | Sim 034
# Iter 0505 | Total Loss 29.855196 | Sim 034
# Iter 0505 | Total Loss 29.855196 | Sim 034
# Iter 0510 | Total Loss 30.793064 | Sim 034
# Iter 0510 | Total Loss 30.793064 | Sim 034
# Iter 0515 | Total Loss 30.239456 | Sim 034
# Iter 0515 | Total Loss 30.239456 | Sim 034
# Iter 0520 | Total Loss 29.414448 | Sim 034
# Iter 0520 | Total Loss 29.414448 | Sim 034
# Iter 0525 | Total Loss 27.336597 | Sim 034
# Iter 0525 | Total Loss 27.336597 | Sim 034
# Iter 0530 | Total Loss 25.074667 | Sim 034
# Iter 0530 | Total Loss 25.074667 | Sim 034
# Iter 0535 | Total Loss 23.270943 | Sim 034
# Iter 0535 | Total Loss 23.270943 | Sim 034
# Iter 0540 | Total Loss 24.347168 | Sim 034
# Iter 0540 | Total Loss 24.347168 | Sim 034
# Iter 0545 | Total Loss 26.305908 | Sim 034
# Iter 0545 | Total Loss 26.305908 | Sim 034
# Iter 0550 | Total Loss 28.180149 | Sim 034
# Iter 0550 | Total Loss 28.180149 | Sim 034
# Iter 0555 | Total Loss 29.593222 | Sim 034
# Iter 0555 | Total Loss 29.593222 | Sim 034
# Iter 0560 | Total Loss 29.187035 | Sim 034
# Iter 0560 | Total Loss 29.187035 | Sim 034
# Iter 0565 | Total Loss 29.567234 | Sim 034
# Iter 0565 | Total Loss 29.567234 | Sim 034
# Iter 0570 | Total Loss 28.902328 | Sim 034
# Iter 0570 | Total Loss 28.902328 | Sim 034
# Iter 0575 | Total Loss 27.840368 | Sim 034
# Iter 0575 | Total Loss 27.840368 | Sim 034
# Iter 0580 | Total Loss 26.905220 | Sim 034
# Iter 0580 | Total Loss 26.905220 | Sim 034
# Iter 0585 | Total Loss 26.425222 | Sim 034
# Iter 0585 | Total Loss 26.425222 | Sim 034
# Iter 0590 | Total Loss 26.363558 | Sim 034
# Iter 0590 | Total Loss 26.363558 | Sim 034
# Iter 0595 | Total Loss 26.055664 | Sim 034
# Iter 0595 | Total Loss 26.055664 | Sim 034
# Iter 0600 | Total Loss 24.059511 | Sim 034
# Iter 0600 | Total Loss 24.059511 | Sim 034
# Iter 0605 | Total Loss 24.840857 | Sim 034
# Iter 0605 | Total Loss 24.840857 | Sim 034
# Iter 0610 | Total Loss 26.808743 | Sim 034
# Iter 0610 | Total Loss 26.808743 | Sim 034
# Iter 0615 | Total Loss 28.587040 | Sim 034
# Iter 0615 | Total Loss 28.587040 | Sim 034
# Iter 0620 | Total Loss 29.495480 | Sim 034
# Iter 0620 | Total Loss 29.495480 | Sim 034
# Iter 0625 | Total Loss 29.716097 | Sim 034
# Iter 0625 | Total Loss 29.716097 | Sim 034
# Iter 0630 | Total Loss 29.993467 | Sim 034
# Iter 0630 | Total Loss 29.993467 | Sim 034
# Iter 0635 | Total Loss 30.029102 | Sim 034
# Iter 0635 | Total Loss 30.029102 | Sim 034
# Iter 0640 | Total Loss 28.720486 | Sim 034
# Iter 0640 | Total Loss 28.720486 | Sim 034
# Iter 0645 | Total Loss 27.156029 | Sim 034
# Iter 0645 | Total Loss 27.156029 | Sim 034
# Iter 0650 | Total Loss 25.215916 | Sim 034
# Iter 0650 | Total Loss 25.215916 | Sim 034
# Iter 0655 | Total Loss 26.311827 | Sim 034
# Iter 0655 | Total Loss 26.311827 | Sim 034
# Iter 0660 | Total Loss 28.146154 | Sim 034
# Iter 0660 | Total Loss 28.146154 | Sim 034
# Iter 0665 | Total Loss 27.651358 | Sim 034
# Iter 0665 | Total Loss 27.651358 | Sim 034
# Iter 0670 | Total Loss 25.799976 | Sim 034
# Iter 0670 | Total Loss 25.799976 | Sim 034
# Iter 0675 | Total Loss 27.343452 | Sim 034
# Iter 0675 | Total Loss 27.343452 | Sim 034
# Iter 0680 | Total Loss 28.203907 | Sim 034
# Iter 0680 | Total Loss 28.203907 | Sim 034
# Iter 0685 | Total Loss 27.762167 | Sim 034
# Iter 0685 | Total Loss 27.762167 | Sim 034
# Iter 0690 | Total Loss 26.086607 | Sim 034
# Iter 0690 | Total Loss 26.086607 | Sim 034
# Iter 0695 | Total Loss 26.754221 | Sim 034
# Iter 0695 | Total Loss 26.754221 | Sim 034
# Iter 0700 | Total Loss 26.342634 | Sim 034
# Iter 0700 | Total Loss 26.342634 | Sim 034
# Iter 0705 | Total Loss 24.820009 | Sim 034
# Iter 0705 | Total Loss 24.820009 | Sim 034
# Iter 0710 | Total Loss 22.952908 | Sim 034
# Iter 0710 | Total Loss 22.952908 | Sim 034
# Iter 0715 | Total Loss 24.830734 | Sim 034
# Iter 0715 | Total Loss 24.830734 | Sim 034
# Iter 0720 | Total Loss 25.173750 | Sim 034
# Iter 0720 | Total Loss 25.173750 | Sim 034
# Iter 0725 | Total Loss 27.276625 | Sim 034
# Iter 0725 | Total Loss 27.276625 | Sim 034
# Iter 0730 | Total Loss 29.481436 | Sim 034
# Iter 0730 | Total Loss 29.481436 | Sim 034
# Iter 0735 | Total Loss 31.185753 | Sim 034
# Iter 0735 | Total Loss 31.185753 | Sim 034
# Iter 0740 | Total Loss 31.882889 | Sim 034
# Iter 0740 | Total Loss 31.882889 | Sim 034
# Iter 0745 | Total Loss 30.815786 | Sim 034
# Iter 0745 | Total Loss 30.815786 | Sim 034
# Iter 0750 | Total Loss 30.483006 | Sim 034
# Iter 0750 | Total Loss 30.483006 | Sim 034
# Saved Model for Sim 034
#
# Saved Model for Sim 034
#
# ODEFunc(
#   (net1): Sequential(
#     (0): Linear(in_features=160, out_features=100, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=100, out_features=100, bias=True)
#     (3): Tanh()
#     (4): Linear(in_features=100, out_features=160, bias=True)
#   )
# )
# ODEFunc(
#   (net1): Sequential(
#     (0): Linear(in_features=160, out_features=100, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=100, out_features=100, bias=True)
#     (3): Tanh()
#     (4): Linear(in_features=100, out_features=160, bias=True)
#   )
# )
# Number of parameters: 42360
# Number of parameters: 42360
# Iter 0005 | Total Loss 498.119995 | Sim 041
# Iter 0005 | Total Loss 498.119995 | Sim 041
# Iter 0010 | Total Loss 461.813019 | Sim 041
# Iter 0010 | Total Loss 461.813019 | Sim 041
# Iter 0015 | Total Loss 424.232910 | Sim 041
# Iter 0015 | Total Loss 424.232910 | Sim 041
# Iter 0020 | Total Loss 384.027283 | Sim 041
# Iter 0020 | Total Loss 384.027283 | Sim 041
# Iter 0025 | Total Loss 344.301544 | Sim 041
# Iter 0025 | Total Loss 344.301544 | Sim 041
# Iter 0030 | Total Loss 305.728119 | Sim 041
# Iter 0030 | Total Loss 305.728119 | Sim 041
# Iter 0035 | Total Loss 270.790161 | Sim 041
# Iter 0035 | Total Loss 270.790161 | Sim 041
# Iter 0040 | Total Loss 237.094666 | Sim 041
# Iter 0040 | Total Loss 237.094666 | Sim 041
# Iter 0045 | Total Loss 203.924057 | Sim 041
# Iter 0045 | Total Loss 203.924057 | Sim 041
# Iter 0050 | Total Loss 173.988251 | Sim 041
# Iter 0050 | Total Loss 173.988251 | Sim 041
# Iter 0055 | Total Loss 150.010025 | Sim 041
# Iter 0055 | Total Loss 150.010025 | Sim 041
# Iter 0060 | Total Loss 129.307938 | Sim 041
# Iter 0060 | Total Loss 129.307938 | Sim 041
# Iter 0065 | Total Loss 113.446236 | Sim 041
# Iter 0065 | Total Loss 113.446236 | Sim 041
# Iter 0070 | Total Loss 101.134262 | Sim 041
# Iter 0070 | Total Loss 101.134262 | Sim 041
# Iter 0075 | Total Loss 92.612770 | Sim 041
# Iter 0075 | Total Loss 92.612770 | Sim 041
# Iter 0080 | Total Loss 86.577126 | Sim 041
# Iter 0080 | Total Loss 86.577126 | Sim 041
# Iter 0085 | Total Loss 82.286293 | Sim 041
# Iter 0085 | Total Loss 82.286293 | Sim 041
# Iter 0090 | Total Loss 80.214005 | Sim 041
# Iter 0090 | Total Loss 80.214005 | Sim 041
# Iter 0095 | Total Loss 79.160400 | Sim 041
# Iter 0095 | Total Loss 79.160400 | Sim 041
# Iter 0100 | Total Loss 80.504822 | Sim 041
# Iter 0100 | Total Loss 80.504822 | Sim 041
# Iter 0105 | Total Loss 81.919151 | Sim 041
# Iter 0105 | Total Loss 81.919151 | Sim 041
# Iter 0110 | Total Loss 82.846924 | Sim 041
# Iter 0110 | Total Loss 82.846924 | Sim 041
# Iter 0115 | Total Loss 83.152992 | Sim 041
# Iter 0115 | Total Loss 83.152992 | Sim 041
# Iter 0120 | Total Loss 81.377518 | Sim 041
# Iter 0120 | Total Loss 81.377518 | Sim 041
# Iter 0125 | Total Loss 79.334564 | Sim 041
# Iter 0125 | Total Loss 79.334564 | Sim 041
# Iter 0130 | Total Loss 77.519463 | Sim 041
# Iter 0130 | Total Loss 77.519463 | Sim 041
# Iter 0135 | Total Loss 78.530838 | Sim 041
# Iter 0135 | Total Loss 78.530838 | Sim 041
# Iter 0140 | Total Loss 80.729492 | Sim 041
# Iter 0140 | Total Loss 80.729492 | Sim 041
# Iter 0145 | Total Loss 83.282936 | Sim 041
# Iter 0145 | Total Loss 83.282936 | Sim 041
# Iter 0150 | Total Loss 82.642441 | Sim 041
# Iter 0150 | Total Loss 82.642441 | Sim 041
# Iter 0155 | Total Loss 82.699112 | Sim 041
# Iter 0155 | Total Loss 82.699112 | Sim 041
# Iter 0160 | Total Loss 81.063789 | Sim 041
# Iter 0160 | Total Loss 81.063789 | Sim 041
# Iter 0165 | Total Loss 81.170959 | Sim 041
# Iter 0165 | Total Loss 81.170959 | Sim 041
# Iter 0170 | Total Loss 80.597557 | Sim 041
# Iter 0170 | Total Loss 80.597557 | Sim 041
# Iter 0175 | Total Loss 77.870667 | Sim 041
# Iter 0175 | Total Loss 77.870667 | Sim 041
# Iter 0180 | Total Loss 74.822464 | Sim 041
# Iter 0180 | Total Loss 74.822464 | Sim 041
# Iter 0185 | Total Loss 71.672302 | Sim 041
# Iter 0185 | Total Loss 71.672302 | Sim 041
# Iter 0190 | Total Loss 69.786995 | Sim 041
# Iter 0190 | Total Loss 69.786995 | Sim 041
# Iter 0195 | Total Loss 69.529747 | Sim 041
# Iter 0195 | Total Loss 69.529747 | Sim 041
# Iter 0200 | Total Loss 70.515427 | Sim 041
# Iter 0200 | Total Loss 70.515427 | Sim 041
# Iter 0205 | Total Loss 72.891014 | Sim 041
# Iter 0205 | Total Loss 72.891014 | Sim 041
# Iter 0210 | Total Loss 75.779388 | Sim 041
# Iter 0210 | Total Loss 75.779388 | Sim 041
# Iter 0215 | Total Loss 77.742180 | Sim 041
# Iter 0215 | Total Loss 77.742180 | Sim 041
# Iter 0220 | Total Loss 76.898041 | Sim 041
# Iter 0220 | Total Loss 76.898041 | Sim 041
# Iter 0225 | Total Loss 77.374306 | Sim 041
# Iter 0225 | Total Loss 77.374306 | Sim 041
# Iter 0230 | Total Loss 78.673134 | Sim 041
# Iter 0230 | Total Loss 78.673134 | Sim 041
# Iter 0235 | Total Loss 81.063339 | Sim 041
# Iter 0235 | Total Loss 81.063339 | Sim 041
# Iter 0240 | Total Loss 81.353813 | Sim 041
# Iter 0240 | Total Loss 81.353813 | Sim 041
# Iter 0245 | Total Loss 80.382690 | Sim 041
# Iter 0245 | Total Loss 80.382690 | Sim 041
# Iter 0250 | Total Loss 76.939781 | Sim 041
# Iter 0250 | Total Loss 76.939781 | Sim 041
# Iter 0255 | Total Loss 74.178268 | Sim 041
# Iter 0255 | Total Loss 74.178268 | Sim 041
# Iter 0260 | Total Loss 72.891899 | Sim 041
# Iter 0260 | Total Loss 72.891899 | Sim 041
# Iter 0265 | Total Loss 72.467583 | Sim 041
# Iter 0265 | Total Loss 72.467583 | Sim 041
# Iter 0270 | Total Loss 72.711456 | Sim 041
# Iter 0270 | Total Loss 72.711456 | Sim 041
# Iter 0275 | Total Loss 74.167122 | Sim 041
# Iter 0275 | Total Loss 74.167122 | Sim 041
# Iter 0280 | Total Loss 75.752396 | Sim 041
# Iter 0280 | Total Loss 75.752396 | Sim 041
# Iter 0285 | Total Loss 78.500008 | Sim 041
# Iter 0285 | Total Loss 78.500008 | Sim 041
# Iter 0290 | Total Loss 82.417374 | Sim 041
# Iter 0290 | Total Loss 82.417374 | Sim 041
# Iter 0295 | Total Loss 85.227669 | Sim 041
# Iter 0295 | Total Loss 85.227669 | Sim 041
# Iter 0300 | Total Loss 83.910393 | Sim 041
# Iter 0300 | Total Loss 83.910393 | Sim 041
# Iter 0305 | Total Loss 82.427414 | Sim 041
# Iter 0305 | Total Loss 82.427414 | Sim 041
# Iter 0310 | Total Loss 80.403008 | Sim 041
# Iter 0310 | Total Loss 80.403008 | Sim 041
# Iter 0315 | Total Loss 79.681610 | Sim 041
# Iter 0315 | Total Loss 79.681610 | Sim 041
# Iter 0320 | Total Loss 78.395638 | Sim 041
# Iter 0320 | Total Loss 78.395638 | Sim 041
# Iter 0325 | Total Loss 75.437012 | Sim 041
# Iter 0325 | Total Loss 75.437012 | Sim 041
# Iter 0330 | Total Loss 75.910332 | Sim 041
# Iter 0330 | Total Loss 75.910332 | Sim 041
# Iter 0335 | Total Loss 76.876770 | Sim 041
# Iter 0335 | Total Loss 76.876770 | Sim 041
# Iter 0340 | Total Loss 75.505013 | Sim 041
# Iter 0340 | Total Loss 75.505013 | Sim 041
# Iter 0345 | Total Loss 75.764885 | Sim 041
# Iter 0345 | Total Loss 75.764885 | Sim 041
# Iter 0350 | Total Loss 75.014580 | Sim 041
# Iter 0350 | Total Loss 75.014580 | Sim 041
# Iter 0355 | Total Loss 74.690964 | Sim 041
# Iter 0355 | Total Loss 74.690964 | Sim 041
# Iter 0360 | Total Loss 74.230728 | Sim 041
# Iter 0360 | Total Loss 74.230728 | Sim 041
# Iter 0365 | Total Loss 75.744614 | Sim 041
# Iter 0365 | Total Loss 75.744614 | Sim 041
# Iter 0370 | Total Loss 73.978203 | Sim 041
# Iter 0370 | Total Loss 73.978203 | Sim 041
# Iter 0375 | Total Loss 70.658447 | Sim 041
# Iter 0375 | Total Loss 70.658447 | Sim 041
# Iter 0380 | Total Loss 69.129646 | Sim 041
# Iter 0380 | Total Loss 69.129646 | Sim 041
# Iter 0385 | Total Loss 70.171204 | Sim 041
# Iter 0385 | Total Loss 70.171204 | Sim 041
# Iter 0390 | Total Loss 70.942711 | Sim 041
# Iter 0390 | Total Loss 70.942711 | Sim 041
# Iter 0395 | Total Loss 74.183945 | Sim 041
# Iter 0395 | Total Loss 74.183945 | Sim 041
# Iter 0400 | Total Loss 78.835785 | Sim 041
# Iter 0400 | Total Loss 78.835785 | Sim 041
# Iter 0405 | Total Loss 81.873917 | Sim 041
# Iter 0405 | Total Loss 81.873917 | Sim 041
# Iter 0410 | Total Loss 81.083466 | Sim 041
# Iter 0410 | Total Loss 81.083466 | Sim 041
# Iter 0415 | Total Loss 79.199463 | Sim 041
# Iter 0415 | Total Loss 79.199463 | Sim 041
# Iter 0420 | Total Loss 78.085663 | Sim 041
# Iter 0420 | Total Loss 78.085663 | Sim 041
# Iter 0425 | Total Loss 78.370071 | Sim 041
# Iter 0425 | Total Loss 78.370071 | Sim 041
# Iter 0430 | Total Loss 79.056381 | Sim 041
# Iter 0430 | Total Loss 79.056381 | Sim 041
# Iter 0435 | Total Loss 79.412239 | Sim 041
# Iter 0435 | Total Loss 79.412239 | Sim 041
# Iter 0440 | Total Loss 80.091125 | Sim 041
# Iter 0440 | Total Loss 80.091125 | Sim 041
# Iter 0445 | Total Loss 83.572556 | Sim 041
# Iter 0445 | Total Loss 83.572556 | Sim 041
# Iter 0450 | Total Loss 84.090630 | Sim 041
# Iter 0450 | Total Loss 84.090630 | Sim 041
# Iter 0455 | Total Loss 83.031105 | Sim 041
# Iter 0455 | Total Loss 83.031105 | Sim 041
# Iter 0460 | Total Loss 82.379608 | Sim 041
# Iter 0460 | Total Loss 82.379608 | Sim 041
# Iter 0465 | Total Loss 81.492920 | Sim 041
# Iter 0465 | Total Loss 81.492920 | Sim 041
# Iter 0470 | Total Loss 79.296288 | Sim 041
# Iter 0470 | Total Loss 79.296288 | Sim 041
# Iter 0475 | Total Loss 76.430077 | Sim 041
# Iter 0475 | Total Loss 76.430077 | Sim 041
# Iter 0480 | Total Loss 74.158813 | Sim 041
# Iter 0480 | Total Loss 74.158813 | Sim 041
# Iter 0485 | Total Loss 71.577911 | Sim 041
# Iter 0485 | Total Loss 71.577911 | Sim 041
# Iter 0490 | Total Loss 68.381622 | Sim 041
# Iter 0490 | Total Loss 68.381622 | Sim 041
# Iter 0495 | Total Loss 68.182236 | Sim 041
# Iter 0495 | Total Loss 68.182236 | Sim 041
# Iter 0500 | Total Loss 70.990654 | Sim 041
# Iter 0500 | Total Loss 70.990654 | Sim 041
# Iter 0505 | Total Loss 71.900040 | Sim 041
# Iter 0505 | Total Loss 71.900040 | Sim 041
# Iter 0510 | Total Loss 71.831009 | Sim 041
# Iter 0510 | Total Loss 71.831009 | Sim 041
# Iter 0515 | Total Loss 73.922325 | Sim 041
# Iter 0515 | Total Loss 73.922325 | Sim 041
# Iter 0520 | Total Loss 75.987076 | Sim 041
# Iter 0520 | Total Loss 75.987076 | Sim 041
# Iter 0525 | Total Loss 75.947365 | Sim 041
# Iter 0525 | Total Loss 75.947365 | Sim 041
# Iter 0530 | Total Loss 75.861816 | Sim 041
# Iter 0530 | Total Loss 75.861816 | Sim 041
# Iter 0535 | Total Loss 77.020805 | Sim 041
# Iter 0535 | Total Loss 77.020805 | Sim 041
# Iter 0540 | Total Loss 82.953506 | Sim 041
# Iter 0540 | Total Loss 82.953506 | Sim 041
# Iter 0545 | Total Loss 83.421524 | Sim 041
# Iter 0545 | Total Loss 83.421524 | Sim 041
# Iter 0550 | Total Loss 82.159103 | Sim 041
# Iter 0550 | Total Loss 82.159103 | Sim 041
# Iter 0555 | Total Loss 79.977592 | Sim 041
# Iter 0555 | Total Loss 79.977592 | Sim 041
# Iter 0560 | Total Loss 78.536385 | Sim 041
# Iter 0560 | Total Loss 78.536385 | Sim 041
# Iter 0565 | Total Loss 76.281250 | Sim 041
# Iter 0565 | Total Loss 76.281250 | Sim 041
# Iter 0570 | Total Loss 77.712944 | Sim 041
# Iter 0570 | Total Loss 77.712944 | Sim 041
# Iter 0575 | Total Loss 80.098022 | Sim 041
# Iter 0575 | Total Loss 80.098022 | Sim 041
# Iter 0580 | Total Loss 80.600189 | Sim 041
# Iter 0580 | Total Loss 80.600189 | Sim 041
# Iter 0585 | Total Loss 78.720032 | Sim 041
# Iter 0585 | Total Loss 78.720032 | Sim 041
# Iter 0590 | Total Loss 74.107086 | Sim 041
# Iter 0590 | Total Loss 74.107086 | Sim 041
# Iter 0595 | Total Loss 72.958435 | Sim 041
# Iter 0595 | Total Loss 72.958435 | Sim 041
# Iter 0600 | Total Loss 73.760094 | Sim 041
# Iter 0600 | Total Loss 73.760094 | Sim 041
# Iter 0605 | Total Loss 74.530823 | Sim 041
# Iter 0605 | Total Loss 74.530823 | Sim 041
# Iter 0610 | Total Loss 76.943169 | Sim 041
# Iter 0610 | Total Loss 76.943169 | Sim 041
# Iter 0615 | Total Loss 81.680962 | Sim 041
# Iter 0615 | Total Loss 81.680962 | Sim 041
# Iter 0620 | Total Loss 83.267395 | Sim 041
# Iter 0620 | Total Loss 83.267395 | Sim 041
# Iter 0625 | Total Loss 82.266083 | Sim 041
# Iter 0625 | Total Loss 82.266083 | Sim 041
# Iter 0630 | Total Loss 80.835106 | Sim 041
# Iter 0630 | Total Loss 80.835106 | Sim 041
# Iter 0635 | Total Loss 79.932602 | Sim 041
# Iter 0635 | Total Loss 79.932602 | Sim 041
# Iter 0640 | Total Loss 76.062408 | Sim 041
# Iter 0640 | Total Loss 76.062408 | Sim 041
# Iter 0645 | Total Loss 74.483528 | Sim 041
# Iter 0645 | Total Loss 74.483528 | Sim 041
# Iter 0650 | Total Loss 75.734848 | Sim 041
# Iter 0650 | Total Loss 75.734848 | Sim 041
# Iter 0655 | Total Loss 76.273552 | Sim 041
# Iter 0655 | Total Loss 76.273552 | Sim 041
# Iter 0660 | Total Loss 77.268570 | Sim 041
# Iter 0660 | Total Loss 77.268570 | Sim 041
# Iter 0665 | Total Loss 78.472343 | Sim 041
# Iter 0665 | Total Loss 78.472343 | Sim 041
# Iter 0670 | Total Loss 78.743164 | Sim 041
# Iter 0670 | Total Loss 78.743164 | Sim 041
# Iter 0675 | Total Loss 77.220543 | Sim 041
# Iter 0675 | Total Loss 77.220543 | Sim 041
# Iter 0680 | Total Loss 74.927055 | Sim 041
# Iter 0680 | Total Loss 74.927055 | Sim 041
# Iter 0685 | Total Loss 73.600410 | Sim 041
# Iter 0685 | Total Loss 73.600410 | Sim 041
# Iter 0690 | Total Loss 73.474236 | Sim 041
# Iter 0690 | Total Loss 73.474236 | Sim 041
# Iter 0695 | Total Loss 74.570595 | Sim 041
# Iter 0695 | Total Loss 74.570595 | Sim 041
# Iter 0700 | Total Loss 77.826477 | Sim 041
# Iter 0700 | Total Loss 77.826477 | Sim 041
# Iter 0705 | Total Loss 81.710617 | Sim 041
# Iter 0705 | Total Loss 81.710617 | Sim 041
# Iter 0710 | Total Loss 81.786682 | Sim 041
# Iter 0710 | Total Loss 81.786682 | Sim 041
# Iter 0715 | Total Loss 79.225655 | Sim 041
# Iter 0715 | Total Loss 79.225655 | Sim 041
# Iter 0720 | Total Loss 76.065514 | Sim 041
# Iter 0720 | Total Loss 76.065514 | Sim 041
# Iter 0725 | Total Loss 73.645454 | Sim 041
# Iter 0725 | Total Loss 73.645454 | Sim 041
# Iter 0730 | Total Loss 71.112679 | Sim 041
# Iter 0730 | Total Loss 71.112679 | Sim 041
# Iter 0735 | Total Loss 70.432709 | Sim 041
# Iter 0735 | Total Loss 70.432709 | Sim 041
# Iter 0740 | Total Loss 72.446793 | Sim 041
# Iter 0740 | Total Loss 72.446793 | Sim 041
# Iter 0745 | Total Loss 77.770462 | Sim 041
# Iter 0745 | Total Loss 77.770462 | Sim 041
# Iter 0750 | Total Loss 80.978271 | Sim 041
# Iter 0750 | Total Loss 80.978271 | Sim 041
# Saved Model for Sim 041
#
# Saved Model for Sim 041
#
# ODEFunc(
#   (net1): Sequential(
#     (0): Linear(in_features=160, out_features=100, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=100, out_features=100, bias=True)
#     (3): Tanh()
#     (4): Linear(in_features=100, out_features=160, bias=True)
#   )
# )
# ODEFunc(
#   (net1): Sequential(
#     (0): Linear(in_features=160, out_features=100, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=100, out_features=100, bias=True)
#     (3): Tanh()
#     (4): Linear(in_features=100, out_features=160, bias=True)
#   )
# )
# Number of parameters: 42360
# Number of parameters: 42360
# Iter 0005 | Total Loss 1115.449341 | Sim 050
# Iter 0005 | Total Loss 1115.449341 | Sim 050
# Iter 0010 | Total Loss 1078.709351 | Sim 050
# Iter 0010 | Total Loss 1078.709351 | Sim 050
# Iter 0015 | Total Loss 1039.453735 | Sim 050
# Iter 0015 | Total Loss 1039.453735 | Sim 050
# Iter 0020 | Total Loss 998.743774 | Sim 050
# Iter 0020 | Total Loss 998.743774 | Sim 050
# Iter 0025 | Total Loss 956.741394 | Sim 050
# Iter 0025 | Total Loss 956.741394 | Sim 050
# Iter 0030 | Total Loss 913.932800 | Sim 050
# Iter 0030 | Total Loss 913.932800 | Sim 050
# Iter 0035 | Total Loss 869.844543 | Sim 050
# Iter 0035 | Total Loss 869.844543 | Sim 050
# Iter 0040 | Total Loss 825.414185 | Sim 050
# Iter 0040 | Total Loss 825.414185 | Sim 050
# Iter 0045 | Total Loss 781.164124 | Sim 050
# Iter 0045 | Total Loss 781.164124 | Sim 050
# Iter 0050 | Total Loss 737.635559 | Sim 050
# Iter 0050 | Total Loss 737.635559 | Sim 050
# Iter 0055 | Total Loss 694.115112 | Sim 050
# Iter 0055 | Total Loss 694.115112 | Sim 050
# Iter 0060 | Total Loss 651.032288 | Sim 050
# Iter 0060 | Total Loss 651.032288 | Sim 050
# Iter 0065 | Total Loss 609.030945 | Sim 050
# Iter 0065 | Total Loss 609.030945 | Sim 050
# Iter 0070 | Total Loss 567.551880 | Sim 050
# Iter 0070 | Total Loss 567.551880 | Sim 050
# Iter 0075 | Total Loss 527.288940 | Sim 050
# Iter 0075 | Total Loss 527.288940 | Sim 050
# Iter 0080 | Total Loss 487.415955 | Sim 050
# Iter 0080 | Total Loss 487.415955 | Sim 050
# Iter 0085 | Total Loss 448.078461 | Sim 050
# Iter 0085 | Total Loss 448.078461 | Sim 050
# Iter 0090 | Total Loss 409.304962 | Sim 050
# Iter 0090 | Total Loss 409.304962 | Sim 050
# Iter 0095 | Total Loss 371.277130 | Sim 050
# Iter 0095 | Total Loss 371.277130 | Sim 050
# Iter 0100 | Total Loss 334.441742 | Sim 050
# Iter 0100 | Total Loss 334.441742 | Sim 050
# Iter 0105 | Total Loss 298.382416 | Sim 050
# Iter 0105 | Total Loss 298.382416 | Sim 050
# Iter 0110 | Total Loss 263.377899 | Sim 050
# Iter 0110 | Total Loss 263.377899 | Sim 050
# Iter 0115 | Total Loss 229.853531 | Sim 050
# Iter 0115 | Total Loss 229.853531 | Sim 050
# Iter 0120 | Total Loss 197.429001 | Sim 050
# Iter 0120 | Total Loss 197.429001 | Sim 050
# Iter 0125 | Total Loss 166.608337 | Sim 050
# Iter 0125 | Total Loss 166.608337 | Sim 050
# Iter 0130 | Total Loss 138.468994 | Sim 050
# Iter 0130 | Total Loss 138.468994 | Sim 050
# Iter 0135 | Total Loss 113.333450 | Sim 050
# Iter 0135 | Total Loss 113.333450 | Sim 050
# Iter 0140 | Total Loss 90.654121 | Sim 050
# Iter 0140 | Total Loss 90.654121 | Sim 050
# Iter 0145 | Total Loss 71.602036 | Sim 050
# Iter 0145 | Total Loss 71.602036 | Sim 050
# Iter 0150 | Total Loss 56.443981 | Sim 050
# Iter 0150 | Total Loss 56.443981 | Sim 050
# Iter 0155 | Total Loss 45.656773 | Sim 050
# Iter 0155 | Total Loss 45.656773 | Sim 050
# Iter 0160 | Total Loss 38.851006 | Sim 050
# Iter 0160 | Total Loss 38.851006 | Sim 050
# Iter 0165 | Total Loss 35.039707 | Sim 050
# Iter 0165 | Total Loss 35.039707 | Sim 050
# Iter 0170 | Total Loss 32.960045 | Sim 050
# Iter 0170 | Total Loss 32.960045 | Sim 050
# Iter 0175 | Total Loss 31.265274 | Sim 050
# Iter 0175 | Total Loss 31.265274 | Sim 050
# Iter 0180 | Total Loss 29.483370 | Sim 050
# Iter 0180 | Total Loss 29.483370 | Sim 050
# Iter 0185 | Total Loss 28.519842 | Sim 050
# Iter 0185 | Total Loss 28.519842 | Sim 050
# Iter 0190 | Total Loss 27.482788 | Sim 050
# Iter 0190 | Total Loss 27.482788 | Sim 050
# Iter 0195 | Total Loss 26.913313 | Sim 050
# Iter 0195 | Total Loss 26.913313 | Sim 050
# Iter 0200 | Total Loss 26.891836 | Sim 050
# Iter 0200 | Total Loss 26.891836 | Sim 050
# Iter 0205 | Total Loss 26.703068 | Sim 050
# Iter 0205 | Total Loss 26.703068 | Sim 050
# Iter 0210 | Total Loss 26.447344 | Sim 050
# Iter 0210 | Total Loss 26.447344 | Sim 050
# Iter 0215 | Total Loss 26.179333 | Sim 050
# Iter 0215 | Total Loss 26.179333 | Sim 050
# Iter 0220 | Total Loss 26.235323 | Sim 050
# Iter 0220 | Total Loss 26.235323 | Sim 050
# Iter 0225 | Total Loss 26.554827 | Sim 050
# Iter 0225 | Total Loss 26.554827 | Sim 050
# Iter 0230 | Total Loss 26.956163 | Sim 050
# Iter 0230 | Total Loss 26.956163 | Sim 050
# Iter 0235 | Total Loss 27.056482 | Sim 050
# Iter 0235 | Total Loss 27.056482 | Sim 050
# Iter 0240 | Total Loss 27.563976 | Sim 050
# Iter 0240 | Total Loss 27.563976 | Sim 050
# Iter 0245 | Total Loss 28.090363 | Sim 050
# Iter 0245 | Total Loss 28.090363 | Sim 050
# Iter 0250 | Total Loss 27.524858 | Sim 050
# Iter 0250 | Total Loss 27.524858 | Sim 050
# Iter 0255 | Total Loss 27.373001 | Sim 050
# Iter 0255 | Total Loss 27.373001 | Sim 050
# Iter 0260 | Total Loss 27.628504 | Sim 050
# Iter 0260 | Total Loss 27.628504 | Sim 050
# Iter 0265 | Total Loss 27.291199 | Sim 050
# Iter 0265 | Total Loss 27.291199 | Sim 050
# Iter 0270 | Total Loss 27.215096 | Sim 050
# Iter 0270 | Total Loss 27.215096 | Sim 050
# Iter 0275 | Total Loss 26.886217 | Sim 050
# Iter 0275 | Total Loss 26.886217 | Sim 050
# Iter 0280 | Total Loss 26.743059 | Sim 050
# Iter 0280 | Total Loss 26.743059 | Sim 050
# Iter 0285 | Total Loss 26.887915 | Sim 050
# Iter 0285 | Total Loss 26.887915 | Sim 050
# Iter 0290 | Total Loss 27.070845 | Sim 050
# Iter 0290 | Total Loss 27.070845 | Sim 050
# Iter 0295 | Total Loss 27.094166 | Sim 050
# Iter 0295 | Total Loss 27.094166 | Sim 050
# Iter 0300 | Total Loss 27.222664 | Sim 050
# Iter 0300 | Total Loss 27.222664 | Sim 050
# Iter 0305 | Total Loss 27.922836 | Sim 050
# Iter 0305 | Total Loss 27.922836 | Sim 050
# Iter 0310 | Total Loss 28.583256 | Sim 050
# Iter 0310 | Total Loss 28.583256 | Sim 050
# Iter 0315 | Total Loss 29.370415 | Sim 050
# Iter 0315 | Total Loss 29.370415 | Sim 050
# Iter 0320 | Total Loss 28.979977 | Sim 050
# Iter 0320 | Total Loss 28.979977 | Sim 050
# Iter 0325 | Total Loss 27.941223 | Sim 050
# Iter 0325 | Total Loss 27.941223 | Sim 050
# Iter 0330 | Total Loss 27.508717 | Sim 050
# Iter 0330 | Total Loss 27.508717 | Sim 050
# Iter 0335 | Total Loss 27.341101 | Sim 050
# Iter 0335 | Total Loss 27.341101 | Sim 050
# Iter 0340 | Total Loss 27.539755 | Sim 050
# Iter 0340 | Total Loss 27.539755 | Sim 050
# Iter 0345 | Total Loss 28.064245 | Sim 050
# Iter 0345 | Total Loss 28.064245 | Sim 050
# Iter 0350 | Total Loss 29.043432 | Sim 050
# Iter 0350 | Total Loss 29.043432 | Sim 050
# Iter 0355 | Total Loss 29.985138 | Sim 050
# Iter 0355 | Total Loss 29.985138 | Sim 050
# Iter 0360 | Total Loss 31.140585 | Sim 050
# Iter 0360 | Total Loss 31.140585 | Sim 050
# Iter 0365 | Total Loss 32.916000 | Sim 050
# Iter 0365 | Total Loss 32.916000 | Sim 050
# Iter 0370 | Total Loss 34.520191 | Sim 050
# Iter 0370 | Total Loss 34.520191 | Sim 050
# Iter 0375 | Total Loss 33.776806 | Sim 050
# Iter 0375 | Total Loss 33.776806 | Sim 050
# Iter 0380 | Total Loss 31.446709 | Sim 050
# Iter 0380 | Total Loss 31.446709 | Sim 050
# Iter 0385 | Total Loss 29.180822 | Sim 050
# Iter 0385 | Total Loss 29.180822 | Sim 050
# Iter 0390 | Total Loss 28.565462 | Sim 050
# Iter 0390 | Total Loss 28.565462 | Sim 050
# Iter 0395 | Total Loss 27.833130 | Sim 050
# Iter 0395 | Total Loss 27.833130 | Sim 050
# Iter 0400 | Total Loss 27.346809 | Sim 050
# Iter 0400 | Total Loss 27.346809 | Sim 050
# Iter 0405 | Total Loss 26.581348 | Sim 050
# Iter 0405 | Total Loss 26.581348 | Sim 050
# Iter 0410 | Total Loss 26.362925 | Sim 050
# Iter 0410 | Total Loss 26.362925 | Sim 050
# Iter 0415 | Total Loss 26.376989 | Sim 050
# Iter 0415 | Total Loss 26.376989 | Sim 050
# Iter 0420 | Total Loss 26.365921 | Sim 050
# Iter 0420 | Total Loss 26.365921 | Sim 050
# Iter 0425 | Total Loss 26.662092 | Sim 050
# Iter 0425 | Total Loss 26.662092 | Sim 050
# Iter 0430 | Total Loss 26.973528 | Sim 050
# Iter 0430 | Total Loss 26.973528 | Sim 050
# Iter 0435 | Total Loss 27.469305 | Sim 050
# Iter 0435 | Total Loss 27.469305 | Sim 050
# Iter 0440 | Total Loss 28.957573 | Sim 050
# Iter 0440 | Total Loss 28.957573 | Sim 050
# Iter 0445 | Total Loss 30.173731 | Sim 050
# Iter 0445 | Total Loss 30.173731 | Sim 050
# Iter 0450 | Total Loss 30.748461 | Sim 050
# Iter 0450 | Total Loss 30.748461 | Sim 050
# Iter 0455 | Total Loss 31.425951 | Sim 050
# Iter 0455 | Total Loss 31.425951 | Sim 050
# Iter 0460 | Total Loss 29.755363 | Sim 050
# Iter 0460 | Total Loss 29.755363 | Sim 050
# Iter 0465 | Total Loss 28.969137 | Sim 050
# Iter 0465 | Total Loss 28.969137 | Sim 050
# Iter 0470 | Total Loss 30.506369 | Sim 050
# Iter 0470 | Total Loss 30.506369 | Sim 050
# Iter 0475 | Total Loss 31.120426 | Sim 050
# Iter 0475 | Total Loss 31.120426 | Sim 050
# Iter 0480 | Total Loss 30.692122 | Sim 050
# Iter 0480 | Total Loss 30.692122 | Sim 050
# Iter 0485 | Total Loss 30.279345 | Sim 050
# Iter 0485 | Total Loss 30.279345 | Sim 050
# Iter 0490 | Total Loss 30.742525 | Sim 050
# Iter 0490 | Total Loss 30.742525 | Sim 050
# Iter 0495 | Total Loss 30.839941 | Sim 050
# Iter 0495 | Total Loss 30.839941 | Sim 050
# Iter 0500 | Total Loss 30.551685 | Sim 050
# Iter 0500 | Total Loss 30.551685 | Sim 050
# Iter 0505 | Total Loss 30.618444 | Sim 050
# Iter 0505 | Total Loss 30.618444 | Sim 050
# Iter 0510 | Total Loss 30.369902 | Sim 050
# Iter 0510 | Total Loss 30.369902 | Sim 050
# Iter 0515 | Total Loss 30.328657 | Sim 050
# Iter 0515 | Total Loss 30.328657 | Sim 050
# Iter 0520 | Total Loss 29.657295 | Sim 050
# Iter 0520 | Total Loss 29.657295 | Sim 050
# Iter 0525 | Total Loss 30.188648 | Sim 050
# Iter 0525 | Total Loss 30.188648 | Sim 050
# Iter 0530 | Total Loss 30.409557 | Sim 050
# Iter 0530 | Total Loss 30.409557 | Sim 050
# Iter 0535 | Total Loss 29.977360 | Sim 050
# Iter 0535 | Total Loss 29.977360 | Sim 050
# Iter 0540 | Total Loss 30.651978 | Sim 050
# Iter 0540 | Total Loss 30.651978 | Sim 050
# Iter 0545 | Total Loss 30.240730 | Sim 050
# Iter 0545 | Total Loss 30.240730 | Sim 050
# Iter 0550 | Total Loss 28.628441 | Sim 050
# Iter 0550 | Total Loss 28.628441 | Sim 050
# Iter 0555 | Total Loss 29.448086 | Sim 050
# Iter 0555 | Total Loss 29.448086 | Sim 050
# Iter 0560 | Total Loss 30.421803 | Sim 050
# Iter 0560 | Total Loss 30.421803 | Sim 050
# Iter 0565 | Total Loss 31.200737 | Sim 050
# Iter 0565 | Total Loss 31.200737 | Sim 050
# Iter 0570 | Total Loss 31.691687 | Sim 050
# Iter 0570 | Total Loss 31.691687 | Sim 050
# Iter 0575 | Total Loss 32.374569 | Sim 050
# Iter 0575 | Total Loss 32.374569 | Sim 050
# Iter 0580 | Total Loss 32.365322 | Sim 050
# Iter 0580 | Total Loss 32.365322 | Sim 050
# Iter 0585 | Total Loss 31.858194 | Sim 050
# Iter 0585 | Total Loss 31.858194 | Sim 050
# Iter 0590 | Total Loss 32.217464 | Sim 050
# Iter 0590 | Total Loss 32.217464 | Sim 050
# Iter 0595 | Total Loss 31.577925 | Sim 050
# Iter 0595 | Total Loss 31.577925 | Sim 050
# Iter 0600 | Total Loss 32.247421 | Sim 050
# Iter 0600 | Total Loss 32.247421 | Sim 050
# Iter 0605 | Total Loss 32.250538 | Sim 050
# Iter 0605 | Total Loss 32.250538 | Sim 050
# Iter 0610 | Total Loss 31.196667 | Sim 050
# Iter 0610 | Total Loss 31.196667 | Sim 050
# Iter 0615 | Total Loss 31.811625 | Sim 050
# Iter 0615 | Total Loss 31.811625 | Sim 050
# Iter 0620 | Total Loss 33.184490 | Sim 050
# Iter 0620 | Total Loss 33.184490 | Sim 050
# Iter 0625 | Total Loss 34.914600 | Sim 050
# Iter 0625 | Total Loss 34.914600 | Sim 050
# Iter 0630 | Total Loss 38.079689 | Sim 050
# Iter 0630 | Total Loss 38.079689 | Sim 050
# Iter 0635 | Total Loss 37.060928 | Sim 050
# Iter 0635 | Total Loss 37.060928 | Sim 050
# Iter 0640 | Total Loss 32.399323 | Sim 050
# Iter 0640 | Total Loss 32.399323 | Sim 050
# Iter 0645 | Total Loss 29.944244 | Sim 050
# Iter 0645 | Total Loss 29.944244 | Sim 050
# Iter 0650 | Total Loss 28.784859 | Sim 050
# Iter 0650 | Total Loss 28.784859 | Sim 050
# Iter 0655 | Total Loss 27.567659 | Sim 050
# Iter 0655 | Total Loss 27.567659 | Sim 050
# Iter 0660 | Total Loss 27.335274 | Sim 050
# Iter 0660 | Total Loss 27.335274 | Sim 050
# Iter 0665 | Total Loss 28.314974 | Sim 050
# Iter 0665 | Total Loss 28.314974 | Sim 050
# Iter 0670 | Total Loss 29.364094 | Sim 050
# Iter 0670 | Total Loss 29.364094 | Sim 050
# Iter 0675 | Total Loss 32.044407 | Sim 050
# Iter 0675 | Total Loss 32.044407 | Sim 050
# Iter 0680 | Total Loss 31.763420 | Sim 050
# Iter 0680 | Total Loss 31.763420 | Sim 050
# Iter 0685 | Total Loss 32.380508 | Sim 050
# Iter 0685 | Total Loss 32.380508 | Sim 050
# Iter 0690 | Total Loss 32.539906 | Sim 050
# Iter 0690 | Total Loss 32.539906 | Sim 050
# Iter 0695 | Total Loss 30.832268 | Sim 050
# Iter 0695 | Total Loss 30.832268 | Sim 050
# Iter 0700 | Total Loss 28.936003 | Sim 050
# Iter 0700 | Total Loss 28.936003 | Sim 050
# Iter 0705 | Total Loss 27.762106 | Sim 050
# Iter 0705 | Total Loss 27.762106 | Sim 050
# Iter 0710 | Total Loss 26.979942 | Sim 050
# Iter 0710 | Total Loss 26.979942 | Sim 050
# Iter 0715 | Total Loss 26.719891 | Sim 050
# Iter 0715 | Total Loss 26.719891 | Sim 050
# Iter 0720 | Total Loss 27.246635 | Sim 050
# Iter 0720 | Total Loss 27.246635 | Sim 050
# Iter 0725 | Total Loss 28.495909 | Sim 050
# Iter 0725 | Total Loss 28.495909 | Sim 050
# Iter 0730 | Total Loss 30.513809 | Sim 050
# Iter 0730 | Total Loss 30.513809 | Sim 050
# Iter 0735 | Total Loss 31.428202 | Sim 050
# Iter 0735 | Total Loss 31.428202 | Sim 050
# Iter 0740 | Total Loss 31.021399 | Sim 050
# Iter 0740 | Total Loss 31.021399 | Sim 050
# Iter 0745 | Total Loss 30.665014 | Sim 050
# Iter 0745 | Total Loss 30.665014 | Sim 050
# Iter 0750 | Total Loss 30.098549 | Sim 050
# Iter 0750 | Total Loss 30.098549 | Sim 050
# Saved Model for Sim 050
#
# Saved Model for Sim 050
#
# ODEFunc(
#   (net1): Sequential(
#     (0): Linear(in_features=160, out_features=100, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=100, out_features=100, bias=True)
#     (3): Tanh()
#     (4): Linear(in_features=100, out_features=160, bias=True)
#   )
# )
# ODEFunc(
#   (net1): Sequential(
#     (0): Linear(in_features=160, out_features=100, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=100, out_features=100, bias=True)
#     (3): Tanh()
#     (4): Linear(in_features=100, out_features=160, bias=True)
#   )
# )
# Number of parameters: 42360
# Number of parameters: 42360
# Iter 0005 | Total Loss 1064.646240 | Sim 051
# Iter 0005 | Total Loss 1064.646240 | Sim 051
# Iter 0010 | Total Loss 1024.487549 | Sim 051
# Iter 0010 | Total Loss 1024.487549 | Sim 051
# Iter 0015 | Total Loss 983.119385 | Sim 051
# Iter 0015 | Total Loss 983.119385 | Sim 051
# Iter 0020 | Total Loss 941.198120 | Sim 051
# Iter 0020 | Total Loss 941.198120 | Sim 051
# Iter 0025 | Total Loss 899.230713 | Sim 051
# Iter 0025 | Total Loss 899.230713 | Sim 051
# Iter 0030 | Total Loss 856.752319 | Sim 051
# Iter 0030 | Total Loss 856.752319 | Sim 051
# Iter 0035 | Total Loss 813.803101 | Sim 051
# Iter 0035 | Total Loss 813.803101 | Sim 051
# Iter 0040 | Total Loss 770.440430 | Sim 051
# Iter 0040 | Total Loss 770.440430 | Sim 051
# Iter 0045 | Total Loss 727.225159 | Sim 051
# Iter 0045 | Total Loss 727.225159 | Sim 051
# Iter 0050 | Total Loss 684.155579 | Sim 051
# Iter 0050 | Total Loss 684.155579 | Sim 051
# Iter 0055 | Total Loss 641.445679 | Sim 051
# Iter 0055 | Total Loss 641.445679 | Sim 051
# Iter 0060 | Total Loss 598.930054 | Sim 051
# Iter 0060 | Total Loss 598.930054 | Sim 051
# Iter 0065 | Total Loss 557.022827 | Sim 051
# Iter 0065 | Total Loss 557.022827 | Sim 051
# Iter 0070 | Total Loss 515.434082 | Sim 051
# Iter 0070 | Total Loss 515.434082 | Sim 051
# Iter 0075 | Total Loss 474.499542 | Sim 051
# Iter 0075 | Total Loss 474.499542 | Sim 051
# Iter 0080 | Total Loss 434.831268 | Sim 051
# Iter 0080 | Total Loss 434.831268 | Sim 051
# Iter 0085 | Total Loss 396.210571 | Sim 051
# Iter 0085 | Total Loss 396.210571 | Sim 051
# Iter 0090 | Total Loss 358.923096 | Sim 051
# Iter 0090 | Total Loss 358.923096 | Sim 051
# Iter 0095 | Total Loss 322.384308 | Sim 051
# Iter 0095 | Total Loss 322.384308 | Sim 051
# Iter 0100 | Total Loss 287.984863 | Sim 051
# Iter 0100 | Total Loss 287.984863 | Sim 051
# Iter 0105 | Total Loss 255.271378 | Sim 051
# Iter 0105 | Total Loss 255.271378 | Sim 051
# Iter 0110 | Total Loss 223.382294 | Sim 051
# Iter 0110 | Total Loss 223.382294 | Sim 051
# Iter 0115 | Total Loss 192.092010 | Sim 051
# Iter 0115 | Total Loss 192.092010 | Sim 051
# Iter 0120 | Total Loss 161.824829 | Sim 051
# Iter 0120 | Total Loss 161.824829 | Sim 051
# Iter 0125 | Total Loss 134.265274 | Sim 051
# Iter 0125 | Total Loss 134.265274 | Sim 051
# Iter 0130 | Total Loss 110.522552 | Sim 051
# Iter 0130 | Total Loss 110.522552 | Sim 051
# Iter 0135 | Total Loss 89.351425 | Sim 051
# Iter 0135 | Total Loss 89.351425 | Sim 051
# Iter 0140 | Total Loss 72.096771 | Sim 051
# Iter 0140 | Total Loss 72.096771 | Sim 051
# Iter 0145 | Total Loss 59.629230 | Sim 051
# Iter 0145 | Total Loss 59.629230 | Sim 051
# Iter 0150 | Total Loss 50.090714 | Sim 051
# Iter 0150 | Total Loss 50.090714 | Sim 051
# Iter 0155 | Total Loss 43.461952 | Sim 051
# Iter 0155 | Total Loss 43.461952 | Sim 051
# Iter 0160 | Total Loss 39.402107 | Sim 051
# Iter 0160 | Total Loss 39.402107 | Sim 051
# Iter 0165 | Total Loss 37.306049 | Sim 051
# Iter 0165 | Total Loss 37.306049 | Sim 051
# Iter 0170 | Total Loss 35.600227 | Sim 051
# Iter 0170 | Total Loss 35.600227 | Sim 051
# Iter 0175 | Total Loss 35.044464 | Sim 051
# Iter 0175 | Total Loss 35.044464 | Sim 051
# Iter 0180 | Total Loss 35.696686 | Sim 051
# Iter 0180 | Total Loss 35.696686 | Sim 051
# Iter 0185 | Total Loss 34.888626 | Sim 051
# Iter 0185 | Total Loss 34.888626 | Sim 051
# Iter 0190 | Total Loss 33.521412 | Sim 051
# Iter 0190 | Total Loss 33.521412 | Sim 051
# Iter 0195 | Total Loss 32.650963 | Sim 051
# Iter 0195 | Total Loss 32.650963 | Sim 051
# Iter 0200 | Total Loss 31.573103 | Sim 051
# Iter 0200 | Total Loss 31.573103 | Sim 051
# Iter 0205 | Total Loss 31.163273 | Sim 051
# Iter 0205 | Total Loss 31.163273 | Sim 051
# Iter 0210 | Total Loss 31.651871 | Sim 051
# Iter 0210 | Total Loss 31.651871 | Sim 051
# Iter 0215 | Total Loss 32.452785 | Sim 051
# Iter 0215 | Total Loss 32.452785 | Sim 051
# Iter 0220 | Total Loss 32.769112 | Sim 051
# Iter 0220 | Total Loss 32.769112 | Sim 051
# Iter 0225 | Total Loss 33.204147 | Sim 051
# Iter 0225 | Total Loss 33.204147 | Sim 051
# Iter 0230 | Total Loss 33.558540 | Sim 051
# Iter 0230 | Total Loss 33.558540 | Sim 051
# Iter 0235 | Total Loss 34.251183 | Sim 051
# Iter 0235 | Total Loss 34.251183 | Sim 051
# Iter 0240 | Total Loss 35.075459 | Sim 051
# Iter 0240 | Total Loss 35.075459 | Sim 051
# Iter 0245 | Total Loss 35.611740 | Sim 051
# Iter 0245 | Total Loss 35.611740 | Sim 051
# Iter 0250 | Total Loss 36.315147 | Sim 051
# Iter 0250 | Total Loss 36.315147 | Sim 051
# Iter 0255 | Total Loss 38.353622 | Sim 051
# Iter 0255 | Total Loss 38.353622 | Sim 051
# Iter 0260 | Total Loss 39.610382 | Sim 051
# Iter 0260 | Total Loss 39.610382 | Sim 051
# Iter 0265 | Total Loss 40.827873 | Sim 051
# Iter 0265 | Total Loss 40.827873 | Sim 051
# Iter 0270 | Total Loss 40.195404 | Sim 051
# Iter 0270 | Total Loss 40.195404 | Sim 051
# Iter 0275 | Total Loss 38.773319 | Sim 051
# Iter 0275 | Total Loss 38.773319 | Sim 051
# Iter 0280 | Total Loss 37.458603 | Sim 051
# Iter 0280 | Total Loss 37.458603 | Sim 051
# Iter 0285 | Total Loss 38.678383 | Sim 051
# Iter 0285 | Total Loss 38.678383 | Sim 051
# Iter 0290 | Total Loss 39.612812 | Sim 051
# Iter 0290 | Total Loss 39.612812 | Sim 051
# Iter 0295 | Total Loss 39.187904 | Sim 051
# Iter 0295 | Total Loss 39.187904 | Sim 051
# Iter 0300 | Total Loss 37.731178 | Sim 051
# Iter 0300 | Total Loss 37.731178 | Sim 051
# Iter 0305 | Total Loss 35.963196 | Sim 051
# Iter 0305 | Total Loss 35.963196 | Sim 051
# Iter 0310 | Total Loss 34.595291 | Sim 051
# Iter 0310 | Total Loss 34.595291 | Sim 051
# Iter 0315 | Total Loss 34.088398 | Sim 051
# Iter 0315 | Total Loss 34.088398 | Sim 051
# Iter 0320 | Total Loss 33.326393 | Sim 051
# Iter 0320 | Total Loss 33.326393 | Sim 051
# Iter 0325 | Total Loss 33.986206 | Sim 051
# Iter 0325 | Total Loss 33.986206 | Sim 051
# Iter 0330 | Total Loss 36.690174 | Sim 051
# Iter 0330 | Total Loss 36.690174 | Sim 051
# ...
# Iter 0440 | Total Loss 27.718262 | Sim 054
# Iter 0445 | Total Loss 28.434944 | Sim 054
# Iter 0445 | Total Loss 28.434944 | Sim 054
# Iter 0450 | Total Loss 28.374369 | Sim 054
# Iter 0450 | Total Loss 28.374369 | Sim 054
# Iter 0455 | Total Loss 29.144295 | Sim 054
# Iter 0455 | Total Loss 29.144295 | Sim 054
# Iter 0460 | Total Loss 30.727287 | Sim 054
# Iter 0460 | Total Loss 30.727287 | Sim 054
# Iter 0465 | Total Loss 29.608253 | Sim 054
# Iter 0465 | Total Loss 29.608253 | Sim 054
# Iter 0470 | Total Loss 28.018888 | Sim 054
# Iter 0470 | Total Loss 28.018888 | Sim 054
# Iter 0475 | Total Loss 28.046566 | Sim 054
# Iter 0475 | Total Loss 28.046566 | Sim 054
# Iter 0480 | Total Loss 28.142206 | Sim 054
# Iter 0480 | Total Loss 28.142206 | Sim 054
# Iter 0485 | Total Loss 29.362383 | Sim 054
# Iter 0485 | Total Loss 29.362383 | Sim 054
# Iter 0490 | Total Loss 29.420731 | Sim 054
# Iter 0490 | Total Loss 29.420731 | Sim 054
# Iter 0495 | Total Loss 28.219248 | Sim 054
# Iter 0495 | Total Loss 28.219248 | Sim 054
# Iter 0500 | Total Loss 27.678070 | Sim 054
# Iter 0500 | Total Loss 27.678070 | Sim 054
# Iter 0505 | Total Loss 27.771496 | Sim 054
# Iter 0505 | Total Loss 27.771496 | Sim 054
# Iter 0510 | Total Loss 28.151154 | Sim 054
# Iter 0510 | Total Loss 28.151154 | Sim 054
# Iter 0515 | Total Loss 28.986162 | Sim 054
# Iter 0515 | Total Loss 28.986162 | Sim 054
# Iter 0520 | Total Loss 29.931309 | Sim 054
# Iter 0520 | Total Loss 29.931309 | Sim 054
# Iter 0525 | Total Loss 28.737030 | Sim 054
# Iter 0525 | Total Loss 28.737030 | Sim 054
# Iter 0530 | Total Loss 27.763161 | Sim 054
# Iter 0530 | Total Loss 27.763161 | Sim 054
# Iter 0535 | Total Loss 27.916830 | Sim 054
# Iter 0535 | Total Loss 27.916830 | Sim 054
# Iter 0540 | Total Loss 27.998411 | Sim 054
# Iter 0540 | Total Loss 27.998411 | Sim 054
# Iter 0545 | Total Loss 28.055361 | Sim 054
# Iter 0545 | Total Loss 28.055361 | Sim 054
# Iter 0550 | Total Loss 28.467747 | Sim 054
# Iter 0550 | Total Loss 28.467747 | Sim 054
# Iter 0555 | Total Loss 29.450241 | Sim 054
# Iter 0555 | Total Loss 29.450241 | Sim 054
# Iter 0560 | Total Loss 30.028793 | Sim 054
# Iter 0560 | Total Loss 30.028793 | Sim 054
# Iter 0565 | Total Loss 29.092991 | Sim 054
# Iter 0565 | Total Loss 29.092991 | Sim 054
# Iter 0570 | Total Loss 28.739271 | Sim 054
# Iter 0570 | Total Loss 28.739271 | Sim 054
# Iter 0575 | Total Loss 28.383554 | Sim 054
# Iter 0575 | Total Loss 28.383554 | Sim 054
# Iter 0580 | Total Loss 29.112673 | Sim 054
# Iter 0580 | Total Loss 29.112673 | Sim 054
# Iter 0585 | Total Loss 28.872576 | Sim 054
# Iter 0585 | Total Loss 28.872576 | Sim 054
# Iter 0590 | Total Loss 28.970383 | Sim 054
# Iter 0590 | Total Loss 28.970383 | Sim 054
# Iter 0595 | Total Loss 28.898182 | Sim 054
# Iter 0595 | Total Loss 28.898182 | Sim 054
# Iter 0600 | Total Loss 28.456797 | Sim 054
# Iter 0600 | Total Loss 28.456797 | Sim 054
# Iter 0605 | Total Loss 27.369602 | Sim 054
# Iter 0605 | Total Loss 27.369602 | Sim 054
# Iter 0610 | Total Loss 27.553091 | Sim 054
# Iter 0610 | Total Loss 27.553091 | Sim 054
# Iter 0615 | Total Loss 27.160563 | Sim 054
# Iter 0615 | Total Loss 27.160563 | Sim 054
# Iter 0620 | Total Loss 27.997393 | Sim 054
# Iter 0620 | Total Loss 27.997393 | Sim 054
# Iter 0625 | Total Loss 28.315306 | Sim 054
# Iter 0625 | Total Loss 28.315306 | Sim 054
# Iter 0630 | Total Loss 28.625835 | Sim 054
# Iter 0630 | Total Loss 28.625835 | Sim 054
# Iter 0635 | Total Loss 29.627357 | Sim 054
# Iter 0635 | Total Loss 29.627357 | Sim 054
# Iter 0640 | Total Loss 30.825504 | Sim 054
# Iter 0640 | Total Loss 30.825504 | Sim 054
# Iter 0645 | Total Loss 30.918104 | Sim 054
# Iter 0645 | Total Loss 30.918104 | Sim 054
# Iter 0650 | Total Loss 29.272137 | Sim 054
# Iter 0650 | Total Loss 29.272137 | Sim 054
# Iter 0655 | Total Loss 28.944742 | Sim 054
# Iter 0655 | Total Loss 28.944742 | Sim 054
# Iter 0660 | Total Loss 30.062246 | Sim 054
# Iter 0660 | Total Loss 30.062246 | Sim 054
# Iter 0665 | Total Loss 29.873629 | Sim 054
# Iter 0665 | Total Loss 29.873629 | Sim 054
# Iter 0670 | Total Loss 29.331738 | Sim 054
# Iter 0670 | Total Loss 29.331738 | Sim 054
# Iter 0675 | Total Loss 29.088245 | Sim 054
# Iter 0675 | Total Loss 29.088245 | Sim 054
# Iter 0680 | Total Loss 29.087746 | Sim 054
# Iter 0680 | Total Loss 29.087746 | Sim 054
# Iter 0685 | Total Loss 28.692842 | Sim 054
# Iter 0685 | Total Loss 28.692842 | Sim 054
# Iter 0690 | Total Loss 28.360970 | Sim 054
# Iter 0690 | Total Loss 28.360970 | Sim 054
# Iter 0695 | Total Loss 28.691290 | Sim 054
# Iter 0695 | Total Loss 28.691290 | Sim 054
# Iter 0700 | Total Loss 29.229002 | Sim 054
# Iter 0700 | Total Loss 29.229002 | Sim 054
# Iter 0705 | Total Loss 29.993025 | Sim 054
# Iter 0705 | Total Loss 29.993025 | Sim 054
# Iter 0710 | Total Loss 29.111908 | Sim 054
# Iter 0710 | Total Loss 29.111908 | Sim 054
# Iter 0715 | Total Loss 28.445473 | Sim 054
# Iter 0715 | Total Loss 28.445473 | Sim 054
# Iter 0720 | Total Loss 28.415728 | Sim 054
# Iter 0720 | Total Loss 28.415728 | Sim 054
# Iter 0725 | Total Loss 27.852898 | Sim 054
# Iter 0725 | Total Loss 27.852898 | Sim 054
# Iter 0730 | Total Loss 27.491489 | Sim 054
# Iter 0730 | Total Loss 27.491489 | Sim 054
# Iter 0735 | Total Loss 28.185413 | Sim 054
# Iter 0735 | Total Loss 28.185413 | Sim 054
# Iter 0740 | Total Loss 28.838131 | Sim 054
# Iter 0740 | Total Loss 28.838131 | Sim 054
# Iter 0745 | Total Loss 28.151983 | Sim 054
# Iter 0745 | Total Loss 28.151983 | Sim 054
# Iter 0750 | Total Loss 28.356207 | Sim 054
# Iter 0750 | Total Loss 28.356207 | Sim 054
# Saved Model for Sim 054
#
# Saved Model for Sim 054
#
# ODEFunc(
#   (net1): Sequential(
#     (0): Linear(in_features=160, out_features=100, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=100, out_features=100, bias=True)
#     (3): Tanh()
#     (4): Linear(in_features=100, out_features=160, bias=True)
#   )
# )
# ODEFunc(
#   (net1): Sequential(
#     (0): Linear(in_features=160, out_features=100, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=100, out_features=100, bias=True)
#     (3): Tanh()
#     (4): Linear(in_features=100, out_features=160, bias=True)
#   )
# )
# Number of parameters: 42360
# Number of parameters: 42360
# Iter 0005 | Total Loss 1202.279785 | Sim 064
# Iter 0005 | Total Loss 1202.279785 | Sim 064
# Iter 0010 | Total Loss 1166.619751 | Sim 064
# Iter 0010 | Total Loss 1166.619751 | Sim 064
# Iter 0015 | Total Loss 1126.339722 | Sim 064
# Iter 0015 | Total Loss 1126.339722 | Sim 064
# Iter 0020 | Total Loss 1083.121704 | Sim 064
# Iter 0020 | Total Loss 1083.121704 | Sim 064
# Iter 0025 | Total Loss 1038.480591 | Sim 064
# Iter 0025 | Total Loss 1038.480591 | Sim 064
# Iter 0030 | Total Loss 993.228394 | Sim 064
# Iter 0030 | Total Loss 993.228394 | Sim 064
# Iter 0035 | Total Loss 947.958313 | Sim 064
# Iter 0035 | Total Loss 947.958313 | Sim 064
# Iter 0040 | Total Loss 903.004456 | Sim 064
# Iter 0040 | Total Loss 903.004456 | Sim 064
# Iter 0045 | Total Loss 858.663269 | Sim 064
# Iter 0045 | Total Loss 858.663269 | Sim 064
# Iter 0050 | Total Loss 814.671204 | Sim 064
# Iter 0050 | Total Loss 814.671204 | Sim 064
# Iter 0055 | Total Loss 770.950684 | Sim 064
# Iter 0055 | Total Loss 770.950684 | Sim 064
# Iter 0060 | Total Loss 727.796265 | Sim 064
# Iter 0060 | Total Loss 727.796265 | Sim 064
# Iter 0065 | Total Loss 685.090698 | Sim 064
# Iter 0065 | Total Loss 685.090698 | Sim 064
# Iter 0070 | Total Loss 643.007812 | Sim 064
# Iter 0070 | Total Loss 643.007812 | Sim 064
# Iter 0075 | Total Loss 601.016479 | Sim 064
# Iter 0075 | Total Loss 601.016479 | Sim 064
# Iter 0080 | Total Loss 559.418152 | Sim 064
# Iter 0080 | Total Loss 559.418152 | Sim 064
# Iter 0085 | Total Loss 518.424438 | Sim 064
# Iter 0085 | Total Loss 518.424438 | Sim 064
# Iter 0090 | Total Loss 477.876373 | Sim 064
# Iter 0090 | Total Loss 477.876373 | Sim 064
# Iter 0095 | Total Loss 437.793488 | Sim 064
# Iter 0095 | Total Loss 437.793488 | Sim 064
# Iter 0100 | Total Loss 398.260834 | Sim 064
# Iter 0100 | Total Loss 398.260834 | Sim 064
# Iter 0105 | Total Loss 359.266022 | Sim 064
# Iter 0105 | Total Loss 359.266022 | Sim 064
# Iter 0110 | Total Loss 321.594666 | Sim 064
# Iter 0110 | Total Loss 321.594666 | Sim 064
# Iter 0115 | Total Loss 285.179840 | Sim 064
# Iter 0115 | Total Loss 285.179840 | Sim 064
# Iter 0120 | Total Loss 250.421844 | Sim 064
# Iter 0120 | Total Loss 250.421844 | Sim 064
# Iter 0125 | Total Loss 216.218475 | Sim 064
# Iter 0125 | Total Loss 216.218475 | Sim 064
# Iter 0130 | Total Loss 184.873520 | Sim 064
# Iter 0130 | Total Loss 184.873520 | Sim 064
# Iter 0135 | Total Loss 155.792358 | Sim 064
# Iter 0135 | Total Loss 155.792358 | Sim 064
# Iter 0140 | Total Loss 129.536362 | Sim 064
# Iter 0140 | Total Loss 129.536362 | Sim 064
# Iter 0145 | Total Loss 106.635765 | Sim 064
# Iter 0145 | Total Loss 106.635765 | Sim 064
# Iter 0150 | Total Loss 89.099289 | Sim 064
# Iter 0150 | Total Loss 89.099289 | Sim 064
# Iter 0155 | Total Loss 75.318832 | Sim 064
# Iter 0155 | Total Loss 75.318832 | Sim 064
# Iter 0160 | Total Loss 64.367523 | Sim 064
# Iter 0160 | Total Loss 64.367523 | Sim 064
# Iter 0165 | Total Loss 56.277679 | Sim 064
# Iter 0165 | Total Loss 56.277679 | Sim 064
# Iter 0170 | Total Loss 51.220291 | Sim 064
# Iter 0170 | Total Loss 51.220291 | Sim 064
# Iter 0175 | Total Loss 47.704025 | Sim 064
# Iter 0175 | Total Loss 47.704025 | Sim 064
# Iter 0180 | Total Loss 45.035824 | Sim 064
# Iter 0180 | Total Loss 45.035824 | Sim 064
# Iter 0185 | Total Loss 43.283516 | Sim 064
# Iter 0185 | Total Loss 43.283516 | Sim 064
# Iter 0190 | Total Loss 41.815048 | Sim 064
# Iter 0190 | Total Loss 41.815048 | Sim 064
# Iter 0195 | Total Loss 40.907177 | Sim 064
# Iter 0195 | Total Loss 40.907177 | Sim 064
# Iter 0200 | Total Loss 40.747364 | Sim 064
# Iter 0200 | Total Loss 40.747364 | Sim 064
# Iter 0205 | Total Loss 40.809425 | Sim 064
# Iter 0205 | Total Loss 40.809425 | Sim 064
# Iter 0210 | Total Loss 40.929314 | Sim 064
# Iter 0210 | Total Loss 40.929314 | Sim 064
# Iter 0215 | Total Loss 40.689880 | Sim 064
# Iter 0215 | Total Loss 40.689880 | Sim 064
# Iter 0220 | Total Loss 40.331455 | Sim 064
# Iter 0220 | Total Loss 40.331455 | Sim 064
# Iter 0225 | Total Loss 40.145004 | Sim 064
# Iter 0225 | Total Loss 40.145004 | Sim 064
# Iter 0230 | Total Loss 39.963985 | Sim 064
# Iter 0230 | Total Loss 39.963985 | Sim 064
# Iter 0235 | Total Loss 39.908611 | Sim 064
# Iter 0235 | Total Loss 39.908611 | Sim 064
# Iter 0240 | Total Loss 39.701191 | Sim 064
# Iter 0240 | Total Loss 39.701191 | Sim 064
# Iter 0245 | Total Loss 39.830887 | Sim 064
# Iter 0245 | Total Loss 39.830887 | Sim 064
# Iter 0250 | Total Loss 39.236145 | Sim 064
# Iter 0250 | Total Loss 39.236145 | Sim 064
# Iter 0255 | Total Loss 38.861385 | Sim 064
# Iter 0255 | Total Loss 38.861385 | Sim 064
# Iter 0260 | Total Loss 38.824451 | Sim 064
# Iter 0260 | Total Loss 38.824451 | Sim 064
# Iter 0265 | Total Loss 38.775856 | Sim 064
# Iter 0265 | Total Loss 38.775856 | Sim 064
# Iter 0270 | Total Loss 38.715874 | Sim 064
# Iter 0270 | Total Loss 38.715874 | Sim 064
# Iter 0275 | Total Loss 38.675896 | Sim 064
# Iter 0275 | Total Loss 38.675896 | Sim 064
# Iter 0280 | Total Loss 38.953220 | Sim 064
# Iter 0280 | Total Loss 38.953220 | Sim 064
# Iter 0285 | Total Loss 38.979755 | Sim 064
# Iter 0285 | Total Loss 38.979755 | Sim 064
# Iter 0290 | Total Loss 39.443897 | Sim 064
# Iter 0290 | Total Loss 39.443897 | Sim 064
# Iter 0295 | Total Loss 39.563877 | Sim 064
# Iter 0295 | Total Loss 39.563877 | Sim 064
# Iter 0300 | Total Loss 39.376362 | Sim 064
# Iter 0300 | Total Loss 39.376362 | Sim 064
# Iter 0305 | Total Loss 39.245647 | Sim 064
# Iter 0305 | Total Loss 39.245647 | Sim 064
# Iter 0310 | Total Loss 39.239395 | Sim 064
# Iter 0310 | Total Loss 39.239395 | Sim 064
# Iter 0315 | Total Loss 39.204121 | Sim 064
# Iter 0315 | Total Loss 39.204121 | Sim 064
# Iter 0320 | Total Loss 39.249081 | Sim 064
# Iter 0320 | Total Loss 39.249081 | Sim 064
# Iter 0325 | Total Loss 39.101540 | Sim 064
# Iter 0325 | Total Loss 39.101540 | Sim 064
# Iter 0330 | Total Loss 39.071175 | Sim 064
# Iter 0330 | Total Loss 39.071175 | Sim 064
# Iter 0335 | Total Loss 38.853382 | Sim 064
# Iter 0335 | Total Loss 38.853382 | Sim 064
# Iter 0340 | Total Loss 38.539951 | Sim 064
# Iter 0340 | Total Loss 38.539951 | Sim 064
# Iter 0345 | Total Loss 38.474197 | Sim 064
# Iter 0345 | Total Loss 38.474197 | Sim 064
# Iter 0350 | Total Loss 38.408443 | Sim 064
# Iter 0350 | Total Loss 38.408443 | Sim 064
# Iter 0355 | Total Loss 38.365673 | Sim 064
# Iter 0355 | Total Loss 38.365673 | Sim 064
# Iter 0360 | Total Loss 38.437061 | Sim 064
# Iter 0360 | Total Loss 38.437061 | Sim 064
# Iter 0365 | Total Loss 38.564384 | Sim 064
# Iter 0365 | Total Loss 38.564384 | Sim 064
# Iter 0370 | Total Loss 38.720863 | Sim 064
# Iter 0370 | Total Loss 38.720863 | Sim 064
# Iter 0375 | Total Loss 38.917767 | Sim 064
# Iter 0375 | Total Loss 38.917767 | Sim 064
# Iter 0380 | Total Loss 39.230358 | Sim 064
# Iter 0380 | Total Loss 39.230358 | Sim 064
# Iter 0385 | Total Loss 39.327511 | Sim 064
# Iter 0385 | Total Loss 39.327511 | Sim 064
# Iter 0390 | Total Loss 39.832287 | Sim 064
# Iter 0390 | Total Loss 39.832287 | Sim 064
# Iter 0395 | Total Loss 41.132767 | Sim 064
# Iter 0395 | Total Loss 41.132767 | Sim 064
# Iter 0400 | Total Loss 42.034050 | Sim 064
# Iter 0400 | Total Loss 42.034050 | Sim 064
# Iter 0405 | Total Loss 41.562862 | Sim 064
# Iter 0405 | Total Loss 41.562862 | Sim 064
# Iter 0410 | Total Loss 41.448242 | Sim 064
# Iter 0410 | Total Loss 41.448242 | Sim 064
# Iter 0415 | Total Loss 42.012680 | Sim 064
# Iter 0415 | Total Loss 42.012680 | Sim 064
# Iter 0420 | Total Loss 42.003815 | Sim 064
# Iter 0420 | Total Loss 42.003815 | Sim 064
# Iter 0425 | Total Loss 41.538750 | Sim 064
# Iter 0425 | Total Loss 41.538750 | Sim 064
# Iter 0430 | Total Loss 41.070850 | Sim 064
# Iter 0430 | Total Loss 41.070850 | Sim 064
# Iter 0435 | Total Loss 40.077599 | Sim 064
# Iter 0435 | Total Loss 40.077599 | Sim 064
# Iter 0440 | Total Loss 39.883736 | Sim 064
# Iter 0440 | Total Loss 39.883736 | Sim 064
# Iter 0445 | Total Loss 39.683994 | Sim 064
# Iter 0445 | Total Loss 39.683994 | Sim 064
# Iter 0450 | Total Loss 39.456711 | Sim 064
# Iter 0450 | Total Loss 39.456711 | Sim 064
# Iter 0455 | Total Loss 39.464947 | Sim 064
# Iter 0455 | Total Loss 39.464947 | Sim 064
# Iter 0460 | Total Loss 39.303616 | Sim 064
# Iter 0460 | Total Loss 39.303616 | Sim 064
# Iter 0465 | Total Loss 39.191498 | Sim 064
# Iter 0465 | Total Loss 39.191498 | Sim 064
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_2018981/3162781.py in <module>
#       2 # for sim in pending_sims:
#       3 for sim in sd_calib:
# ----> 4     runNeuralODE(sim, trained_models, niters=750, test_freq=5)
#
# /tmp/ipykernel_2018981/566247438.py in runNeuralODE(simID, model_save_path, niters, test_freq, batch_time, batch_size)
#      32
#      33         loss = getAbsoluteAvgBatchLoss(pred_y, batch_y)
# ---> 34         loss.backward()
#      35         optimizer.step()
#      36
#
# ~/.local/perlmutter/pytorch1.9.0/lib/python3.8/site-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     485                 inputs=inputs,
#     486             )
# --> 487         torch.autograd.backward(
#     488             self, gradient, retain_graph, create_graph, inputs=inputs
#     489         )
#
# ~/.local/perlmutter/pytorch1.9.0/lib/python3.8/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     198     # some Python versions print out the first line of a multi-line function
#     199     # calls in the traceback and some print out the last line
# --> 200     Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     201         tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     202         allow_unreachable=True, accumulate_grad=True)  # Calls into the C++ engine to run the backward pass
#
# KeyboardInterrupt:
